# %%
# Validation of the steady-state simulation - Case 3: AeroCNN-II
import os
import sys
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import datetime
# %matplotlib inline

# %%
### Defining parameters and hyperparameters of the model

n_kernels=200 # Number of kernels in convolutional network
kernel_size1=3
strides=1
n_units=128 # Number of units in the hidden layer of the MLP network
input_size = 100 # Size of input for the network (100 coefficients and 3 other parameters, AoA, h, beta)
lr = 1e-04 # Learning rate of the network
test_rate=0.1 # Defines the ratio of training dataset and test dataset
val_rate=0.2
n_data = 16 # Number of txt files from which the aerodynamic coefficients are extracted
batch_size = 20 # Mini-batch size

# %%
# Changing working directory

main_directory = 'D:\\VAWT_data\\flap_steady\\flap_steady'
os.chdir(main_directory)

# %%
## Basic parameters

c = 1 # Chord length
h = np.array([0.01, 0.02, 0.03]) * c # Height of the Gurney flaps
t = 0.02 * h # Thickness of the Gurney flaps
alpha = np.linspace(0, 16, 9).reshape((9,1)) # Angles of attack
beta = np.linspace(30, 90, 5).reshape((5,1))

h = h.reshape((-1,1))
t = t.reshape((-1,1))

# %%
n_alpha = alpha.shape[0] # Number of the angles of attack
n_beta = beta.shape[0] # Number of the Gurney flap inclination
n_h = h.shape[0] # Number of the height of the Gurney flaps
n_cases = n_data * n_alpha
aa_ = np.zeros((n_cases,1))
for i in range(0, n_data):
    aa_[n_alpha*i:n_alpha*(i+1),:] = alpha[:,:]
    
aa = aa_ / np.max(alpha)

# %%
h = h.reshape((-1,1))
t = t.reshape((-1,1))

# %%
n_alpha = alpha.shape[0] # Number of the angles of attack
n_beta = beta.shape[0] # Number of the Gurney flap inclination
n_h = h.shape[0] # Number of the height of the Gurney flaps
n_cases = n_data * n_alpha # Total number of cases(Number of geometries * Number of angles of attack)

# %%
## Creating input dataset - mask
mask_dir = main_directory + '\\aeroCNN2Mask'
os.chdir(mask_dir)
mask_list = os.listdir(mask_dir)
mask_target = [file for file in mask_list if file.endswith('.csv')]

# %%
mask_df = pd.DataFrame()
for file in mask_target:
    data = pd.read_csv(file, header=None)
    mask_df = pd.concat([mask_df, data], axis=0)

# %%
x = mask_df.iloc[:,:].values

# %%
x_alligned = np.zeros((x.shape[0],x.shape[1]))
for i in range(0,144*2):
    if i%2==0:
        x_alligned[i*100:(i+1)*100,:] = x[i*100:(i+1)*100,:]
    else:
        x_alligned[i*100:(i+1)*100,:] = x[i*100:(i+1)*100,:].T

# %%
x = x_alligned.reshape((16*9,2,input_size,input_size))

# %%
## Creating output dataset - Cl and Cd
files_orig = os.listdir(main_directory)
files_target = [file for file in files_orig if file.endswith('.txt')]
os.chdir(main_directory)

# %%
target_df = pd.DataFrame()
for file in files_target:
    data = pd.read_table(file, header=None)
    target_df = pd.concat([target_df, data], axis=0)

# %%
cd_orig = target_df.iloc[:,3].values # Cd values
#target_c4 = target_df.iloc[:,4].values# Cl values

# %%
cd = (cd_orig-np.min(cd_orig))/(np.max(cd_orig)-np.min(cd_orig))

# %%
y = cd.reshape((-1,1))

# %%
x_all, x_test, y_all, y_test = train_test_split(x, y, test_size=test_rate, random_state=1)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_all, y_all, test_size=val_rate/(1-test_rate), random_state=1)

# %%
x_train.shape
# Out:
# (100, 2, 100, 100)

# %%
y_train.shape
# Out:
# (100, 1)

# %%
tf.keras.backend.set_image_data_format('channels_first')

# %%
input_image = tf.keras.Input(shape=(2, input_size, input_size))

x_conv1 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(input_image)
x1_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv1)
x_conv2 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x1_)
x2_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv2)
x_conv3 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x2_)
x3_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv3)
x_conv4 = tf.keras.layers.Conv2D(1, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x3_)
x4_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv4)
x_flat = tf.keras.layers.Flatten()(x4_)
x_fc1 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc1')(x_flat)
x_fc2 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc2')(x_fc1)
x_fc3 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc3')(x_fc2)
x_fc4 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc4')(x_fc3)
x_fc5 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc5')(x_fc4)

output_data = tf.keras.layers.Dense(units=1, activation='linear', name='outputLayer')(x_fc5)
# AeroCNN-II based
model = tf.keras.Model(input_image, output_data)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2, 100, 100)]     0
#
#  conv2d (Conv2D)             (None, 200, 100, 100)     3800
#
#  max_pooling2d (MaxPooling2D  (None, 200, 50, 50)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 200, 50, 50)       360200
#
#  max_pooling2d_1 (MaxPooling  (None, 200, 25, 25)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 200, 25, 25)       360200
#
#  max_pooling2d_2 (MaxPooling  (None, 200, 12, 12)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 1, 12, 12)         1801
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 6, 6)          0
#  2D)
#
#  flatten (Flatten)           (None, 36)                0
#
#  fc1 (Dense)                 (None, 128)               4736
#
#  fc2 (Dense)                 (None, 128)               16512
#
#  fc3 (Dense)                 (None, 128)               16512
#
#  fc4 (Dense)                 (None, 128)               16512
#
#  fc5 (Dense)                 (None, 128)               16512
#
#  outputLayer (Dense)         (None, 1)                 129
#
# =================================================================
# Total params: 796,914
# Trainable params: 796,914
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
              loss = tf.keras.losses.MeanSquaredError(),
              metrics=[tf.keras.metrics.RootMeanSquaredError(name="rmse")])

# %%
model_directory = "D:\\TrainedModels\\20221130"
if not os.path.exists(model_directory):
    os.makedirs(model_directory)

# %%
# ckpt_name = model_directory + "\\20221130steadyValidation_AeroCNN2_val_"+str(val_rate) + "_test"+str(test_rate)+ "_" + str(n_units) +"units_OptimalSettings_Cdcheckpoint.h5"

# ckpt = tf.keras.callbacks.ModelCheckpoint(ckpt_name, monitor="val_loss", mode='min', verbose=1, save_best_only=True)

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=1000, min_delta=6e-7,
                                      restore_best_weights=True, verbose=1)
rp = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=200, factor=0.5,
                                          min_delta = 1e-09, min_lr=1e-06, verbose=1)

# %%
STEP_SIZE_TRAIN = len(x_train)//batch_size
VALIDATION_STEPS = len(x_val)//batch_size

# %%
start = datetime.datetime.now()
history = model.fit(x_train, y_train, batch_size=batch_size,
                    validation_data=(x_val, y_val),
                    steps_per_epoch = STEP_SIZE_TRAIN, validation_steps=VALIDATION_STEPS,
                    epochs=10000, shuffle=True, callbacks=[es, rp])
end = datetime.datetime.now()
# Out:
# Epoch 1/10000
# 5/5 [==============================] - 3s 66ms/step - loss: 0.1153 - rmse: 0.3395 - val_loss: 0.0433 - val_rmse: 0.2082 - lr: 1.0000e-04
# Epoch 2/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0476 - rmse: 0.2183 - val_loss: 0.0261 - val_rmse: 0.1614 - lr: 1.0000e-04
# Epoch 3/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0315 - rmse: 0.1775 - val_loss: 0.0103 - val_rmse: 0.1014 - lr: 1.0000e-04
# Epoch 4/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0167 - rmse: 0.1292 - val_loss: 0.0096 - val_rmse: 0.0978 - lr: 1.0000e-04
# Epoch 5/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0110 - rmse: 0.1050 - val_loss: 0.0062 - val_rmse: 0.0789 - lr: 1.0000e-04
# Epoch 6/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0079 - rmse: 0.0890 - val_loss: 0.0056 - val_rmse: 0.0746 - lr: 1.0000e-04
# Epoch 7/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0066 - rmse: 0.0812 - val_loss: 0.0042 - val_rmse: 0.0649 - lr: 1.0000e-04
# Epoch 8/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0055 - rmse: 0.0743 - val_loss: 0.0039 - val_rmse: 0.0628 - lr: 1.0000e-04
# Epoch 9/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0046 - rmse: 0.0681 - val_loss: 0.0040 - val_rmse: 0.0630 - lr: 1.0000e-04
# Epoch 10/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0041 - rmse: 0.0644 - val_loss: 0.0035 - val_rmse: 0.0595 - lr: 1.0000e-04
# Epoch 11/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0039 - rmse: 0.0623 - val_loss: 0.0031 - val_rmse: 0.0560 - lr: 1.0000e-04
# Epoch 12/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0039 - rmse: 0.0625 - val_loss: 0.0025 - val_rmse: 0.0500 - lr: 1.0000e-04
# Epoch 13/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0032 - rmse: 0.0569 - val_loss: 0.0030 - val_rmse: 0.0551 - lr: 1.0000e-04
# Epoch 14/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0028 - rmse: 0.0530 - val_loss: 0.0025 - val_rmse: 0.0501 - lr: 1.0000e-04
# Epoch 15/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0029 - rmse: 0.0537 - val_loss: 0.0024 - val_rmse: 0.0494 - lr: 1.0000e-04
# Epoch 16/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0025 - rmse: 0.0499 - val_loss: 0.0028 - val_rmse: 0.0531 - lr: 1.0000e-04
# Epoch 17/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0027 - rmse: 0.0522 - val_loss: 0.0029 - val_rmse: 0.0535 - lr: 1.0000e-04
# Epoch 18/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0025 - rmse: 0.0502 - val_loss: 0.0026 - val_rmse: 0.0511 - lr: 1.0000e-04
# Epoch 19/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0019 - rmse: 0.0440 - val_loss: 0.0030 - val_rmse: 0.0549 - lr: 1.0000e-04
# Epoch 20/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0019 - rmse: 0.0432 - val_loss: 0.0026 - val_rmse: 0.0509 - lr: 1.0000e-04
# Epoch 21/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0020 - rmse: 0.0444 - val_loss: 0.0024 - val_rmse: 0.0485 - lr: 1.0000e-04
# Epoch 22/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0017 - rmse: 0.0410 - val_loss: 0.0036 - val_rmse: 0.0596 - lr: 1.0000e-04
# Epoch 23/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0019 - rmse: 0.0431 - val_loss: 0.0028 - val_rmse: 0.0530 - lr: 1.0000e-04
# Epoch 24/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0017 - rmse: 0.0407 - val_loss: 0.0028 - val_rmse: 0.0525 - lr: 1.0000e-04
# Epoch 25/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0016 - rmse: 0.0405 - val_loss: 0.0033 - val_rmse: 0.0573 - lr: 1.0000e-04
# Epoch 26/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0013 - rmse: 0.0357 - val_loss: 0.0026 - val_rmse: 0.0513 - lr: 1.0000e-04
# Epoch 27/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0014 - rmse: 0.0371 - val_loss: 0.0027 - val_rmse: 0.0523 - lr: 1.0000e-04
# Epoch 28/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0014 - rmse: 0.0381 - val_loss: 0.0030 - val_rmse: 0.0548 - lr: 1.0000e-04
# Epoch 29/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0010 - rmse: 0.0317 - val_loss: 0.0031 - val_rmse: 0.0555 - lr: 1.0000e-04
# Epoch 30/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0012 - rmse: 0.0340 - val_loss: 0.0027 - val_rmse: 0.0522 - lr: 1.0000e-04
# Epoch 31/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0333 - val_loss: 0.0029 - val_rmse: 0.0537 - lr: 1.0000e-04
# Epoch 32/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 9.2495e-04 - rmse: 0.0304 - val_loss: 0.0025 - val_rmse: 0.0496 - lr: 1.0000e-04
# Epoch 33/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.9336e-04 - rmse: 0.0299 - val_loss: 0.0029 - val_rmse: 0.0542 - lr: 1.0000e-04
# Epoch 34/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0011 - rmse: 0.0327 - val_loss: 0.0027 - val_rmse: 0.0523 - lr: 1.0000e-04
# Epoch 35/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.3977e-04 - rmse: 0.0290 - val_loss: 0.0028 - val_rmse: 0.0525 - lr: 1.0000e-04
# Epoch 36/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.3080e-04 - rmse: 0.0288 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 1.0000e-04
# Epoch 37/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.0012e-04 - rmse: 0.0265 - val_loss: 0.0027 - val_rmse: 0.0522 - lr: 1.0000e-04
# Epoch 38/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 9.0726e-04 - rmse: 0.0301 - val_loss: 0.0031 - val_rmse: 0.0557 - lr: 1.0000e-04
# Epoch 39/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.9569e-04 - rmse: 0.0282 - val_loss: 0.0028 - val_rmse: 0.0524 - lr: 1.0000e-04
# Epoch 40/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.6126e-04 - rmse: 0.0276 - val_loss: 0.0031 - val_rmse: 0.0554 - lr: 1.0000e-04
# Epoch 41/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.2299e-04 - rmse: 0.0287 - val_loss: 0.0031 - val_rmse: 0.0558 - lr: 1.0000e-04
# Epoch 42/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.9283e-04 - rmse: 0.0282 - val_loss: 0.0026 - val_rmse: 0.0511 - lr: 1.0000e-04
# Epoch 43/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.3626e-04 - rmse: 0.0289 - val_loss: 0.0035 - val_rmse: 0.0592 - lr: 1.0000e-04
# Epoch 44/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.7342e-04 - rmse: 0.0278 - val_loss: 0.0028 - val_rmse: 0.0527 - lr: 1.0000e-04
# Epoch 45/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.8435e-04 - rmse: 0.0297 - val_loss: 0.0033 - val_rmse: 0.0573 - lr: 1.0000e-04
# Epoch 46/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.1846e-04 - rmse: 0.0286 - val_loss: 0.0023 - val_rmse: 0.0477 - lr: 1.0000e-04
# Epoch 47/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.9353e-04 - rmse: 0.0263 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 1.0000e-04
# Epoch 48/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.5810e-04 - rmse: 0.0310 - val_loss: 0.0030 - val_rmse: 0.0549 - lr: 1.0000e-04
# Epoch 49/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.5346e-04 - rmse: 0.0274 - val_loss: 0.0024 - val_rmse: 0.0494 - lr: 1.0000e-04
# Epoch 50/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3628e-04 - rmse: 0.0252 - val_loss: 0.0039 - val_rmse: 0.0622 - lr: 1.0000e-04
# Epoch 51/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 7.4488e-04 - rmse: 0.0273 - val_loss: 0.0022 - val_rmse: 0.0474 - lr: 1.0000e-04
# Epoch 52/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.5095e-04 - rmse: 0.0274 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 1.0000e-04
# Epoch 53/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0010 - rmse: 0.0318 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 1.0000e-04
# Epoch 54/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.3122e-04 - rmse: 0.0270 - val_loss: 0.0047 - val_rmse: 0.0689 - lr: 1.0000e-04
# Epoch 55/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.5943e-04 - rmse: 0.0257 - val_loss: 0.0023 - val_rmse: 0.0481 - lr: 1.0000e-04
# Epoch 56/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.2973e-04 - rmse: 0.0251 - val_loss: 0.0038 - val_rmse: 0.0615 - lr: 1.0000e-04
# Epoch 57/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.1083e-04 - rmse: 0.0247 - val_loss: 0.0029 - val_rmse: 0.0538 - lr: 1.0000e-04
# Epoch 58/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4764e-04 - rmse: 0.0234 - val_loss: 0.0030 - val_rmse: 0.0552 - lr: 1.0000e-04
# Epoch 59/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.4635e-04 - rmse: 0.0211 - val_loss: 0.0029 - val_rmse: 0.0537 - lr: 1.0000e-04
# Epoch 60/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.3289e-04 - rmse: 0.0208 - val_loss: 0.0029 - val_rmse: 0.0541 - lr: 1.0000e-04
# Epoch 61/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.4808e-04 - rmse: 0.0187 - val_loss: 0.0029 - val_rmse: 0.0542 - lr: 1.0000e-04
# Epoch 62/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.6131e-04 - rmse: 0.0190 - val_loss: 0.0027 - val_rmse: 0.0524 - lr: 1.0000e-04
# Epoch 63/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 3.4759e-04 - rmse: 0.0186 - val_loss: 0.0030 - val_rmse: 0.0544 - lr: 1.0000e-04
# Epoch 64/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 3.3830e-04 - rmse: 0.0184 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 1.0000e-04
# Epoch 65/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.2167e-04 - rmse: 0.0205 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 1.0000e-04
# Epoch 66/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.3554e-04 - rmse: 0.0183 - val_loss: 0.0028 - val_rmse: 0.0529 - lr: 1.0000e-04
# Epoch 67/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.5687e-04 - rmse: 0.0214 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 1.0000e-04
# Epoch 68/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 3.7363e-04 - rmse: 0.0193 - val_loss: 0.0027 - val_rmse: 0.0518 - lr: 1.0000e-04
# Epoch 69/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.9053e-04 - rmse: 0.0198 - val_loss: 0.0028 - val_rmse: 0.0526 - lr: 1.0000e-04
# Epoch 70/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3645e-04 - rmse: 0.0252 - val_loss: 0.0036 - val_rmse: 0.0600 - lr: 1.0000e-04
# Epoch 71/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.0191e-04 - rmse: 0.0283 - val_loss: 0.0035 - val_rmse: 0.0595 - lr: 1.0000e-04
# Epoch 72/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0010 - rmse: 0.0316 - val_loss: 0.0038 - val_rmse: 0.0620 - lr: 1.0000e-04
# Epoch 73/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0329 - val_loss: 0.0033 - val_rmse: 0.0570 - lr: 1.0000e-04
# Epoch 74/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.4382e-04 - rmse: 0.0290 - val_loss: 0.0031 - val_rmse: 0.0560 - lr: 1.0000e-04
# Epoch 75/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.5547e-04 - rmse: 0.0292 - val_loss: 0.0025 - val_rmse: 0.0497 - lr: 1.0000e-04
# Epoch 76/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 9.4079e-04 - rmse: 0.0307 - val_loss: 0.0056 - val_rmse: 0.0746 - lr: 1.0000e-04
# Epoch 77/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.3276e-04 - rmse: 0.0271 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 1.0000e-04
# Epoch 78/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.6007e-04 - rmse: 0.0310 - val_loss: 0.0054 - val_rmse: 0.0733 - lr: 1.0000e-04
# Epoch 79/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 9.7023e-04 - rmse: 0.0311 - val_loss: 0.0030 - val_rmse: 0.0551 - lr: 1.0000e-04
# Epoch 80/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0326 - val_loss: 0.0037 - val_rmse: 0.0605 - lr: 1.0000e-04
# Epoch 81/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0012 - rmse: 0.0348 - val_loss: 0.0029 - val_rmse: 0.0542 - lr: 1.0000e-04
# Epoch 82/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.4581e-04 - rmse: 0.0273 - val_loss: 0.0029 - val_rmse: 0.0535 - lr: 1.0000e-04
# Epoch 83/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.7931e-04 - rmse: 0.0279 - val_loss: 0.0032 - val_rmse: 0.0567 - lr: 1.0000e-04
# Epoch 84/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.4497e-04 - rmse: 0.0211 - val_loss: 0.0026 - val_rmse: 0.0508 - lr: 1.0000e-04
# Epoch 85/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6686e-04 - rmse: 0.0216 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 1.0000e-04
# Epoch 86/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4347e-04 - rmse: 0.0233 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 1.0000e-04
# Epoch 87/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0738e-04 - rmse: 0.0225 - val_loss: 0.0031 - val_rmse: 0.0560 - lr: 1.0000e-04
# Epoch 88/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0511e-04 - rmse: 0.0175 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 1.0000e-04
# Epoch 89/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4802e-04 - rmse: 0.0157 - val_loss: 0.0029 - val_rmse: 0.0541 - lr: 1.0000e-04
# Epoch 90/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4148e-04 - rmse: 0.0155 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 1.0000e-04
# Epoch 91/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5040e-04 - rmse: 0.0158 - val_loss: 0.0029 - val_rmse: 0.0543 - lr: 1.0000e-04
# Epoch 92/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.2635e-04 - rmse: 0.0181 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 1.0000e-04
# Epoch 93/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9950e-04 - rmse: 0.0173 - val_loss: 0.0031 - val_rmse: 0.0552 - lr: 1.0000e-04
# Epoch 94/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7594e-04 - rmse: 0.0166 - val_loss: 0.0031 - val_rmse: 0.0560 - lr: 1.0000e-04
# Epoch 95/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0265e-04 - rmse: 0.0174 - val_loss: 0.0029 - val_rmse: 0.0540 - lr: 1.0000e-04
# Epoch 96/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.5930e-04 - rmse: 0.0161 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 1.0000e-04
# Epoch 97/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9460e-04 - rmse: 0.0172 - val_loss: 0.0028 - val_rmse: 0.0532 - lr: 1.0000e-04
# Epoch 98/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.8092e-04 - rmse: 0.0219 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 1.0000e-04
# Epoch 99/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.2591e-04 - rmse: 0.0206 - val_loss: 0.0035 - val_rmse: 0.0595 - lr: 1.0000e-04
# Epoch 100/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.7496e-04 - rmse: 0.0260 - val_loss: 0.0026 - val_rmse: 0.0506 - lr: 1.0000e-04
# Epoch 101/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.1961e-04 - rmse: 0.0205 - val_loss: 0.0039 - val_rmse: 0.0626 - lr: 1.0000e-04
# Epoch 102/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7396e-04 - rmse: 0.0218 - val_loss: 0.0023 - val_rmse: 0.0475 - lr: 1.0000e-04
# Epoch 103/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.1150e-04 - rmse: 0.0247 - val_loss: 0.0043 - val_rmse: 0.0657 - lr: 1.0000e-04
# Epoch 104/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3487e-04 - rmse: 0.0231 - val_loss: 0.0027 - val_rmse: 0.0519 - lr: 1.0000e-04
# Epoch 105/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3296e-04 - rmse: 0.0252 - val_loss: 0.0037 - val_rmse: 0.0611 - lr: 1.0000e-04
# Epoch 106/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9975e-04 - rmse: 0.0173 - val_loss: 0.0032 - val_rmse: 0.0570 - lr: 1.0000e-04
# Epoch 107/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6645e-04 - rmse: 0.0163 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 1.0000e-04
# Epoch 108/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9356e-04 - rmse: 0.0139 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 1.0000e-04
# Epoch 109/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3630e-04 - rmse: 0.0154 - val_loss: 0.0032 - val_rmse: 0.0565 - lr: 1.0000e-04
# Epoch 110/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8564e-04 - rmse: 0.0169 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 1.0000e-04
# Epoch 111/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.7959e-04 - rmse: 0.0167 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 1.0000e-04
# Epoch 112/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8711e-04 - rmse: 0.0169 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 1.0000e-04
# Epoch 113/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8215e-04 - rmse: 0.0168 - val_loss: 0.0031 - val_rmse: 0.0553 - lr: 1.0000e-04
# Epoch 114/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8813e-04 - rmse: 0.0137 - val_loss: 0.0031 - val_rmse: 0.0556 - lr: 1.0000e-04
# Epoch 115/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7484e-04 - rmse: 0.0132 - val_loss: 0.0029 - val_rmse: 0.0538 - lr: 1.0000e-04
# Epoch 116/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5434e-04 - rmse: 0.0159 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 1.0000e-04
# Epoch 117/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 3.0168e-04 - rmse: 0.0174 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 1.0000e-04
# Epoch 118/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.2991e-04 - rmse: 0.0182 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 1.0000e-04
# Epoch 119/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2744e-04 - rmse: 0.0151 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 1.0000e-04
# Epoch 120/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8785e-04 - rmse: 0.0137 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 1.0000e-04
# Epoch 121/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8203e-04 - rmse: 0.0135 - val_loss: 0.0037 - val_rmse: 0.0609 - lr: 1.0000e-04
# Epoch 122/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9394e-04 - rmse: 0.0139 - val_loss: 0.0028 - val_rmse: 0.0533 - lr: 1.0000e-04
# Epoch 123/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0567e-04 - rmse: 0.0143 - val_loss: 0.0038 - val_rmse: 0.0619 - lr: 1.0000e-04
# Epoch 124/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8445e-04 - rmse: 0.0169 - val_loss: 0.0026 - val_rmse: 0.0508 - lr: 1.0000e-04
# Epoch 125/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.6141e-04 - rmse: 0.0215 - val_loss: 0.0042 - val_rmse: 0.0645 - lr: 1.0000e-04
# Epoch 126/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.6689e-04 - rmse: 0.0277 - val_loss: 0.0028 - val_rmse: 0.0530 - lr: 1.0000e-04
# Epoch 127/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.1773e-04 - rmse: 0.0268 - val_loss: 0.0052 - val_rmse: 0.0718 - lr: 1.0000e-04
# Epoch 128/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.3201e-04 - rmse: 0.0305 - val_loss: 0.0024 - val_rmse: 0.0492 - lr: 1.0000e-04
# Epoch 129/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.4623e-04 - rmse: 0.0273 - val_loss: 0.0036 - val_rmse: 0.0596 - lr: 1.0000e-04
# Epoch 130/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.5948e-04 - rmse: 0.0214 - val_loss: 0.0029 - val_rmse: 0.0538 - lr: 1.0000e-04
# Epoch 131/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.1733e-04 - rmse: 0.0178 - val_loss: 0.0029 - val_rmse: 0.0543 - lr: 1.0000e-04
# Epoch 132/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7019e-04 - rmse: 0.0164 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 1.0000e-04
# Epoch 133/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2319e-04 - rmse: 0.0149 - val_loss: 0.0028 - val_rmse: 0.0533 - lr: 1.0000e-04
# Epoch 134/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8326e-04 - rmse: 0.0168 - val_loss: 0.0040 - val_rmse: 0.0636 - lr: 1.0000e-04
# Epoch 135/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1095e-04 - rmse: 0.0145 - val_loss: 0.0029 - val_rmse: 0.0542 - lr: 1.0000e-04
# Epoch 136/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2323e-04 - rmse: 0.0149 - val_loss: 0.0030 - val_rmse: 0.0550 - lr: 1.0000e-04
# Epoch 137/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7389e-04 - rmse: 0.0132 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 1.0000e-04
# Epoch 138/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.7743e-04 - rmse: 0.0133 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 1.0000e-04
# Epoch 139/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5367e-04 - rmse: 0.0124 - val_loss: 0.0030 - val_rmse: 0.0545 - lr: 1.0000e-04
# Epoch 140/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5419e-04 - rmse: 0.0124 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 1.0000e-04
# Epoch 141/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4205e-04 - rmse: 0.0119 - val_loss: 0.0032 - val_rmse: 0.0565 - lr: 1.0000e-04
# Epoch 142/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3512e-04 - rmse: 0.0116 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 1.0000e-04
# Epoch 143/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3974e-04 - rmse: 0.0118 - val_loss: 0.0033 - val_rmse: 0.0571 - lr: 1.0000e-04
# Epoch 144/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4821e-04 - rmse: 0.0122 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 1.0000e-04
# Epoch 145/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7124e-04 - rmse: 0.0131 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 1.0000e-04
# Epoch 146/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7065e-04 - rmse: 0.0131 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 1.0000e-04
# Epoch 147/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7871e-04 - rmse: 0.0134 - val_loss: 0.0033 - val_rmse: 0.0575 - lr: 1.0000e-04
# Epoch 148/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3896e-04 - rmse: 0.0155 - val_loss: 0.0036 - val_rmse: 0.0603 - lr: 1.0000e-04
# Epoch 149/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4310e-04 - rmse: 0.0156 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 1.0000e-04
# Epoch 150/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6801e-04 - rmse: 0.0130 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 1.0000e-04
# Epoch 151/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.8029e-04 - rmse: 0.0134 - val_loss: 0.0031 - val_rmse: 0.0555 - lr: 1.0000e-04
# Epoch 152/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5859e-04 - rmse: 0.0161 - val_loss: 0.0032 - val_rmse: 0.0569 - lr: 1.0000e-04
# Epoch 153/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1085e-04 - rmse: 0.0145 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 1.0000e-04
# Epoch 154/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9167e-04 - rmse: 0.0138 - val_loss: 0.0033 - val_rmse: 0.0571 - lr: 1.0000e-04
# Epoch 155/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6438e-04 - rmse: 0.0128 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 1.0000e-04
# Epoch 156/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.5768e-04 - rmse: 0.0161 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 1.0000e-04
# Epoch 157/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1447e-04 - rmse: 0.0146 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 1.0000e-04
# Epoch 158/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9061e-04 - rmse: 0.0138 - val_loss: 0.0031 - val_rmse: 0.0559 - lr: 1.0000e-04
# Epoch 159/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3058e-04 - rmse: 0.0152 - val_loss: 0.0032 - val_rmse: 0.0567 - lr: 1.0000e-04
# Epoch 160/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7703e-04 - rmse: 0.0133 - val_loss: 0.0032 - val_rmse: 0.0570 - lr: 1.0000e-04
# Epoch 161/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1242e-04 - rmse: 0.0146 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 1.0000e-04
# Epoch 162/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9638e-04 - rmse: 0.0140 - val_loss: 0.0028 - val_rmse: 0.0528 - lr: 1.0000e-04
# Epoch 163/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1847e-04 - rmse: 0.0148 - val_loss: 0.0030 - val_rmse: 0.0550 - lr: 1.0000e-04
# Epoch 164/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3938e-04 - rmse: 0.0155 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 1.0000e-04
# Epoch 165/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6105e-04 - rmse: 0.0127 - val_loss: 0.0029 - val_rmse: 0.0541 - lr: 1.0000e-04
# Epoch 166/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5049e-04 - rmse: 0.0123 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 1.0000e-04
# Epoch 167/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5860e-04 - rmse: 0.0126 - val_loss: 0.0030 - val_rmse: 0.0552 - lr: 1.0000e-04
# Epoch 168/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4558e-04 - rmse: 0.0121 - val_loss: 0.0033 - val_rmse: 0.0570 - lr: 1.0000e-04
# Epoch 169/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5441e-04 - rmse: 0.0124 - val_loss: 0.0031 - val_rmse: 0.0557 - lr: 1.0000e-04
# Epoch 170/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.7903e-04 - rmse: 0.0134 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 1.0000e-04
# Epoch 171/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5761e-04 - rmse: 0.0126 - val_loss: 0.0031 - val_rmse: 0.0553 - lr: 1.0000e-04
# Epoch 172/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.4194e-04 - rmse: 0.0119 - val_loss: 0.0033 - val_rmse: 0.0571 - lr: 1.0000e-04
# Epoch 173/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2549e-04 - rmse: 0.0112 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 1.0000e-04
# Epoch 174/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3079e-04 - rmse: 0.0114 - val_loss: 0.0035 - val_rmse: 0.0589 - lr: 1.0000e-04
# Epoch 175/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1443e-04 - rmse: 0.0146 - val_loss: 0.0030 - val_rmse: 0.0548 - lr: 1.0000e-04
# Epoch 176/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.1796e-04 - rmse: 0.0148 - val_loss: 0.0036 - val_rmse: 0.0601 - lr: 1.0000e-04
# Epoch 177/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9248e-04 - rmse: 0.0171 - val_loss: 0.0032 - val_rmse: 0.0568 - lr: 1.0000e-04
# Epoch 178/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6667e-04 - rmse: 0.0163 - val_loss: 0.0031 - val_rmse: 0.0559 - lr: 1.0000e-04
# Epoch 179/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3121e-04 - rmse: 0.0152 - val_loss: 0.0036 - val_rmse: 0.0603 - lr: 1.0000e-04
# Epoch 180/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.9136e-04 - rmse: 0.0138 - val_loss: 0.0031 - val_rmse: 0.0554 - lr: 1.0000e-04
# Epoch 181/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.8651e-04 - rmse: 0.0137 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 1.0000e-04
# Epoch 182/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8975e-04 - rmse: 0.0138 - val_loss: 0.0033 - val_rmse: 0.0572 - lr: 1.0000e-04
# Epoch 183/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3387e-04 - rmse: 0.0116 - val_loss: 0.0033 - val_rmse: 0.0575 - lr: 1.0000e-04
# Epoch 184/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1130e-04 - rmse: 0.0106 - val_loss: 0.0032 - val_rmse: 0.0569 - lr: 1.0000e-04
# Epoch 185/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3338e-04 - rmse: 0.0115 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 1.0000e-04
# Epoch 186/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3200e-04 - rmse: 0.0115 - val_loss: 0.0032 - val_rmse: 0.0570 - lr: 1.0000e-04
# Epoch 187/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1480e-04 - rmse: 0.0107 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 1.0000e-04
# Epoch 188/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1101e-04 - rmse: 0.0105 - val_loss: 0.0031 - val_rmse: 0.0556 - lr: 1.0000e-04
# Epoch 189/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2965e-04 - rmse: 0.0114 - val_loss: 0.0035 - val_rmse: 0.0593 - lr: 1.0000e-04
# Epoch 190/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.9888e-04 - rmse: 0.0141 - val_loss: 0.0029 - val_rmse: 0.0535 - lr: 1.0000e-04
# Epoch 191/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3257e-04 - rmse: 0.0115 - val_loss: 0.0037 - val_rmse: 0.0611 - lr: 1.0000e-04
# Epoch 192/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5934e-04 - rmse: 0.0126 - val_loss: 0.0029 - val_rmse: 0.0536 - lr: 1.0000e-04
# Epoch 193/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3900e-04 - rmse: 0.0118 - val_loss: 0.0038 - val_rmse: 0.0619 - lr: 1.0000e-04
# Epoch 194/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8240e-04 - rmse: 0.0135 - val_loss: 0.0027 - val_rmse: 0.0518 - lr: 1.0000e-04
# Epoch 195/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.7958e-04 - rmse: 0.0134 - val_loss: 0.0038 - val_rmse: 0.0616 - lr: 1.0000e-04
# Epoch 196/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2796e-04 - rmse: 0.0113 - val_loss: 0.0030 - val_rmse: 0.0544 - lr: 1.0000e-04
# Epoch 197/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.4295e-04 - rmse: 0.0120 - val_loss: 0.0039 - val_rmse: 0.0623 - lr: 1.0000e-04
# Epoch 198/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9171e-04 - rmse: 0.0138 - val_loss: 0.0030 - val_rmse: 0.0547 - lr: 1.0000e-04
# Epoch 199/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.9036e-04 - rmse: 0.0138 - val_loss: 0.0033 - val_rmse: 0.0573 - lr: 1.0000e-04
# Epoch 200/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.7408e-04 - rmse: 0.0132 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 1.0000e-04
# Epoch 201/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5202e-04 - rmse: 0.0123 - val_loss: 0.0032 - val_rmse: 0.0569 - lr: 1.0000e-04
# Epoch 202/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2289e-04 - rmse: 0.0111 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 1.0000e-04
# Epoch 203/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6897e-04 - rmse: 0.0130 - val_loss: 0.0032 - val_rmse: 0.0569 - lr: 1.0000e-04
# Epoch 204/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6239e-04 - rmse: 0.0127 - val_loss: 0.0029 - val_rmse: 0.0541 - lr: 1.0000e-04
# Epoch 205/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1455e-04 - rmse: 0.0146 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 1.0000e-04
# Epoch 206/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3298e-04 - rmse: 0.0115 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 1.0000e-04
# Epoch 207/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.8030e-04 - rmse: 0.0134 - val_loss: 0.0037 - val_rmse: 0.0607 - lr: 1.0000e-04
# Epoch 208/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9397e-04 - rmse: 0.0139 - val_loss: 0.0030 - val_rmse: 0.0549 - lr: 1.0000e-04
# Epoch 209/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2984e-04 - rmse: 0.0114 - val_loss: 0.0038 - val_rmse: 0.0615 - lr: 1.0000e-04
# Epoch 210/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1790e-04 - rmse: 0.0109 - val_loss: 0.0032 - val_rmse: 0.0570 - lr: 1.0000e-04
# Epoch 211/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5274e-04 - rmse: 0.0124 - val_loss: 0.0037 - val_rmse: 0.0609 - lr: 1.0000e-04
# Epoch 212/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5803e-04 - rmse: 0.0126 - val_loss: 0.0027 - val_rmse: 0.0517 - lr: 1.0000e-04
# Epoch 213/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.1585e-04 - rmse: 0.0147 - val_loss: 0.0040 - val_rmse: 0.0632 - lr: 1.0000e-04
# Epoch 214/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2781e-04 - rmse: 0.0151 - val_loss: 0.0028 - val_rmse: 0.0529 - lr: 1.0000e-04
# Epoch 215/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4077e-04 - rmse: 0.0119 - val_loss: 0.0036 - val_rmse: 0.0600 - lr: 1.0000e-04
# Epoch 216/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2900e-04 - rmse: 0.0114 - val_loss: 0.0028 - val_rmse: 0.0528 - lr: 1.0000e-04
# Epoch 217/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1036e-04 - rmse: 0.0105 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 1.0000e-04
# Epoch 218/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.0778e-04 - rmse: 0.0104 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 1.0000e-04
# Epoch 219/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0248e-04 - rmse: 0.0101 - val_loss: 0.0031 - val_rmse: 0.0557 - lr: 1.0000e-04
# Epoch 220/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0200e-04 - rmse: 0.0101 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 1.0000e-04
# Epoch 221/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2709e-04 - rmse: 0.0113 - val_loss: 0.0031 - val_rmse: 0.0558 - lr: 1.0000e-04
# Epoch 222/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.4645e-05 - rmse: 0.0097 - val_loss: 0.0032 - val_rmse: 0.0565 - lr: 1.0000e-04
# Epoch 223/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4650e-04 - rmse: 0.0121 - val_loss: 0.0031 - val_rmse: 0.0560 - lr: 1.0000e-04
# Epoch 224/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0556e-04 - rmse: 0.0103 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 1.0000e-04
# Epoch 225/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1250e-04 - rmse: 0.0106 - val_loss: 0.0030 - val_rmse: 0.0548 - lr: 1.0000e-04
# Epoch 226/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.5091e-05 - rmse: 0.0098 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 1.0000e-04
# Epoch 227/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.7039e-05 - rmse: 0.0093 - val_loss: 0.0031 - val_rmse: 0.0558 - lr: 1.0000e-04
# Epoch 228/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.5636e-05 - rmse: 0.0093 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 1.0000e-04
# Epoch 229/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.8792e-05 - rmse: 0.0099 - val_loss: 0.0030 - val_rmse: 0.0552 - lr: 1.0000e-04
# Epoch 230/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2042e-04 - rmse: 0.0110 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 1.0000e-04
# Epoch 231/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2920e-04 - rmse: 0.0114 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 1.0000e-04
# Epoch 232/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0102e-04 - rmse: 0.0142 - val_loss: 0.0035 - val_rmse: 0.0589 - lr: 1.0000e-04
# Epoch 233/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9519e-04 - rmse: 0.0140 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 1.0000e-04
# Epoch 234/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6265e-04 - rmse: 0.0128 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 1.0000e-04
# Epoch 235/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6053e-04 - rmse: 0.0127 - val_loss: 0.0033 - val_rmse: 0.0572 - lr: 1.0000e-04
# Epoch 236/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3047e-04 - rmse: 0.0114 - val_loss: 0.0030 - val_rmse: 0.0551 - lr: 1.0000e-04
# Epoch 237/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1771e-04 - rmse: 0.0108 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 1.0000e-04
# Epoch 238/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2788e-04 - rmse: 0.0113 - val_loss: 0.0035 - val_rmse: 0.0595 - lr: 1.0000e-04
# Epoch 239/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3829e-04 - rmse: 0.0118 - val_loss: 0.0029 - val_rmse: 0.0534 - lr: 1.0000e-04
# Epoch 240/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8879e-04 - rmse: 0.0137 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 1.0000e-04
# Epoch 241/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8412e-04 - rmse: 0.0169 - val_loss: 0.0038 - val_rmse: 0.0615 - lr: 1.0000e-04
# Epoch 242/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7405e-04 - rmse: 0.0132 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 1.0000e-04
# Epoch 243/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1289e-04 - rmse: 0.0106 - val_loss: 0.0033 - val_rmse: 0.0571 - lr: 1.0000e-04
# Epoch 244/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4533e-04 - rmse: 0.0121 - val_loss: 0.0028 - val_rmse: 0.0531 - lr: 1.0000e-04
# Epoch 245/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0242e-04 - rmse: 0.0101 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 1.0000e-04
# Epoch 246/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0653e-04 - rmse: 0.0103 - val_loss: 0.0029 - val_rmse: 0.0541 - lr: 1.0000e-04
# Epoch 247/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.5435e-05 - rmse: 0.0098 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 1.0000e-04
# Epoch 248/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1268e-04 - rmse: 0.0106 - val_loss: 0.0027 - val_rmse: 0.0522 - lr: 1.0000e-04
# Epoch 249/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.4959e-04 - rmse: 0.0122 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 1.0000e-04
# Epoch 250/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.0229e-04 - rmse: 0.0101 - val_loss: 0.0031 - val_rmse: 0.0557 - lr: 1.0000e-04
# Epoch 251/10000
# 5/5 [==============================] - ETA: 0s - loss: 1.8104e-04 - rmse: 0.0135
# Epoch 251: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 5/5 [==============================] - 0s 22ms/step - loss: 1.8104e-04 - rmse: 0.0135 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 1.0000e-04
# Epoch 252/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1505e-04 - rmse: 0.0107 - val_loss: 0.0030 - val_rmse: 0.0548 - lr: 5.0000e-05
# Epoch 253/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1454e-04 - rmse: 0.0107 - val_loss: 0.0032 - val_rmse: 0.0569 - lr: 5.0000e-05
# Epoch 254/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.7661e-05 - rmse: 0.0088 - val_loss: 0.0031 - val_rmse: 0.0557 - lr: 5.0000e-05
# Epoch 255/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.6435e-05 - rmse: 0.0093 - val_loss: 0.0033 - val_rmse: 0.0573 - lr: 5.0000e-05
# Epoch 256/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0176e-04 - rmse: 0.0101 - val_loss: 0.0033 - val_rmse: 0.0571 - lr: 5.0000e-05
# Epoch 257/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 9.0126e-05 - rmse: 0.0095 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 5.0000e-05
# Epoch 258/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.5708e-05 - rmse: 0.0087 - val_loss: 0.0033 - val_rmse: 0.0574 - lr: 5.0000e-05
# Epoch 259/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.6171e-05 - rmse: 0.0093 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 260/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.2245e-05 - rmse: 0.0079 - val_loss: 0.0032 - val_rmse: 0.0569 - lr: 5.0000e-05
# Epoch 261/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.4432e-05 - rmse: 0.0080 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 5.0000e-05
# Epoch 262/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.5307e-05 - rmse: 0.0087 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 5.0000e-05
# Epoch 263/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.4533e-05 - rmse: 0.0086 - val_loss: 0.0032 - val_rmse: 0.0565 - lr: 5.0000e-05
# Epoch 264/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.1214e-05 - rmse: 0.0078 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 5.0000e-05
# Epoch 265/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.6742e-05 - rmse: 0.0082 - val_loss: 0.0033 - val_rmse: 0.0574 - lr: 5.0000e-05
# Epoch 266/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.0474e-05 - rmse: 0.0078 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 5.0000e-05
# Epoch 267/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.4145e-05 - rmse: 0.0080 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 5.0000e-05
# Epoch 268/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.1684e-05 - rmse: 0.0085 - val_loss: 0.0032 - val_rmse: 0.0569 - lr: 5.0000e-05
# Epoch 269/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.8858e-05 - rmse: 0.0083 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 270/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.7769e-05 - rmse: 0.0076 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 5.0000e-05
# Epoch 271/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.6938e-05 - rmse: 0.0075 - val_loss: 0.0033 - val_rmse: 0.0575 - lr: 5.0000e-05
# Epoch 272/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.5212e-05 - rmse: 0.0081 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 5.0000e-05
# Epoch 273/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.2664e-05 - rmse: 0.0079 - val_loss: 0.0033 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 274/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.4306e-05 - rmse: 0.0080 - val_loss: 0.0032 - val_rmse: 0.0568 - lr: 5.0000e-05
# Epoch 275/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.6164e-05 - rmse: 0.0075 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 5.0000e-05
# Epoch 276/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.5278e-05 - rmse: 0.0087 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 5.0000e-05
# Epoch 277/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.5274e-05 - rmse: 0.0081 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 5.0000e-05
# Epoch 278/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.7797e-05 - rmse: 0.0082 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 5.0000e-05
# Epoch 279/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.6090e-05 - rmse: 0.0081 - val_loss: 0.0032 - val_rmse: 0.0565 - lr: 5.0000e-05
# Epoch 280/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.5659e-05 - rmse: 0.0075 - val_loss: 0.0033 - val_rmse: 0.0571 - lr: 5.0000e-05
# Epoch 281/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.0124e-05 - rmse: 0.0078 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 5.0000e-05
# Epoch 282/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.2889e-05 - rmse: 0.0073 - val_loss: 0.0032 - val_rmse: 0.0568 - lr: 5.0000e-05
# Epoch 283/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3481e-05 - rmse: 0.0073 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 5.0000e-05
# Epoch 284/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4873e-05 - rmse: 0.0074 - val_loss: 0.0032 - val_rmse: 0.0568 - lr: 5.0000e-05
# Epoch 285/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.2624e-05 - rmse: 0.0079 - val_loss: 0.0032 - val_rmse: 0.0567 - lr: 5.0000e-05
# Epoch 286/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9107e-05 - rmse: 0.0070 - val_loss: 0.0033 - val_rmse: 0.0572 - lr: 5.0000e-05
# Epoch 287/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8749e-05 - rmse: 0.0070 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 5.0000e-05
# Epoch 288/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8303e-05 - rmse: 0.0070 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 5.0000e-05
# Epoch 289/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.7813e-05 - rmse: 0.0076 - val_loss: 0.0032 - val_rmse: 0.0570 - lr: 5.0000e-05
# Epoch 290/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.6306e-05 - rmse: 0.0081 - val_loss: 0.0033 - val_rmse: 0.0571 - lr: 5.0000e-05
# Epoch 291/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.1075e-05 - rmse: 0.0078 - val_loss: 0.0033 - val_rmse: 0.0574 - lr: 5.0000e-05
# Epoch 292/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.3186e-05 - rmse: 0.0073 - val_loss: 0.0031 - val_rmse: 0.0559 - lr: 5.0000e-05
# Epoch 293/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.9151e-05 - rmse: 0.0077 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 5.0000e-05
# Epoch 294/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.3898e-05 - rmse: 0.0073 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 5.0000e-05
# Epoch 295/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6450e-05 - rmse: 0.0068 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 5.0000e-05
# Epoch 296/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6912e-05 - rmse: 0.0068 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 5.0000e-05
# Epoch 297/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.1088e-05 - rmse: 0.0078 - val_loss: 0.0033 - val_rmse: 0.0571 - lr: 5.0000e-05
# Epoch 298/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3648e-05 - rmse: 0.0080 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 5.0000e-05
# Epoch 299/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.3161e-05 - rmse: 0.0079 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 5.0000e-05
# Epoch 300/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.0023e-05 - rmse: 0.0077 - val_loss: 0.0030 - val_rmse: 0.0552 - lr: 5.0000e-05
# Epoch 301/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.4274e-05 - rmse: 0.0074 - val_loss: 0.0033 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 302/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.6233e-05 - rmse: 0.0075 - val_loss: 0.0032 - val_rmse: 0.0565 - lr: 5.0000e-05
# Epoch 303/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.6770e-05 - rmse: 0.0082 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 5.0000e-05
# Epoch 304/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.9353e-05 - rmse: 0.0095 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 5.0000e-05
# Epoch 305/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.5503e-05 - rmse: 0.0092 - val_loss: 0.0032 - val_rmse: 0.0565 - lr: 5.0000e-05
# Epoch 306/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.7687e-05 - rmse: 0.0082 - val_loss: 0.0033 - val_rmse: 0.0575 - lr: 5.0000e-05
# Epoch 307/10000
# ...
# Epoch 952/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8986e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 953/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9716e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 954/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8337e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 955/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7019e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 956/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7048e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 957/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6316e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 958/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9229e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 959/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.3942e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 960/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.1970e-06 - rmse: 0.0023 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 961/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7635e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 962/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7478e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 963/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8952e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 964/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7699e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 965/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9295e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 966/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8903e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 967/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7625e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 968/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.9568e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 969/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7501e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 970/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7479e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 971/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7233e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 972/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.0338e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 973/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9857e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 974/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7518e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 975/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6676e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 976/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8817e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 977/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7752e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 978/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8963e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 979/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.0570e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0560 - lr: 6.2500e-06
# Epoch 980/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7842e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 981/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9162e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 982/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6859e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 983/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.1326e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 984/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9129e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 985/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9098e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 986/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8988e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 987/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8276e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 988/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0311e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 989/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7089e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 990/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6288e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 991/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7107e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 992/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9739e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 993/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6096e-06 - rmse: 0.0021 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 994/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.8149e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 995/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7228e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 996/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.9348e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 997/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7856e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 998/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8547e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 999/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7936e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 1000/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.5795e-06 - rmse: 0.0021 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1001/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.5516e-06 - rmse: 0.0021 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 1002/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8259e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 1003/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9821e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 1004/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.0200e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1005/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9536e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1006/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.4998e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1007/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.5718e-06 - rmse: 0.0024 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1008/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.2502e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1009/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.1246e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1010/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.3699e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1011/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9801e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 1012/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.3422e-06 - rmse: 0.0023 - val_loss: 0.0031 - val_rmse: 0.0559 - lr: 6.2500e-06
# Epoch 1013/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.5348e-06 - rmse: 0.0024 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 1014/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.2783e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1015/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.4294e-06 - rmse: 0.0023 - val_loss: 0.0031 - val_rmse: 0.0560 - lr: 6.2500e-06
# Epoch 1016/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0032e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1017/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.2419e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1018/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.4074e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 1019/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.5633e-06 - rmse: 0.0024 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1020/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0016e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 1021/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.1121e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1022/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6750e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 1023/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8582e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1024/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6609e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 1025/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9022e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 1026/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.0540e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 1027/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9664e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1028/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0346e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1029/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8522e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1030/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.0827e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 1031/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9485e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1032/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.0790e-06 - rmse: 0.0023 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1033/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6800e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1034/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6431e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1035/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.5072e-06 - rmse: 0.0021 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1036/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.5920e-06 - rmse: 0.0021 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1037/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0009e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1038/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7351e-06 - rmse: 0.0022 - val_loss: 0.0031 - val_rmse: 0.0560 - lr: 6.2500e-06
# Epoch 1039/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.5296e-06 - rmse: 0.0021 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1040/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8195e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1041/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.6403e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1042/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7034e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 1043/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8629e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1044/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8566e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1045/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.6035e-06 - rmse: 0.0021 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1046/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.8115e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1047/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.9310e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1048/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.9264e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 6.2500e-06
# Epoch 1049/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7624e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 6.2500e-06
# Epoch 1050/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.1086e-06 - rmse: 0.0023 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 1051/10000
# 5/5 [==============================] - ETA: 0s - loss: 4.8612e-06 - rmse: 0.0022Restoring model weights from the end of the best epoch: 51.
#
# Epoch 1051: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 5/5 [==============================] - 0s 23ms/step - loss: 4.8612e-06 - rmse: 0.0022 - val_loss: 0.0032 - val_rmse: 0.0561 - lr: 6.2500e-06
# Epoch 1051: early stopping

# %%
time = end - start
print("Training time:", time)
# Out:
# Training time: 0:01:50.459767

# %%
storage_dir = "D:\\VAWT_data\\flap_steady\\flap_steady\\result\\"+"20221130AeroCNN2_optimalSettings\\test"+str(test_rate)+"Cdonly"
if not os.path.exists(storage_dir):
    os.makedirs(storage_dir)
os.chdir(storage_dir)

# %%
hist = history.history
plt.plot(hist['loss'], lw=2, label='Training loss')
plt.plot(hist['val_loss'], lw=2, label='Validation loss')
plt.title('Training loss (mean squared error)\nAeroCNN-II, optimal settings, $C_d$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.yscale('log')
#plt.ylim([5e-5, 1e-1])
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()
plt.legend(loc='upper right')
saveName = "TrainingLoss_test"+str(test_rate) + ".jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(hist['rmse'], lw=2)
plt.plot(hist['val_rmse'], lw=2)
plt.title('Root Mean Squared Error, optimal settings, $C_d$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.show()

# %%
plt.plot(hist['rmse'], lw=2, label='Training RMSE')
plt.plot(hist['val_loss'], lw=2, label='Validation RMSE')
plt.title('Root Mean Squared Error\nAeroCNN-II, optimal settings, $C_d$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()
plt.legend(loc='upper right')
saveName = "RMSE_test"+str(test_rate) + ".jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
train_results = model.evaluate(x_train, y_train)
# Out:
# 4/4 [==============================] - 0s 26ms/step - loss: 5.3072e-04 - rmse: 0.0230

# %%
test_results = model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0017 - rmse: 0.0413

# %%
decoded_train_ = model.predict(x_train)
decoded_val_ = model.predict(x_val)
decoded_test_ = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
index_train = np.unique(np.where(np.isin(cd, y_train)))
index_val = np.unique(np.where(np.isin(cd, y_val)))
index_test = np.unique(np.where(np.isin(cd, y_test)))

# %%
y_train = y_train*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
y_val = y_val*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
y_test = y_test*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)

# %%
decoded_train = decoded_train_*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
decoded_val = decoded_val_*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
decoded_test = decoded_test_*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)

# %%
model_directory = "D:\\TrainedModels\\20221130"
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
os.chdir(model_directory)
model_name = "20221130steadyValidation_AeroCNN2_val_"+str(val_rate)+"_test"+str(test_rate)+ "_" + str(n_units) +"units_optimalSettings_Cdonly.h5"
model.save(model_name, overwrite=True, include_optimizer=True, save_format='h5')

# %%
error_train_abs = np.abs(decoded_train - y_train)

# %%
error_test_abs = np.abs(decoded_test - y_test)

# %%
os.chdir(storage_dir)

# %%
l2_error_train = np.sqrt(np.sum((decoded_train - y_train)**2) / np.sum(y_train**2))
print(l2_error_train)
# Out:
# 0.046274316797928844

# %%
l2_error_val = np.sqrt(np.sum((decoded_val - y_val)**2) / np.sum(y_val**2))
print(l2_error_val)
# Out:
# 0.11928630991212817

# %%
l2_error_test = np.sqrt(np.sum((decoded_test - y_test)**2) / np.sum(y_test**2))
print(l2_error_test)
# Out:
# 0.09608148070576754

# %%
l2_error_train_list = []
for i in range(0, len(x_train)):
    l2_error_train_data = np.sqrt(np.sum((decoded_train[i] - y_train[i])**2) / np.sum(y_train[i]**2))
    l2_error_train_list.append(l2_error_train_data)

# %%
l2_error_val_list = []
for i in range(0, len(x_val)):
    l2_error_val_data = np.sqrt(np.sum((decoded_val[i] - y_val[i])**2) / np.sum((y_val[i]+1e-07)**2))
    l2_error_val_list.append(l2_error_val_data)

# %%
l2_error_test_list = []
for i in range(0, len(x_test)):
    l2_error_test_data = np.sqrt(np.sum((decoded_test[i] - y_test[i])**2) / np.sum(y_test[i]**2))
    l2_error_test_list.append(l2_error_test_data)

# %%
plt.plot(np.linspace(1,x_train.shape[0],x_train.shape[0]),
         l2_error_train*np.ones(x_train.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_train.shape[0], x_train.shape[0]), l2_error_train_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, training\nValidation rate {0}, test rate {1}, optimal settings ($C_d$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "trainingErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(np.linspace(1,x_val.shape[0],x_val.shape[0]),
         l2_error_val*np.ones(x_val.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_val.shape[0], x_val.shape[0]), l2_error_val_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, validation\nValidation rate {0}, test rate {1}, optimal settings ($C_d$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "validationErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(np.linspace(1,x_test.shape[0],x_test.shape[0]),
         l2_error_test*np.ones(x_test.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_test.shape[0], x_test.shape[0]), l2_error_test_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, test\nValidation rate {0}, test rate {1}, optimal settings ($C_d$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "testErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
predicted = model.predict(x)
# Out:
# 5/5 [==============================] - 0s 63ms/step

# %%
def CD_trainTestSplit_Plot(i, CD, cd, aTrain, aTest, iTrain, iTest):
    
    title_0_Cd = 'Gurney flap not attached (NACA0018)\n$C_D$ prediction, L2 error=%.4f' % l2_error_Cd
    #title_0_Cl = 'Gurney flap not attached (NACA0018)\n$C_L$ prediction, L2 error=%.4f' % l2_error_Cl
    
    title_n_Cd = 'Gurney flap attached h=%.2f, '%(h[i]) + r'$\beta$=%d'%(beta[i])+'\n$C_D$ prediction, L2 error=%.4f'%(l2_error_Cd)
    #title_n_Cl = 'Gurney flap attached h=%.2f, '%(h[i]) + r'$\beta$=%d'%(beta[i])+'\n$C_L$ prediction, L2 error=%.4f'%(l2_error_Cl)
    
    if i==0:
#         title_Cd, title_Cl = title_0_Cd, title_0_Cl
#         savename1,savename2 = "CdComparison_NACA0018.jpg", "ClComparison_NACA0018.jpg"
        title_Cd = title_0_Cd
        savename1 = "CdComparison_NACA0018.jpg"
    else:
#         title_Cd, title_Cl = title_n_Cd, title_n_Cl
        title_Cd = title_n_Cd
        savename1 = "CdComparison_h"+str(h[i])+"_beta"+str(beta[i])+".jpg"
#         savename2 = "ClComparison_h"+str(h[i])+"_beta"+str(beta[i])+".jpg"
    
    # CD graph plot
    plt.plot(alpha, CD, 'k-', label='Ground truth')
    plt.plot(alpha, cd, 'k--', label='Predicted value')
    plt.scatter(aTrain, iTrain, color='b', label='Training set')
    plt.scatter(aVal, iVal, color='g', label='Validation set')
    plt.scatter(aTest, iTest, color='r', label='Test set')
    plt.xlabel('AoA (degree)')
    plt.ylabel('$C_D$')
    plt.title(title_Cd, fontsize=15)        
    plt.legend(loc='upper left')
    plt.ylim([0, 0.12])
    plt.grid()
    plt.savefig(savename1, dpi=300, bbox_inches='tight', pad_inches=0.3)
    plt.show()

    '''# CL graph plot
    plt.plot(alpha, CL, 'k-', label='Ground truth')
    plt.plot(alpha, cl, 'k--', label='Predicted value')
    plt.scatter(aTrain, iTrain[:,1]*(np.max(cl_orig)-np.min(cl_orig)) + np.min(cl_orig), color='b', label='Training set')
    plt.scatter(aTest, iTest[:,1]*(np.max(cl_orig)-np.min(cl_orig)) + np.min(cl_orig), color='r', label='Test set')
    plt.xlabel('AoA (degree)')
    plt.ylabel('$C_L$')
    plt.title(title_Cl, fontsize=15)
    plt.legend(loc='upper left')
    plt.ylim([0, 2])
    plt.grid()
    plt.savefig(savename2, dpi=300, bbox_inches='tight', pad_inches=0.3)
    plt.show()'''

# %%
h = [0, 0.01, 0.01, 0.01, 0.01, 0.01, 0.02, 0.02, 0.02, 0.02, 0.02, 0.03, 0.03, 0.03, 0.03, 0.03]
beta = [0, 30, 45, 60, 75, 90, 30, 45, 60, 75, 90, 30, 45, 60, 75, 90]
for i in range(0, 16):
    # Index from each dataset
    iTrain = []
    iVal = []
    iTest = []
    
    # Index from input data (alpha, in this case)
    alpha_train = []
    alpha_val = []
    alpha_test = []
    
    predictedValue = model.predict(x[n_alpha*i:n_alpha*(i+1),:])
    y_corres = y[n_alpha*i:n_alpha*(i+1),:]
    
    l2_error_Cd = np.sqrt(np.sum((predictedValue - y_corres)**2) / np.sum(y_corres**2))
    
    if i==0:
        print('NACA0018 airfoil without Gurney flap\nL2 error of Cd: {0:0.4f}'.format(l2_error_Cd))
    else:
        print('L2 error of Cd: {0:0.4f}'.format(l2_error_Cd))
    
    cd = predicted[n_alpha*i:n_alpha*(i+1)]*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    CD = y[n_alpha*i:n_alpha*(i+1)]*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    
    for ii, index in enumerate(index_train[np.where((index_train<(i+1)*n_alpha) & ((index_train>=i*n_alpha)))]):
        iTrain.append(predicted[index])
    for kk, index in enumerate(index_val[np.where((index_val<(i+1)*n_alpha) & ((index_val>=i*n_alpha)))]):
        iVal.append(predicted[index])    
    for jj, index in enumerate(index_test[np.where((index_test<(i+1)*n_alpha) & (index_test>=i*n_alpha))]):
        iTest.append(predicted[index])
        
    iTrain = np.array(iTrain)*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    iTest = np.array(iTest)*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    iVal = np.array(iVal)*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    
    for ii, index in enumerate(index_train[np.where((index_train<(i+1)*n_alpha) & ((index_train>=i*n_alpha)))]):
        alpha_train.append(aa[index])
    for kk, index in enumerate(index_val[np.where((index_val<(i+1)*n_alpha) & ((index_val>=i*n_alpha)))]):
        alpha_val.append(aa[index])
    for jj, index in enumerate(index_test[np.where((index_test<(i+1)*n_alpha) & ((index_test>=i*n_alpha)))]):
        alpha_test.append(aa[index])
        
    aTrain = np.array(alpha_train)*np.max(alpha)
    aVal = np.array(alpha_val)*np.max(alpha)
    aTest = np.array(alpha_test)*np.max(alpha)
    
    CD_trainTestSplit_Plot(i, CD, cd, aTrain, aTest, iTrain, iTest)
# Out:
# 1/1 [==============================] - 0s 150ms/step
# NACA0018 airfoil without Gurney flap
# L2 error of Cd: 0.1393
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.1121
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0656
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0485
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0545
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0958
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0349
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0622
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0889
# 1/1 [==============================] - 0s 14ms/step
# L2 error of Cd: 0.0505
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.1828
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.1037
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0752
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0379
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0805
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.2300
