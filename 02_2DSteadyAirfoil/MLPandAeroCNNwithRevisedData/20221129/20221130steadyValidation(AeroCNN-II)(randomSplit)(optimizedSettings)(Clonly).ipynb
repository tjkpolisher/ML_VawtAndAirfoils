# %%
# Validation of the steady-state simulation - Case 3: AeroCNN-II
import os
import sys
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import datetime
# %matplotlib inline

# %%
### Defining parameters and hyperparameters of the model

n_kernels=200 # Number of kernels in convolutional network
kernel_size1=3
strides=1
n_units=128 # Number of units in the hidden layer of the MLP network
input_size = 100 # Size of input for the network (100 coefficients and 3 other parameters, AoA, h, beta)
lr = 1e-04 # Learning rate of the network
test_rate=0.1 # Defines the ratio of training dataset and test dataset
val_rate=0.2
n_data = 16 # Number of txt files from which the aerodynamic coefficients are extracted
batch_size = 20 # Mini-batch size

# %%
# Changing working directory

main_directory = 'D:\\VAWT_data\\flap_steady\\flap_steady'
os.chdir(main_directory)

# %%
## Basic parameters

c = 1 # Chord length
h = np.array([0.01, 0.02, 0.03]) * c # Height of the Gurney flaps
t = 0.02 * h # Thickness of the Gurney flaps
alpha = np.linspace(0, 16, 9).reshape((9,1)) # Angles of attack
beta = np.linspace(30, 90, 5).reshape((5,1))

h = h.reshape((-1,1))
t = t.reshape((-1,1))

# %%
n_alpha = alpha.shape[0] # Number of the angles of attack
n_beta = beta.shape[0] # Number of the Gurney flap inclination
n_h = h.shape[0] # Number of the height of the Gurney flaps
n_cases = n_data * n_alpha
aa_ = np.zeros((n_cases,1))
for i in range(0, n_data):
    aa_[n_alpha*i:n_alpha*(i+1),:] = alpha[:,:]
    
aa = aa_ / np.max(alpha)

# %%
h = h.reshape((-1,1))
t = t.reshape((-1,1))

# %%
n_alpha = alpha.shape[0] # Number of the angles of attack
n_beta = beta.shape[0] # Number of the Gurney flap inclination
n_h = h.shape[0] # Number of the height of the Gurney flaps
n_cases = n_data * n_alpha # Total number of cases(Number of geometries * Number of angles of attack)

# %%
## Creating input dataset - mask
mask_dir = main_directory + '\\aeroCNN2Mask'
os.chdir(mask_dir)
mask_list = os.listdir(mask_dir)
mask_target = [file for file in mask_list if file.endswith('.csv')]

# %%
mask_df = pd.DataFrame()
for file in mask_target:
    data = pd.read_csv(file, header=None)
    mask_df = pd.concat([mask_df, data], axis=0)

# %%
x = mask_df.iloc[:,:].values

# %%
x_alligned = np.zeros((x.shape[0],x.shape[1]))
for i in range(0,144*2):
    if i%2==0:
        x_alligned[i*100:(i+1)*100,:] = x[i*100:(i+1)*100,:]
    else:
        x_alligned[i*100:(i+1)*100,:] = x[i*100:(i+1)*100,:].T

# %%
x = x_alligned.reshape((16*9,2,input_size,input_size))

# %%
## Creating output dataset - Cl and Cd
files_orig = os.listdir(main_directory)
files_target = [file for file in files_orig if file.endswith('.txt')]
os.chdir(main_directory)

# %%
target_df = pd.DataFrame()
for file in files_target:
    data = pd.read_table(file, header=None)
    target_df = pd.concat([target_df, data], axis=0)

# %%
cl_orig = target_df.iloc[:,4].values # Cd values
#target_c4 = target_df.iloc[:,4].values# Cl values

# %%
cl = (cl_orig-np.min(cl_orig))/(np.max(cl_orig)-np.min(cl_orig))

# %%
y = cl.reshape((-1,1))

# %%
x_all, x_test, y_all, y_test = train_test_split(x, y, test_size=test_rate, random_state=1)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_all, y_all, test_size=val_rate/(1-test_rate), random_state=1)

# %%
x_train.shape
# Out:
# (100, 2, 100, 100)

# %%
y_train.shape
# Out:
# (100, 1)

# %%
tf.keras.backend.set_image_data_format('channels_first')

# %%
input_image = tf.keras.Input(shape=(2, input_size, input_size))

x_conv1 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(input_image)
x1_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv1)
x_conv2 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x1_)
x2_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv2)
x_conv3 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x2_)
x3_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv3)
x_conv4 = tf.keras.layers.Conv2D(1, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x3_)
x4_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv4)
x_flat = tf.keras.layers.Flatten()(x4_)
x_fc1 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc1')(x_flat)
x_fc2 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc2')(x_fc1)
x_fc3 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc3')(x_fc2)
x_fc4 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc4')(x_fc3)
x_fc5 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc5')(x_fc4)

output_data = tf.keras.layers.Dense(units=1, activation='linear', name='outputLayer')(x_fc5)
# AeroCNN-II based
model = tf.keras.Model(input_image, output_data)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2, 100, 100)]     0
#
#  conv2d (Conv2D)             (None, 200, 100, 100)     3800
#
#  max_pooling2d (MaxPooling2D  (None, 200, 50, 50)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 200, 50, 50)       360200
#
#  max_pooling2d_1 (MaxPooling  (None, 200, 25, 25)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 200, 25, 25)       360200
#
#  max_pooling2d_2 (MaxPooling  (None, 200, 12, 12)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 1, 12, 12)         1801
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 6, 6)          0
#  2D)
#
#  flatten (Flatten)           (None, 36)                0
#
#  fc1 (Dense)                 (None, 128)               4736
#
#  fc2 (Dense)                 (None, 128)               16512
#
#  fc3 (Dense)                 (None, 128)               16512
#
#  fc4 (Dense)                 (None, 128)               16512
#
#  fc5 (Dense)                 (None, 128)               16512
#
#  outputLayer (Dense)         (None, 1)                 129
#
# =================================================================
# Total params: 796,914
# Trainable params: 796,914
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
              loss = tf.keras.losses.MeanSquaredError(),
              metrics=[tf.keras.metrics.RootMeanSquaredError(name="rmse")])

# %%
model_directory = "D:\\TrainedModels\\20221130"
if not os.path.exists(model_directory):
    os.makedirs(model_directory)

# %%
# ckpt_name = model_directory + "\\20221130steadyValidation_AeroCNN2_val_"+str(val_rate) + "_test"+str(test_rate)+ "_" + str(n_units) +"units_OptimalSettings_Clcheckpoint.h5"

# ckpt = tf.keras.callbacks.ModelCheckpoint(ckpt_name, monitor="val_loss", mode='min', verbose=1, save_best_only=True)

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=1000, min_delta=6e-7,
                                      restore_best_weights=True, verbose=1)
rp = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=200, factor=0.5,
                                          min_delta = 1e-09, min_lr=1e-06, verbose=1)

# %%
STEP_SIZE_TRAIN = len(x_train)//batch_size
VALIDATION_STEPS = len(x_val)//batch_size

# %%
start = datetime.datetime.now()
history = model.fit(x_train, y_train, batch_size=batch_size,
                    validation_data=(x_val, y_val),
                    steps_per_epoch = STEP_SIZE_TRAIN, validation_steps=VALIDATION_STEPS,
                    epochs=10000, shuffle=True, callbacks=[es, rp])
end = datetime.datetime.now()
# Out:
# Epoch 1/10000
# 5/5 [==============================] - 4s 70ms/step - loss: 0.4455 - rmse: 0.6675 - val_loss: 0.3482 - val_rmse: 0.5901 - lr: 1.0000e-04
# Epoch 2/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1953 - rmse: 0.4419 - val_loss: 0.0462 - val_rmse: 0.2150 - lr: 1.0000e-04
# Epoch 3/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1028 - rmse: 0.3206 - val_loss: 0.0332 - val_rmse: 0.1821 - lr: 1.0000e-04
# Epoch 4/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0289 - rmse: 0.1701 - val_loss: 0.0406 - val_rmse: 0.2014 - lr: 1.0000e-04
# Epoch 5/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0321 - rmse: 0.1792 - val_loss: 0.0203 - val_rmse: 0.1426 - lr: 1.0000e-04
# Epoch 6/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0142 - rmse: 0.1191 - val_loss: 0.0140 - val_rmse: 0.1182 - lr: 1.0000e-04
# Epoch 7/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0128 - rmse: 0.1132 - val_loss: 0.0120 - val_rmse: 0.1097 - lr: 1.0000e-04
# Epoch 8/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0116 - rmse: 0.1075 - val_loss: 0.0126 - val_rmse: 0.1122 - lr: 1.0000e-04
# Epoch 9/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0091 - rmse: 0.0956 - val_loss: 0.0108 - val_rmse: 0.1041 - lr: 1.0000e-04
# Epoch 10/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0083 - rmse: 0.0913 - val_loss: 0.0098 - val_rmse: 0.0992 - lr: 1.0000e-04
# Epoch 11/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0072 - rmse: 0.0847 - val_loss: 0.0089 - val_rmse: 0.0944 - lr: 1.0000e-04
# Epoch 12/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0071 - rmse: 0.0844 - val_loss: 0.0082 - val_rmse: 0.0908 - lr: 1.0000e-04
# Epoch 13/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0063 - rmse: 0.0792 - val_loss: 0.0080 - val_rmse: 0.0893 - lr: 1.0000e-04
# Epoch 14/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0060 - rmse: 0.0775 - val_loss: 0.0078 - val_rmse: 0.0885 - lr: 1.0000e-04
# Epoch 15/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0054 - rmse: 0.0738 - val_loss: 0.0079 - val_rmse: 0.0891 - lr: 1.0000e-04
# Epoch 16/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0053 - rmse: 0.0729 - val_loss: 0.0074 - val_rmse: 0.0863 - lr: 1.0000e-04
# Epoch 17/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0050 - rmse: 0.0708 - val_loss: 0.0068 - val_rmse: 0.0825 - lr: 1.0000e-04
# Epoch 18/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0045 - rmse: 0.0672 - val_loss: 0.0066 - val_rmse: 0.0815 - lr: 1.0000e-04
# Epoch 19/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0044 - rmse: 0.0665 - val_loss: 0.0067 - val_rmse: 0.0817 - lr: 1.0000e-04
# Epoch 20/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0040 - rmse: 0.0632 - val_loss: 0.0064 - val_rmse: 0.0797 - lr: 1.0000e-04
# Epoch 21/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0040 - rmse: 0.0631 - val_loss: 0.0063 - val_rmse: 0.0793 - lr: 1.0000e-04
# Epoch 22/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0036 - rmse: 0.0604 - val_loss: 0.0064 - val_rmse: 0.0803 - lr: 1.0000e-04
# Epoch 23/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0037 - rmse: 0.0606 - val_loss: 0.0062 - val_rmse: 0.0784 - lr: 1.0000e-04
# Epoch 24/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0036 - rmse: 0.0603 - val_loss: 0.0060 - val_rmse: 0.0772 - lr: 1.0000e-04
# Epoch 25/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0033 - rmse: 0.0577 - val_loss: 0.0060 - val_rmse: 0.0772 - lr: 1.0000e-04
# Epoch 26/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0032 - rmse: 0.0565 - val_loss: 0.0062 - val_rmse: 0.0787 - lr: 1.0000e-04
# Epoch 27/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0029 - rmse: 0.0538 - val_loss: 0.0058 - val_rmse: 0.0760 - lr: 1.0000e-04
# Epoch 28/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0031 - rmse: 0.0555 - val_loss: 0.0054 - val_rmse: 0.0735 - lr: 1.0000e-04
# Epoch 29/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0027 - rmse: 0.0521 - val_loss: 0.0056 - val_rmse: 0.0748 - lr: 1.0000e-04
# Epoch 30/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0028 - rmse: 0.0532 - val_loss: 0.0057 - val_rmse: 0.0758 - lr: 1.0000e-04
# Epoch 31/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0026 - rmse: 0.0514 - val_loss: 0.0056 - val_rmse: 0.0745 - lr: 1.0000e-04
# Epoch 32/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0026 - rmse: 0.0512 - val_loss: 0.0053 - val_rmse: 0.0726 - lr: 1.0000e-04
# Epoch 33/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0023 - rmse: 0.0477 - val_loss: 0.0058 - val_rmse: 0.0760 - lr: 1.0000e-04
# Epoch 34/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0024 - rmse: 0.0486 - val_loss: 0.0056 - val_rmse: 0.0749 - lr: 1.0000e-04
# Epoch 35/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0023 - rmse: 0.0480 - val_loss: 0.0054 - val_rmse: 0.0733 - lr: 1.0000e-04
# Epoch 36/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0020 - rmse: 0.0450 - val_loss: 0.0055 - val_rmse: 0.0740 - lr: 1.0000e-04
# Epoch 37/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0020 - rmse: 0.0445 - val_loss: 0.0057 - val_rmse: 0.0757 - lr: 1.0000e-04
# Epoch 38/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0020 - rmse: 0.0445 - val_loss: 0.0057 - val_rmse: 0.0754 - lr: 1.0000e-04
# Epoch 39/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0018 - rmse: 0.0428 - val_loss: 0.0056 - val_rmse: 0.0746 - lr: 1.0000e-04
# Epoch 40/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0021 - rmse: 0.0459 - val_loss: 0.0055 - val_rmse: 0.0743 - lr: 1.0000e-04
# Epoch 41/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0021 - rmse: 0.0463 - val_loss: 0.0062 - val_rmse: 0.0788 - lr: 1.0000e-04
# Epoch 42/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0018 - rmse: 0.0419 - val_loss: 0.0056 - val_rmse: 0.0750 - lr: 1.0000e-04
# Epoch 43/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0018 - rmse: 0.0429 - val_loss: 0.0051 - val_rmse: 0.0715 - lr: 1.0000e-04
# Epoch 44/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0017 - rmse: 0.0417 - val_loss: 0.0056 - val_rmse: 0.0746 - lr: 1.0000e-04
# Epoch 45/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0017 - rmse: 0.0409 - val_loss: 0.0058 - val_rmse: 0.0764 - lr: 1.0000e-04
# Epoch 46/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0017 - rmse: 0.0418 - val_loss: 0.0058 - val_rmse: 0.0765 - lr: 1.0000e-04
# Epoch 47/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0015 - rmse: 0.0389 - val_loss: 0.0053 - val_rmse: 0.0731 - lr: 1.0000e-04
# Epoch 48/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0016 - rmse: 0.0406 - val_loss: 0.0055 - val_rmse: 0.0742 - lr: 1.0000e-04
# Epoch 49/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0016 - rmse: 0.0396 - val_loss: 0.0058 - val_rmse: 0.0764 - lr: 1.0000e-04
# Epoch 50/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0015 - rmse: 0.0392 - val_loss: 0.0064 - val_rmse: 0.0797 - lr: 1.0000e-04
# Epoch 51/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0018 - rmse: 0.0423 - val_loss: 0.0057 - val_rmse: 0.0757 - lr: 1.0000e-04
# Epoch 52/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0016 - rmse: 0.0396 - val_loss: 0.0057 - val_rmse: 0.0758 - lr: 1.0000e-04
# Epoch 53/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0017 - rmse: 0.0408 - val_loss: 0.0056 - val_rmse: 0.0745 - lr: 1.0000e-04
# Epoch 54/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0014 - rmse: 0.0371 - val_loss: 0.0054 - val_rmse: 0.0735 - lr: 1.0000e-04
# Epoch 55/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0014 - rmse: 0.0377 - val_loss: 0.0057 - val_rmse: 0.0753 - lr: 1.0000e-04
# Epoch 56/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0017 - rmse: 0.0413 - val_loss: 0.0060 - val_rmse: 0.0774 - lr: 1.0000e-04
# Epoch 57/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0013 - rmse: 0.0354 - val_loss: 0.0065 - val_rmse: 0.0808 - lr: 1.0000e-04
# Epoch 58/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0014 - rmse: 0.0371 - val_loss: 0.0055 - val_rmse: 0.0743 - lr: 1.0000e-04
# Epoch 59/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0012 - rmse: 0.0346 - val_loss: 0.0059 - val_rmse: 0.0771 - lr: 1.0000e-04
# Epoch 60/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0012 - rmse: 0.0341 - val_loss: 0.0060 - val_rmse: 0.0774 - lr: 1.0000e-04
# Epoch 61/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0011 - rmse: 0.0326 - val_loss: 0.0059 - val_rmse: 0.0771 - lr: 1.0000e-04
# Epoch 62/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0012 - rmse: 0.0351 - val_loss: 0.0062 - val_rmse: 0.0789 - lr: 1.0000e-04
# Epoch 63/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0337 - val_loss: 0.0061 - val_rmse: 0.0783 - lr: 1.0000e-04
# Epoch 64/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0013 - rmse: 0.0355 - val_loss: 0.0060 - val_rmse: 0.0771 - lr: 1.0000e-04
# Epoch 65/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0011 - rmse: 0.0336 - val_loss: 0.0063 - val_rmse: 0.0795 - lr: 1.0000e-04
# Epoch 66/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0013 - rmse: 0.0355 - val_loss: 0.0059 - val_rmse: 0.0767 - lr: 1.0000e-04
# Epoch 67/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0012 - rmse: 0.0345 - val_loss: 0.0057 - val_rmse: 0.0756 - lr: 1.0000e-04
# Epoch 68/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0018 - rmse: 0.0423 - val_loss: 0.0068 - val_rmse: 0.0825 - lr: 1.0000e-04
# Epoch 69/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0018 - rmse: 0.0419 - val_loss: 0.0072 - val_rmse: 0.0851 - lr: 1.0000e-04
# Epoch 70/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0015 - rmse: 0.0392 - val_loss: 0.0077 - val_rmse: 0.0875 - lr: 1.0000e-04
# Epoch 71/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0021 - rmse: 0.0462 - val_loss: 0.0074 - val_rmse: 0.0859 - lr: 1.0000e-04
# Epoch 72/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0022 - rmse: 0.0469 - val_loss: 0.0063 - val_rmse: 0.0795 - lr: 1.0000e-04
# Epoch 73/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0019 - rmse: 0.0440 - val_loss: 0.0061 - val_rmse: 0.0780 - lr: 1.0000e-04
# Epoch 74/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0021 - rmse: 0.0458 - val_loss: 0.0090 - val_rmse: 0.0949 - lr: 1.0000e-04
# Epoch 75/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0016 - rmse: 0.0394 - val_loss: 0.0060 - val_rmse: 0.0777 - lr: 1.0000e-04
# Epoch 76/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0016 - rmse: 0.0398 - val_loss: 0.0058 - val_rmse: 0.0760 - lr: 1.0000e-04
# Epoch 77/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0015 - rmse: 0.0385 - val_loss: 0.0055 - val_rmse: 0.0740 - lr: 1.0000e-04
# Epoch 78/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0011 - rmse: 0.0329 - val_loss: 0.0059 - val_rmse: 0.0770 - lr: 1.0000e-04
# Epoch 79/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0015 - rmse: 0.0388 - val_loss: 0.0081 - val_rmse: 0.0897 - lr: 1.0000e-04
# Epoch 80/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0015 - rmse: 0.0386 - val_loss: 0.0069 - val_rmse: 0.0828 - lr: 1.0000e-04
# Epoch 81/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0010 - rmse: 0.0324 - val_loss: 0.0066 - val_rmse: 0.0814 - lr: 1.0000e-04
# Epoch 82/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0013 - rmse: 0.0366 - val_loss: 0.0053 - val_rmse: 0.0729 - lr: 1.0000e-04
# Epoch 83/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0010 - rmse: 0.0321 - val_loss: 0.0055 - val_rmse: 0.0740 - lr: 1.0000e-04
# Epoch 84/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0012 - rmse: 0.0346 - val_loss: 0.0076 - val_rmse: 0.0870 - lr: 1.0000e-04
# Epoch 85/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 9.4823e-04 - rmse: 0.0308 - val_loss: 0.0065 - val_rmse: 0.0805 - lr: 1.0000e-04
# Epoch 86/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.5082e-04 - rmse: 0.0308 - val_loss: 0.0070 - val_rmse: 0.0837 - lr: 1.0000e-04
# Epoch 87/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0012 - rmse: 0.0348 - val_loss: 0.0065 - val_rmse: 0.0806 - lr: 1.0000e-04
# Epoch 88/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0010 - rmse: 0.0323 - val_loss: 0.0062 - val_rmse: 0.0788 - lr: 1.0000e-04
# Epoch 89/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.0204e-04 - rmse: 0.0283 - val_loss: 0.0063 - val_rmse: 0.0795 - lr: 1.0000e-04
# Epoch 90/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.9705e-04 - rmse: 0.0282 - val_loss: 0.0063 - val_rmse: 0.0791 - lr: 1.0000e-04
# Epoch 91/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.8690e-04 - rmse: 0.0298 - val_loss: 0.0069 - val_rmse: 0.0832 - lr: 1.0000e-04
# Epoch 92/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.0079e-04 - rmse: 0.0300 - val_loss: 0.0063 - val_rmse: 0.0792 - lr: 1.0000e-04
# Epoch 93/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.4825e-04 - rmse: 0.0291 - val_loss: 0.0067 - val_rmse: 0.0818 - lr: 1.0000e-04
# Epoch 94/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0012 - rmse: 0.0347 - val_loss: 0.0063 - val_rmse: 0.0792 - lr: 1.0000e-04
# Epoch 95/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0331 - val_loss: 0.0062 - val_rmse: 0.0788 - lr: 1.0000e-04
# Epoch 96/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0013 - rmse: 0.0359 - val_loss: 0.0075 - val_rmse: 0.0866 - lr: 1.0000e-04
# Epoch 97/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0015 - rmse: 0.0387 - val_loss: 0.0068 - val_rmse: 0.0827 - lr: 1.0000e-04
# Epoch 98/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0324 - val_loss: 0.0072 - val_rmse: 0.0849 - lr: 1.0000e-04
# Epoch 99/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0017 - rmse: 0.0415 - val_loss: 0.0068 - val_rmse: 0.0825 - lr: 1.0000e-04
# Epoch 100/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0337 - val_loss: 0.0084 - val_rmse: 0.0918 - lr: 1.0000e-04
# Epoch 101/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0015 - rmse: 0.0387 - val_loss: 0.0060 - val_rmse: 0.0774 - lr: 1.0000e-04
# Epoch 102/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.8483e-04 - rmse: 0.0297 - val_loss: 0.0059 - val_rmse: 0.0768 - lr: 1.0000e-04
# Epoch 103/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0013 - rmse: 0.0367 - val_loss: 0.0063 - val_rmse: 0.0794 - lr: 1.0000e-04
# Epoch 104/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.8116e-04 - rmse: 0.0297 - val_loss: 0.0056 - val_rmse: 0.0745 - lr: 1.0000e-04
# Epoch 105/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.2839e-04 - rmse: 0.0288 - val_loss: 0.0060 - val_rmse: 0.0774 - lr: 1.0000e-04
# Epoch 106/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.6760e-04 - rmse: 0.0295 - val_loss: 0.0060 - val_rmse: 0.0773 - lr: 1.0000e-04
# Epoch 107/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.4959e-04 - rmse: 0.0274 - val_loss: 0.0064 - val_rmse: 0.0801 - lr: 1.0000e-04
# Epoch 108/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.3617e-04 - rmse: 0.0289 - val_loss: 0.0063 - val_rmse: 0.0792 - lr: 1.0000e-04
# Epoch 109/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3427e-04 - rmse: 0.0252 - val_loss: 0.0065 - val_rmse: 0.0809 - lr: 1.0000e-04
# Epoch 110/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.0096e-04 - rmse: 0.0265 - val_loss: 0.0063 - val_rmse: 0.0796 - lr: 1.0000e-04
# Epoch 111/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.7713e-04 - rmse: 0.0240 - val_loss: 0.0065 - val_rmse: 0.0809 - lr: 1.0000e-04
# Epoch 112/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9433e-04 - rmse: 0.0244 - val_loss: 0.0064 - val_rmse: 0.0797 - lr: 1.0000e-04
# Epoch 113/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.8502e-04 - rmse: 0.0262 - val_loss: 0.0069 - val_rmse: 0.0828 - lr: 1.0000e-04
# Epoch 114/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.5566e-04 - rmse: 0.0275 - val_loss: 0.0065 - val_rmse: 0.0805 - lr: 1.0000e-04
# Epoch 115/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3531e-04 - rmse: 0.0252 - val_loss: 0.0067 - val_rmse: 0.0816 - lr: 1.0000e-04
# Epoch 116/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3505e-04 - rmse: 0.0231 - val_loss: 0.0066 - val_rmse: 0.0813 - lr: 1.0000e-04
# Epoch 117/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.9336e-04 - rmse: 0.0263 - val_loss: 0.0068 - val_rmse: 0.0827 - lr: 1.0000e-04
# Epoch 118/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.6453e-04 - rmse: 0.0238 - val_loss: 0.0066 - val_rmse: 0.0814 - lr: 1.0000e-04
# Epoch 119/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.7932e-04 - rmse: 0.0241 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 1.0000e-04
# Epoch 120/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7770e-04 - rmse: 0.0219 - val_loss: 0.0068 - val_rmse: 0.0824 - lr: 1.0000e-04
# Epoch 121/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3432e-04 - rmse: 0.0231 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 1.0000e-04
# Epoch 122/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.8016e-04 - rmse: 0.0261 - val_loss: 0.0064 - val_rmse: 0.0801 - lr: 1.0000e-04
# Epoch 123/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0010 - rmse: 0.0317 - val_loss: 0.0069 - val_rmse: 0.0830 - lr: 1.0000e-04
# Epoch 124/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.6950e-04 - rmse: 0.0259 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 1.0000e-04
# Epoch 125/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.6906e-04 - rmse: 0.0239 - val_loss: 0.0062 - val_rmse: 0.0787 - lr: 1.0000e-04
# Epoch 126/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9913e-04 - rmse: 0.0245 - val_loss: 0.0070 - val_rmse: 0.0834 - lr: 1.0000e-04
# Epoch 127/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.7025e-04 - rmse: 0.0278 - val_loss: 0.0065 - val_rmse: 0.0804 - lr: 1.0000e-04
# Epoch 128/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.6050e-04 - rmse: 0.0257 - val_loss: 0.0064 - val_rmse: 0.0800 - lr: 1.0000e-04
# Epoch 129/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9295e-04 - rmse: 0.0244 - val_loss: 0.0073 - val_rmse: 0.0853 - lr: 1.0000e-04
# Epoch 130/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.8471e-04 - rmse: 0.0262 - val_loss: 0.0069 - val_rmse: 0.0831 - lr: 1.0000e-04
# Epoch 131/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.6725e-04 - rmse: 0.0258 - val_loss: 0.0063 - val_rmse: 0.0792 - lr: 1.0000e-04
# Epoch 132/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.1691e-04 - rmse: 0.0248 - val_loss: 0.0070 - val_rmse: 0.0836 - lr: 1.0000e-04
# Epoch 133/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3164e-04 - rmse: 0.0231 - val_loss: 0.0068 - val_rmse: 0.0824 - lr: 1.0000e-04
# Epoch 134/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.7532e-04 - rmse: 0.0260 - val_loss: 0.0069 - val_rmse: 0.0832 - lr: 1.0000e-04
# Epoch 135/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.9945e-04 - rmse: 0.0264 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 1.0000e-04
# Epoch 136/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.1243e-04 - rmse: 0.0267 - val_loss: 0.0067 - val_rmse: 0.0816 - lr: 1.0000e-04
# Epoch 137/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.1359e-04 - rmse: 0.0267 - val_loss: 0.0068 - val_rmse: 0.0825 - lr: 1.0000e-04
# Epoch 138/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.4662e-04 - rmse: 0.0291 - val_loss: 0.0076 - val_rmse: 0.0869 - lr: 1.0000e-04
# Epoch 139/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0013 - rmse: 0.0359 - val_loss: 0.0067 - val_rmse: 0.0816 - lr: 1.0000e-04
# Epoch 140/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3902e-04 - rmse: 0.0253 - val_loss: 0.0067 - val_rmse: 0.0819 - lr: 1.0000e-04
# Epoch 141/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.2610e-04 - rmse: 0.0304 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 1.0000e-04
# Epoch 142/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.8475e-04 - rmse: 0.0297 - val_loss: 0.0070 - val_rmse: 0.0836 - lr: 1.0000e-04
# Epoch 143/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0338 - val_loss: 0.0069 - val_rmse: 0.0831 - lr: 1.0000e-04
# Epoch 144/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0010 - rmse: 0.0317 - val_loss: 0.0067 - val_rmse: 0.0820 - lr: 1.0000e-04
# Epoch 145/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0010 - rmse: 0.0321 - val_loss: 0.0067 - val_rmse: 0.0818 - lr: 1.0000e-04
# Epoch 146/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.7760e-04 - rmse: 0.0279 - val_loss: 0.0073 - val_rmse: 0.0853 - lr: 1.0000e-04
# Epoch 147/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.7760e-04 - rmse: 0.0296 - val_loss: 0.0077 - val_rmse: 0.0879 - lr: 1.0000e-04
# Epoch 148/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3662e-04 - rmse: 0.0252 - val_loss: 0.0067 - val_rmse: 0.0817 - lr: 1.0000e-04
# Epoch 149/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9799e-04 - rmse: 0.0245 - val_loss: 0.0065 - val_rmse: 0.0805 - lr: 1.0000e-04
# Epoch 150/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.6154e-04 - rmse: 0.0215 - val_loss: 0.0072 - val_rmse: 0.0848 - lr: 1.0000e-04
# Epoch 151/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.5960e-04 - rmse: 0.0237 - val_loss: 0.0068 - val_rmse: 0.0823 - lr: 1.0000e-04
# Epoch 152/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.2567e-04 - rmse: 0.0250 - val_loss: 0.0066 - val_rmse: 0.0814 - lr: 1.0000e-04
# Epoch 153/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0010 - rmse: 0.0320 - val_loss: 0.0083 - val_rmse: 0.0909 - lr: 1.0000e-04
# Epoch 154/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.4641e-04 - rmse: 0.0254 - val_loss: 0.0068 - val_rmse: 0.0826 - lr: 1.0000e-04
# Epoch 155/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.8763e-04 - rmse: 0.0262 - val_loss: 0.0063 - val_rmse: 0.0795 - lr: 1.0000e-04
# Epoch 156/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.2730e-04 - rmse: 0.0250 - val_loss: 0.0073 - val_rmse: 0.0852 - lr: 1.0000e-04
# Epoch 157/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.2457e-04 - rmse: 0.0229 - val_loss: 0.0074 - val_rmse: 0.0858 - lr: 1.0000e-04
# Epoch 158/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.7275e-04 - rmse: 0.0259 - val_loss: 0.0069 - val_rmse: 0.0829 - lr: 1.0000e-04
# Epoch 159/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9307e-04 - rmse: 0.0244 - val_loss: 0.0070 - val_rmse: 0.0838 - lr: 1.0000e-04
# Epoch 160/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.0911e-04 - rmse: 0.0247 - val_loss: 0.0069 - val_rmse: 0.0833 - lr: 1.0000e-04
# Epoch 161/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.4980e-04 - rmse: 0.0255 - val_loss: 0.0069 - val_rmse: 0.0829 - lr: 1.0000e-04
# Epoch 162/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.4044e-04 - rmse: 0.0210 - val_loss: 0.0066 - val_rmse: 0.0811 - lr: 1.0000e-04
# Epoch 163/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.5298e-04 - rmse: 0.0213 - val_loss: 0.0066 - val_rmse: 0.0813 - lr: 1.0000e-04
# Epoch 164/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.0643e-04 - rmse: 0.0202 - val_loss: 0.0067 - val_rmse: 0.0818 - lr: 1.0000e-04
# Epoch 165/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.4274e-04 - rmse: 0.0210 - val_loss: 0.0067 - val_rmse: 0.0821 - lr: 1.0000e-04
# Epoch 166/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9032e-04 - rmse: 0.0243 - val_loss: 0.0075 - val_rmse: 0.0864 - lr: 1.0000e-04
# Epoch 167/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.7631e-04 - rmse: 0.0240 - val_loss: 0.0072 - val_rmse: 0.0850 - lr: 1.0000e-04
# Epoch 168/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4578e-04 - rmse: 0.0234 - val_loss: 0.0063 - val_rmse: 0.0796 - lr: 1.0000e-04
# Epoch 169/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.9899e-04 - rmse: 0.0264 - val_loss: 0.0068 - val_rmse: 0.0822 - lr: 1.0000e-04
# Epoch 170/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4245e-04 - rmse: 0.0233 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 1.0000e-04
# Epoch 171/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.5526e-04 - rmse: 0.0275 - val_loss: 0.0073 - val_rmse: 0.0854 - lr: 1.0000e-04
# Epoch 172/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.6066e-04 - rmse: 0.0276 - val_loss: 0.0078 - val_rmse: 0.0884 - lr: 1.0000e-04
# Epoch 173/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7831e-04 - rmse: 0.0219 - val_loss: 0.0068 - val_rmse: 0.0823 - lr: 1.0000e-04
# Epoch 174/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.8955e-04 - rmse: 0.0243 - val_loss: 0.0066 - val_rmse: 0.0815 - lr: 1.0000e-04
# Epoch 175/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.7564e-04 - rmse: 0.0296 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 1.0000e-04
# Epoch 176/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.5342e-04 - rmse: 0.0235 - val_loss: 0.0066 - val_rmse: 0.0814 - lr: 1.0000e-04
# Epoch 177/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3039e-04 - rmse: 0.0230 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 1.0000e-04
# Epoch 178/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0995e-04 - rmse: 0.0226 - val_loss: 0.0072 - val_rmse: 0.0850 - lr: 1.0000e-04
# Epoch 179/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.9733e-04 - rmse: 0.0264 - val_loss: 0.0066 - val_rmse: 0.0811 - lr: 1.0000e-04
# Epoch 180/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.4588e-04 - rmse: 0.0254 - val_loss: 0.0070 - val_rmse: 0.0838 - lr: 1.0000e-04
# Epoch 181/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.6483e-04 - rmse: 0.0216 - val_loss: 0.0069 - val_rmse: 0.0830 - lr: 1.0000e-04
# Epoch 182/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.4018e-04 - rmse: 0.0210 - val_loss: 0.0069 - val_rmse: 0.0829 - lr: 1.0000e-04
# Epoch 183/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.5622e-04 - rmse: 0.0236 - val_loss: 0.0074 - val_rmse: 0.0858 - lr: 1.0000e-04
# Epoch 184/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.3932e-04 - rmse: 0.0272 - val_loss: 0.0074 - val_rmse: 0.0861 - lr: 1.0000e-04
# Epoch 185/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.2146e-04 - rmse: 0.0269 - val_loss: 0.0072 - val_rmse: 0.0846 - lr: 1.0000e-04
# Epoch 186/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.7731e-04 - rmse: 0.0260 - val_loss: 0.0070 - val_rmse: 0.0837 - lr: 1.0000e-04
# Epoch 187/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.1253e-04 - rmse: 0.0247 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 1.0000e-04
# Epoch 188/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.1406e-04 - rmse: 0.0248 - val_loss: 0.0062 - val_rmse: 0.0788 - lr: 1.0000e-04
# Epoch 189/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0427e-04 - rmse: 0.0225 - val_loss: 0.0067 - val_rmse: 0.0819 - lr: 1.0000e-04
# Epoch 190/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3226e-04 - rmse: 0.0231 - val_loss: 0.0070 - val_rmse: 0.0835 - lr: 1.0000e-04
# Epoch 191/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.0477e-04 - rmse: 0.0201 - val_loss: 0.0066 - val_rmse: 0.0815 - lr: 1.0000e-04
# Epoch 192/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.9196e-04 - rmse: 0.0222 - val_loss: 0.0067 - val_rmse: 0.0819 - lr: 1.0000e-04
# Epoch 193/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.2704e-04 - rmse: 0.0207 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 1.0000e-04
# Epoch 194/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.6135e-04 - rmse: 0.0215 - val_loss: 0.0068 - val_rmse: 0.0823 - lr: 1.0000e-04
# Epoch 195/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4441e-04 - rmse: 0.0233 - val_loss: 0.0068 - val_rmse: 0.0827 - lr: 1.0000e-04
# Epoch 196/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7568e-04 - rmse: 0.0218 - val_loss: 0.0070 - val_rmse: 0.0834 - lr: 1.0000e-04
# Epoch 197/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0348e-04 - rmse: 0.0224 - val_loss: 0.0068 - val_rmse: 0.0823 - lr: 1.0000e-04
# Epoch 198/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.8750e-04 - rmse: 0.0221 - val_loss: 0.0068 - val_rmse: 0.0822 - lr: 1.0000e-04
# Epoch 199/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.8817e-04 - rmse: 0.0243 - val_loss: 0.0069 - val_rmse: 0.0830 - lr: 1.0000e-04
# Epoch 200/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.1292e-04 - rmse: 0.0226 - val_loss: 0.0069 - val_rmse: 0.0832 - lr: 1.0000e-04
# Epoch 201/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.2120e-04 - rmse: 0.0228 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 1.0000e-04
# Epoch 202/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.2675e-04 - rmse: 0.0304 - val_loss: 0.0069 - val_rmse: 0.0829 - lr: 1.0000e-04
# Epoch 203/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0010 - rmse: 0.0318 - val_loss: 0.0067 - val_rmse: 0.0819 - lr: 1.0000e-04
# Epoch 204/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.9670e-04 - rmse: 0.0299 - val_loss: 0.0074 - val_rmse: 0.0859 - lr: 1.0000e-04
# Epoch 205/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.0090e-04 - rmse: 0.0300 - val_loss: 0.0076 - val_rmse: 0.0869 - lr: 1.0000e-04
# Epoch 206/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.6311e-04 - rmse: 0.0310 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 1.0000e-04
# Epoch 207/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.4482e-04 - rmse: 0.0291 - val_loss: 0.0060 - val_rmse: 0.0773 - lr: 1.0000e-04
# Epoch 208/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.5645e-04 - rmse: 0.0256 - val_loss: 0.0071 - val_rmse: 0.0840 - lr: 1.0000e-04
# Epoch 209/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.4628e-04 - rmse: 0.0254 - val_loss: 0.0066 - val_rmse: 0.0814 - lr: 1.0000e-04
# Epoch 210/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.1478e-04 - rmse: 0.0267 - val_loss: 0.0072 - val_rmse: 0.0847 - lr: 1.0000e-04
# Epoch 211/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.9893e-04 - rmse: 0.0283 - val_loss: 0.0065 - val_rmse: 0.0804 - lr: 1.0000e-04
# Epoch 212/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0328 - val_loss: 0.0070 - val_rmse: 0.0836 - lr: 1.0000e-04
# Epoch 213/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.9233e-04 - rmse: 0.0299 - val_loss: 0.0072 - val_rmse: 0.0846 - lr: 1.0000e-04
# Epoch 214/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0012 - rmse: 0.0350 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 1.0000e-04
# Epoch 215/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.8288e-04 - rmse: 0.0314 - val_loss: 0.0073 - val_rmse: 0.0857 - lr: 1.0000e-04
# Epoch 216/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.8603e-04 - rmse: 0.0314 - val_loss: 0.0081 - val_rmse: 0.0899 - lr: 1.0000e-04
# Epoch 217/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.2160e-04 - rmse: 0.0287 - val_loss: 0.0065 - val_rmse: 0.0803 - lr: 1.0000e-04
# Epoch 218/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.8919e-04 - rmse: 0.0281 - val_loss: 0.0063 - val_rmse: 0.0795 - lr: 1.0000e-04
# Epoch 219/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.1619e-04 - rmse: 0.0268 - val_loss: 0.0062 - val_rmse: 0.0789 - lr: 1.0000e-04
# Epoch 220/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.2405e-04 - rmse: 0.0229 - val_loss: 0.0068 - val_rmse: 0.0826 - lr: 1.0000e-04
# Epoch 221/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3930e-04 - rmse: 0.0253 - val_loss: 0.0066 - val_rmse: 0.0810 - lr: 1.0000e-04
# Epoch 222/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.4706e-04 - rmse: 0.0273 - val_loss: 0.0063 - val_rmse: 0.0791 - lr: 1.0000e-04
# Epoch 223/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.8394e-04 - rmse: 0.0297 - val_loss: 0.0083 - val_rmse: 0.0909 - lr: 1.0000e-04
# Epoch 224/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0013 - rmse: 0.0359 - val_loss: 0.0072 - val_rmse: 0.0849 - lr: 1.0000e-04
# Epoch 225/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0012 - rmse: 0.0343 - val_loss: 0.0067 - val_rmse: 0.0821 - lr: 1.0000e-04
# Epoch 226/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0014 - rmse: 0.0367 - val_loss: 0.0091 - val_rmse: 0.0956 - lr: 1.0000e-04
# Epoch 227/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0015 - rmse: 0.0388 - val_loss: 0.0057 - val_rmse: 0.0757 - lr: 1.0000e-04
# Epoch 228/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.5003e-04 - rmse: 0.0292 - val_loss: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-04
# Epoch 229/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.3893e-04 - rmse: 0.0290 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 1.0000e-04
# Epoch 230/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3235e-04 - rmse: 0.0251 - val_loss: 0.0073 - val_rmse: 0.0852 - lr: 1.0000e-04
# Epoch 231/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.3268e-04 - rmse: 0.0289 - val_loss: 0.0067 - val_rmse: 0.0818 - lr: 1.0000e-04
# Epoch 232/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.2977e-04 - rmse: 0.0270 - val_loss: 0.0070 - val_rmse: 0.0835 - lr: 1.0000e-04
# Epoch 233/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.8583e-04 - rmse: 0.0262 - val_loss: 0.0073 - val_rmse: 0.0856 - lr: 1.0000e-04
# Epoch 234/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0817e-04 - rmse: 0.0225 - val_loss: 0.0065 - val_rmse: 0.0807 - lr: 1.0000e-04
# Epoch 235/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4558e-04 - rmse: 0.0234 - val_loss: 0.0069 - val_rmse: 0.0829 - lr: 1.0000e-04
# Epoch 236/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.6865e-04 - rmse: 0.0277 - val_loss: 0.0064 - val_rmse: 0.0802 - lr: 1.0000e-04
# Epoch 237/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.6047e-04 - rmse: 0.0276 - val_loss: 0.0067 - val_rmse: 0.0820 - lr: 1.0000e-04
# Epoch 238/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.5302e-04 - rmse: 0.0235 - val_loss: 0.0069 - val_rmse: 0.0829 - lr: 1.0000e-04
# Epoch 239/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.3320e-04 - rmse: 0.0208 - val_loss: 0.0063 - val_rmse: 0.0791 - lr: 1.0000e-04
# Epoch 240/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.2906e-04 - rmse: 0.0207 - val_loss: 0.0063 - val_rmse: 0.0792 - lr: 1.0000e-04
# Epoch 241/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.1712e-04 - rmse: 0.0204 - val_loss: 0.0066 - val_rmse: 0.0813 - lr: 1.0000e-04
# Epoch 242/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.6447e-04 - rmse: 0.0216 - val_loss: 0.0067 - val_rmse: 0.0819 - lr: 1.0000e-04
# Epoch 243/10000
# 5/5 [==============================] - ETA: 0s - loss: 3.5888e-04 - rmse: 0.0189
# Epoch 243: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 5/5 [==============================] - 0s 21ms/step - loss: 3.5888e-04 - rmse: 0.0189 - val_loss: 0.0067 - val_rmse: 0.0816 - lr: 1.0000e-04
# Epoch 244/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.9715e-04 - rmse: 0.0199 - val_loss: 0.0069 - val_rmse: 0.0833 - lr: 5.0000e-05
# Epoch 245/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.6793e-04 - rmse: 0.0192 - val_loss: 0.0066 - val_rmse: 0.0813 - lr: 5.0000e-05
# Epoch 246/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.2435e-04 - rmse: 0.0180 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 5.0000e-05
# Epoch 247/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.4109e-04 - rmse: 0.0185 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 5.0000e-05
# Epoch 248/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.8392e-04 - rmse: 0.0168 - val_loss: 0.0067 - val_rmse: 0.0816 - lr: 5.0000e-05
# Epoch 249/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.1728e-04 - rmse: 0.0178 - val_loss: 0.0065 - val_rmse: 0.0807 - lr: 5.0000e-05
# Epoch 250/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7662e-04 - rmse: 0.0166 - val_loss: 0.0066 - val_rmse: 0.0809 - lr: 5.0000e-05
# Epoch 251/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5557e-04 - rmse: 0.0160 - val_loss: 0.0066 - val_rmse: 0.0811 - lr: 5.0000e-05
# Epoch 252/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4605e-04 - rmse: 0.0157 - val_loss: 0.0064 - val_rmse: 0.0802 - lr: 5.0000e-05
# Epoch 253/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6100e-04 - rmse: 0.0162 - val_loss: 0.0064 - val_rmse: 0.0800 - lr: 5.0000e-05
# Epoch 254/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7433e-04 - rmse: 0.0166 - val_loss: 0.0064 - val_rmse: 0.0800 - lr: 5.0000e-05
# Epoch 255/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4566e-04 - rmse: 0.0157 - val_loss: 0.0066 - val_rmse: 0.0810 - lr: 5.0000e-05
# Epoch 256/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4045e-04 - rmse: 0.0155 - val_loss: 0.0067 - val_rmse: 0.0819 - lr: 5.0000e-05
# Epoch 257/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4772e-04 - rmse: 0.0157 - val_loss: 0.0066 - val_rmse: 0.0810 - lr: 5.0000e-05
# Epoch 258/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9128e-04 - rmse: 0.0171 - val_loss: 0.0065 - val_rmse: 0.0805 - lr: 5.0000e-05
# Epoch 259/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.4086e-04 - rmse: 0.0185 - val_loss: 0.0066 - val_rmse: 0.0810 - lr: 5.0000e-05
# Epoch 260/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7692e-04 - rmse: 0.0166 - val_loss: 0.0067 - val_rmse: 0.0817 - lr: 5.0000e-05
# Epoch 261/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7747e-04 - rmse: 0.0167 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 5.0000e-05
# Epoch 262/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.1185e-04 - rmse: 0.0177 - val_loss: 0.0067 - val_rmse: 0.0816 - lr: 5.0000e-05
# Epoch 263/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5079e-04 - rmse: 0.0158 - val_loss: 0.0065 - val_rmse: 0.0807 - lr: 5.0000e-05
# Epoch 264/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8659e-04 - rmse: 0.0169 - val_loss: 0.0065 - val_rmse: 0.0809 - lr: 5.0000e-05
# Epoch 265/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4481e-04 - rmse: 0.0156 - val_loss: 0.0067 - val_rmse: 0.0820 - lr: 5.0000e-05
# Epoch 266/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7449e-04 - rmse: 0.0166 - val_loss: 0.0066 - val_rmse: 0.0811 - lr: 5.0000e-05
# Epoch 267/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9265e-04 - rmse: 0.0171 - val_loss: 0.0067 - val_rmse: 0.0817 - lr: 5.0000e-05
# Epoch 268/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7205e-04 - rmse: 0.0165 - val_loss: 0.0067 - val_rmse: 0.0818 - lr: 5.0000e-05
# Epoch 269/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6630e-04 - rmse: 0.0163 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 5.0000e-05
# Epoch 270/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4718e-04 - rmse: 0.0157 - val_loss: 0.0064 - val_rmse: 0.0800 - lr: 5.0000e-05
# Epoch 271/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6818e-04 - rmse: 0.0164 - val_loss: 0.0067 - val_rmse: 0.0819 - lr: 5.0000e-05
# Epoch 272/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6594e-04 - rmse: 0.0163 - val_loss: 0.0067 - val_rmse: 0.0818 - lr: 5.0000e-05
# Epoch 273/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3973e-04 - rmse: 0.0155 - val_loss: 0.0065 - val_rmse: 0.0805 - lr: 5.0000e-05
# Epoch 274/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8005e-04 - rmse: 0.0167 - val_loss: 0.0066 - val_rmse: 0.0813 - lr: 5.0000e-05
# Epoch 275/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0068e-04 - rmse: 0.0173 - val_loss: 0.0066 - val_rmse: 0.0814 - lr: 5.0000e-05
# Epoch 276/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6611e-04 - rmse: 0.0163 - val_loss: 0.0068 - val_rmse: 0.0822 - lr: 5.0000e-05
# Epoch 277/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3070e-04 - rmse: 0.0152 - val_loss: 0.0067 - val_rmse: 0.0819 - lr: 5.0000e-05
# Epoch 278/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8724e-04 - rmse: 0.0169 - val_loss: 0.0065 - val_rmse: 0.0805 - lr: 5.0000e-05
# Epoch 279/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4142e-04 - rmse: 0.0155 - val_loss: 0.0065 - val_rmse: 0.0806 - lr: 5.0000e-05
# Epoch 280/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5778e-04 - rmse: 0.0161 - val_loss: 0.0068 - val_rmse: 0.0823 - lr: 5.0000e-05
# Epoch 281/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.3111e-04 - rmse: 0.0182 - val_loss: 0.0069 - val_rmse: 0.0831 - lr: 5.0000e-05
# Epoch 282/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.7072e-04 - rmse: 0.0193 - val_loss: 0.0066 - val_rmse: 0.0810 - lr: 5.0000e-05
# Epoch 283/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.2114e-04 - rmse: 0.0179 - val_loss: 0.0065 - val_rmse: 0.0809 - lr: 5.0000e-05
# Epoch 284/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5649e-04 - rmse: 0.0160 - val_loss: 0.0065 - val_rmse: 0.0809 - lr: 5.0000e-05
# Epoch 285/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9556e-04 - rmse: 0.0172 - val_loss: 0.0067 - val_rmse: 0.0816 - lr: 5.0000e-05
# Epoch 286/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5045e-04 - rmse: 0.0158 - val_loss: 0.0067 - val_rmse: 0.0816 - lr: 5.0000e-05
# Epoch 287/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5580e-04 - rmse: 0.0160 - val_loss: 0.0066 - val_rmse: 0.0814 - lr: 5.0000e-05
# Epoch 288/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5374e-04 - rmse: 0.0159 - val_loss: 0.0066 - val_rmse: 0.0813 - lr: 5.0000e-05
# Epoch 289/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6001e-04 - rmse: 0.0161 - val_loss: 0.0065 - val_rmse: 0.0809 - lr: 5.0000e-05
# Epoch 290/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.4137e-04 - rmse: 0.0185 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 5.0000e-05
# Epoch 291/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8048e-04 - rmse: 0.0167 - val_loss: 0.0066 - val_rmse: 0.0815 - lr: 5.0000e-05
# Epoch 292/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0553e-04 - rmse: 0.0175 - val_loss: 0.0067 - val_rmse: 0.0818 - lr: 5.0000e-05
# Epoch 293/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6426e-04 - rmse: 0.0163 - val_loss: 0.0065 - val_rmse: 0.0807 - lr: 5.0000e-05
# Epoch 294/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7005e-04 - rmse: 0.0164 - val_loss: 0.0066 - val_rmse: 0.0811 - lr: 5.0000e-05
# Epoch 295/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1247e-04 - rmse: 0.0146 - val_loss: 0.0069 - val_rmse: 0.0830 - lr: 5.0000e-05
# Epoch 296/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7179e-04 - rmse: 0.0165 - val_loss: 0.0066 - val_rmse: 0.0814 - lr: 5.0000e-05
# Epoch 297/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4186e-04 - rmse: 0.0156 - val_loss: 0.0064 - val_rmse: 0.0803 - lr: 5.0000e-05
# Epoch 298/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0027e-04 - rmse: 0.0173 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 5.0000e-05
# Epoch 299/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8241e-04 - rmse: 0.0168 - val_loss: 0.0069 - val_rmse: 0.0829 - lr: 5.0000e-05
# Epoch 300/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6829e-04 - rmse: 0.0164 - val_loss: 0.0066 - val_rmse: 0.0815 - lr: 5.0000e-05
# Epoch 301/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4410e-04 - rmse: 0.0156 - val_loss: 0.0065 - val_rmse: 0.0804 - lr: 5.0000e-05
# Epoch 302/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4844e-04 - rmse: 0.0158 - val_loss: 0.0068 - val_rmse: 0.0823 - lr: 5.0000e-05
# Epoch 303/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4045e-04 - rmse: 0.0155 - val_loss: 0.0066 - val_rmse: 0.0811 - lr: 5.0000e-05
# Epoch 304/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1955e-04 - rmse: 0.0148 - val_loss: 0.0067 - val_rmse: 0.0816 - lr: 5.0000e-05
# Epoch 305/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3196e-04 - rmse: 0.0152 - val_loss: 0.0065 - val_rmse: 0.0804 - lr: 5.0000e-05
# Epoch 306/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4611e-04 - rmse: 0.0157 - val_loss: 0.0065 - val_rmse: 0.0808 - lr: 5.0000e-05
# Epoch 307/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9543e-04 - rmse: 0.0172 - val_loss: 0.0068 - val_rmse: 0.0822 - lr: 5.0000e-05
# Epoch 308/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9810e-04 - rmse: 0.0173 - val_loss: 0.0069 - val_rmse: 0.0829 - lr: 5.0000e-05
# Epoch 309/10000
# ...
# Epoch 944/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5666e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 945/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5165e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 946/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5963e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0840 - lr: 6.2500e-06
# Epoch 947/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.5504e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 948/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.5631e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 949/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6923e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 950/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8762e-05 - rmse: 0.0054 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 951/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.6644e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 952/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.6879e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 953/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5935e-05 - rmse: 0.0051 - val_loss: 0.0070 - val_rmse: 0.0839 - lr: 6.2500e-06
# Epoch 954/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6836e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 955/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.5447e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 956/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5692e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 957/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4846e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 958/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6457e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 959/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.6758e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 960/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.7131e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 961/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6635e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0840 - lr: 6.2500e-06
# Epoch 962/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6975e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 963/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8606e-05 - rmse: 0.0053 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 964/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6526e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 965/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.8512e-05 - rmse: 0.0053 - val_loss: 0.0072 - val_rmse: 0.0848 - lr: 6.2500e-06
# Epoch 966/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6509e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 967/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.7141e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0840 - lr: 6.2500e-06
# Epoch 968/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.7557e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 969/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7287e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 970/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8001e-05 - rmse: 0.0053 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 971/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6483e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 972/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.5350e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 973/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6899e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 974/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7866e-05 - rmse: 0.0053 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 975/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9922e-05 - rmse: 0.0055 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 976/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9347e-05 - rmse: 0.0054 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 977/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7019e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 978/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6713e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 979/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8059e-05 - rmse: 0.0053 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 980/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8787e-05 - rmse: 0.0054 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 981/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6442e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 982/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.6022e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 983/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5657e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 984/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.5465e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 985/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5670e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 986/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7108e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 987/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7180e-05 - rmse: 0.0052 - val_loss: 0.0072 - val_rmse: 0.0846 - lr: 6.2500e-06
# Epoch 988/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4946e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 989/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5911e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 990/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.8172e-05 - rmse: 0.0053 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 991/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4639e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 992/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6141e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 993/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.5639e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 994/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.7321e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0840 - lr: 6.2500e-06
# Epoch 995/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5774e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 996/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4573e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 997/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5690e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 998/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5287e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 999/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9565e-05 - rmse: 0.0054 - val_loss: 0.0071 - val_rmse: 0.0840 - lr: 6.2500e-06
# Epoch 1000/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5832e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 1001/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6664e-05 - rmse: 0.0052 - val_loss: 0.0072 - val_rmse: 0.0846 - lr: 6.2500e-06
# Epoch 1002/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.8371e-05 - rmse: 0.0053 - val_loss: 0.0072 - val_rmse: 0.0847 - lr: 6.2500e-06
# Epoch 1003/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.4851e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 1004/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.5898e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 1005/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6763e-05 - rmse: 0.0052 - val_loss: 0.0070 - val_rmse: 0.0839 - lr: 6.2500e-06
# Epoch 1006/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5774e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 1007/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5497e-05 - rmse: 0.0050 - val_loss: 0.0072 - val_rmse: 0.0846 - lr: 6.2500e-06
# Epoch 1008/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7430e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 1009/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9603e-05 - rmse: 0.0054 - val_loss: 0.0072 - val_rmse: 0.0846 - lr: 6.2500e-06
# Epoch 1010/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.1977e-05 - rmse: 0.0057 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 1011/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.6640e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 1012/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.5583e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 1013/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5925e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 1014/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6789e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 1015/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5554e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 1016/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5383e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 1017/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6566e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0840 - lr: 6.2500e-06
# Epoch 1018/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4075e-05 - rmse: 0.0049 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 1019/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6472e-05 - rmse: 0.0051 - val_loss: 0.0072 - val_rmse: 0.0846 - lr: 6.2500e-06
# Epoch 1020/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7118e-05 - rmse: 0.0052 - val_loss: 0.0072 - val_rmse: 0.0847 - lr: 6.2500e-06
# Epoch 1021/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8616e-05 - rmse: 0.0053 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 1022/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6855e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0840 - lr: 6.2500e-06
# Epoch 1023/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8742e-05 - rmse: 0.0054 - val_loss: 0.0072 - val_rmse: 0.0848 - lr: 6.2500e-06
# Epoch 1024/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6622e-05 - rmse: 0.0052 - val_loss: 0.0072 - val_rmse: 0.0848 - lr: 6.2500e-06
# Epoch 1025/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9875e-05 - rmse: 0.0055 - val_loss: 0.0071 - val_rmse: 0.0841 - lr: 6.2500e-06
# Epoch 1026/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0487e-05 - rmse: 0.0055 - val_loss: 0.0072 - val_rmse: 0.0846 - lr: 6.2500e-06
# Epoch 1027/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0387e-05 - rmse: 0.0055 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 1028/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.3541e-05 - rmse: 0.0058 - val_loss: 0.0072 - val_rmse: 0.0846 - lr: 6.2500e-06
# Epoch 1029/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0226e-05 - rmse: 0.0055 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 1030/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5886e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 1031/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4843e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 1032/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5571e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 1033/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6096e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 1034/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.6143e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0840 - lr: 6.2500e-06
# Epoch 1035/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8769e-05 - rmse: 0.0054 - val_loss: 0.0072 - val_rmse: 0.0847 - lr: 6.2500e-06
# Epoch 1036/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6036e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 1037/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7744e-05 - rmse: 0.0053 - val_loss: 0.0071 - val_rmse: 0.0845 - lr: 6.2500e-06
# Epoch 1038/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6658e-05 - rmse: 0.0052 - val_loss: 0.0071 - val_rmse: 0.0842 - lr: 6.2500e-06
# Epoch 1039/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4674e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 1040/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4891e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 1041/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4259e-05 - rmse: 0.0049 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 1042/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4988e-05 - rmse: 0.0050 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 6.2500e-06
# Epoch 1043/10000
# 5/5 [==============================] - ETA: 0s - loss: 2.6215e-05 - rmse: 0.0051    Restoring model weights from the end of the best epoch: 43.
#
# Epoch 1043: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 5/5 [==============================] - 0s 23ms/step - loss: 2.6215e-05 - rmse: 0.0051 - val_loss: 0.0071 - val_rmse: 0.0843 - lr: 6.2500e-06
# Epoch 1043: early stopping

# %%
time = end - start
print("Training time:", time)
# Out:
# Training time: 0:01:48.510507

# %%
storage_dir = "D:\\VAWT_data\\flap_steady\\flap_steady\\result\\"+"20221130AeroCNN2_optimalSettings\\test"+str(test_rate)+"Clonly"
if not os.path.exists(storage_dir):
    os.makedirs(storage_dir)
os.chdir(storage_dir)

# %%
hist = history.history
plt.plot(hist['loss'], lw=2, label='Training loss')
plt.plot(hist['val_loss'], lw=2, label='Validation loss')
plt.title('Training loss (mean squared error)\nAeroCNN-II, optimal settings, $C_l$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.yscale('log')
#plt.ylim([5e-5, 1e-1])
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()
plt.legend(loc='upper right')
saveName = "TrainingLoss_test"+str(test_rate) + ".jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(hist['rmse'], lw=2)
plt.plot(hist['val_rmse'], lw=2)
plt.title('Root Mean Squared Error, optimal settings, $C_d$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.show()

# %%
plt.plot(hist['rmse'], lw=2, label='Training RMSE')
plt.plot(hist['val_loss'], lw=2, label='Validation RMSE')
plt.title('Root Mean Squared Error\nAeroCNN-II, optimal settings, $C_l$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()
plt.legend(loc='upper right')
saveName = "RMSE_test"+str(test_rate) + ".jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
train_results = model.evaluate(x_train, y_train)
# Out:
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0015 - rmse: 0.0389

# %%
test_results = model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0048 - rmse: 0.0689

# %%
decoded_train_ = model.predict(x_train)
decoded_val_ = model.predict(x_val)
decoded_test_ = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
index_train = np.unique(np.where(np.isin(cl, y_train)))
index_val = np.unique(np.where(np.isin(cl, y_val)))
index_test = np.unique(np.where(np.isin(cl, y_test)))

# %%
y_train = y_train*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)
y_val = y_val*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)
y_test = y_test*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)

# %%
decoded_train = decoded_train_*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)
decoded_val = decoded_val_*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)
decoded_test = decoded_test_*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)

# %%
model_directory = "D:\\TrainedModels\\20221130"
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
os.chdir(model_directory)
model_name = "20221130steadyValidation_AeroCNN2_val_"+str(val_rate)+"_test"+str(test_rate)+ "_" + str(n_units) +"units_optimalSettings_Clonly.h5"
model.save(model_name, overwrite=True, include_optimizer=True, save_format='h5')

# %%
error_train_abs = np.abs(decoded_train - y_train)

# %%
error_test_abs = np.abs(decoded_test - y_test)

# %%
os.chdir(storage_dir)

# %%
l2_error_train = np.sqrt(np.sum((decoded_train - y_train)**2) / np.sum(y_train**2))
print(l2_error_train)
# Out:
# 0.05940393024503633

# %%
l2_error_val = np.sqrt(np.sum((decoded_val - y_val)**2) / np.sum(y_val**2))
print(l2_error_val)
# Out:
# 0.13351203059511232

# %%
l2_error_test = np.sqrt(np.sum((decoded_test - y_test)**2) / np.sum(y_test**2))
print(l2_error_test)
# Out:
# 0.10312772134636185

# %%
l2_error_train_list = []
for i in range(0, len(x_train)):
    l2_error_train_data = np.sqrt(np.sum((decoded_train[i] - y_train[i])**2) / np.sum(y_train[i]**2))
    l2_error_train_list.append(l2_error_train_data)

# %%
l2_error_val_list = []
for i in range(0, len(x_val)):
    l2_error_val_data = np.sqrt(np.sum((decoded_val[i] - y_val[i])**2) / np.sum((y_val[i]+1e-07)**2))
    l2_error_val_list.append(l2_error_val_data)

# %%
l2_error_test_list = []
for i in range(0, len(x_test)):
    l2_error_test_data = np.sqrt(np.sum((decoded_test[i] - y_test[i])**2) / np.sum(y_test[i]**2))
    l2_error_test_list.append(l2_error_test_data)

# %%
plt.plot(np.linspace(1,x_train.shape[0],x_train.shape[0]),
         l2_error_train*np.ones(x_train.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_train.shape[0], x_train.shape[0]), l2_error_train_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, training\nValidation rate {0}, test rate {1}, optimal settings ($C_l$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "trainingErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(np.linspace(1,x_val.shape[0],x_val.shape[0]),
         l2_error_val*np.ones(x_val.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_val.shape[0], x_val.shape[0]), l2_error_val_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, validation\nValidation rate {0}, test rate {1}, optimal settings ($C_l$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "validationErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(np.linspace(1,x_test.shape[0],x_test.shape[0]),
         l2_error_test*np.ones(x_test.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_test.shape[0], x_test.shape[0]), l2_error_test_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, test\nValidation rate {0}, test rate {1}, optimal settings ($C_l$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "testErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
predicted = model.predict(x)
# Out:
# 5/5 [==============================] - 0s 73ms/step

# %%
def CL_trainTestSplit_Plot(i, CL, cl, aTrain, aTest, iTrain, iTest):
    
    #title_0_Cd = 'Gurney flap not attached (NACA0018)\n$C_D$ prediction, L2 error=%.4f' % l2_error_Cd
    title_0_Cl = 'Gurney flap not attached (NACA0018)\n$C_L$ prediction, L2 error=%.4f' % l2_error_Cl
    
    #title_n_Cd = 'Gurney flap attached h=%.2f, '%(h[i]) + r'$\beta$=%d'%(beta[i])+'\n$C_D$ prediction, L2 error=%.4f'%(l2_error_Cd)
    title_n_Cl = 'Gurney flap attached h=%.2f, '%(h[i]) + r'$\beta$=%d'%(beta[i])+'\n$C_L$ prediction, L2 error=%.4f'%(l2_error_Cl)
    
    if i==0:
#         title_Cd, title_Cl = title_0_Cd, title_0_Cl
#         savename1,savename2 = "CdComparison_NACA0018.jpg", "ClComparison_NACA0018.jpg"
        title_Cl = title_0_Cl
        savename2 = "ClComparison_NACA0018.jpg"
    else:
#         title_Cd, title_Cl = title_n_Cd, title_n_Cl
        title_Cl = title_n_Cl
        savename2 = "ClComparison_h"+str(h[i])+"_beta"+str(beta[i])+".jpg"
    
    '''# CD graph plot
    plt.plot(alpha, CD, 'k-', label='Ground truth')
    plt.plot(alpha, cd, 'k--', label='Predicted value')
    plt.scatter(aTrain, iTrain*(np.max(cd_orig)-np.max(cd_orig))+np.min(cd_orig), color='b', label='Training set')
    plt.scatter(aVal, iVal*(np.max(cd_orig)-np.max(cd_orig))+np.min(cd_orig), color='g', label='Validation set')
    plt.scatter(aTest, iTest*(np.max(cd_orig)-np.max(cd_orig))+np.min(cd_orig), color='r', label='Test set')
    plt.xlabel('AoA (degree)')
    plt.ylabel('$C_D$')
    plt.title(title_Cd, fontsize=15)        
    plt.legend(loc='upper left')
    plt.ylim([0, 0.12])
    plt.grid()
    plt.savefig(savename1, dpi=300, bbox_inches='tight', pad_inches=0.3)
    plt.show()'''

   # CL graph plot
    plt.plot(alpha, CL, 'k-', label='Ground truth')
    plt.plot(alpha, cl, 'k--', label='Predicted value')
    plt.scatter(aTrain, iTrain, color='b', label='Training set')
    plt.scatter(aVal, iVal, color='g', label='Validation set')
    plt.scatter(aTest, iTest, color='r', label='Test set')
    plt.xlabel('AoA (degree)')
    plt.ylabel('$C_L$')
    plt.title(title_Cl, fontsize=15)
    plt.legend(loc='upper left')
    plt.ylim([0, 2])
    plt.grid()
    plt.savefig(savename2, dpi=300, bbox_inches='tight', pad_inches=0.3)
    plt.show()

# %%
h = [0, 0.01, 0.01, 0.01, 0.01, 0.01, 0.02, 0.02, 0.02, 0.02, 0.02, 0.03, 0.03, 0.03, 0.03, 0.03]
beta = [0, 30, 45, 60, 75, 90, 30, 45, 60, 75, 90, 30, 45, 60, 75, 90]
for i in range(0, 16):
    # Index from each dataset
    iTrain = []
    iVal = []
    iTest = []
    
    # Index from input data (alpha, in this case)
    alpha_train = []
    alpha_val = []
    alpha_test = []
    
    predictedValue = model.predict(x[n_alpha*i:n_alpha*(i+1),:])
    y_corres = y[n_alpha*i:n_alpha*(i+1),:]
    
    l2_error_Cl = np.sqrt(np.sum((predictedValue - y_corres)**2) / np.sum(y_corres**2))
    
    if i==0:
        print('NACA0018 airfoil without Gurney flap\nL2 error of Cl: {0:0.4f}'.format(l2_error_Cl))
    else:
        print('L2 error of Cl: {0:0.4f}'.format(l2_error_Cl))
    
    cl = predicted[n_alpha*i:n_alpha*(i+1)]*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)
    CL = y[n_alpha*i:n_alpha*(i+1)]*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)
    
    for ii, index in enumerate(index_train[np.where((index_train<(i+1)*n_alpha) & ((index_train>=i*n_alpha)))]):
        iTrain.append(predicted[index])
    for kk, index in enumerate(index_val[np.where((index_val<(i+1)*n_alpha) & ((index_val>=i*n_alpha)))]):
        iVal.append(predicted[index])    
    for jj, index in enumerate(index_test[np.where((index_test<(i+1)*n_alpha) & (index_test>=i*n_alpha))]):
        iTest.append(predicted[index])
        
    iTrain = np.array(iTrain)*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)
    iTest = np.array(iTest)*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)
    iVal = np.array(iVal)*(np.max(cl_orig)-np.min(cl_orig))+np.min(cl_orig)
    
    for ii, index in enumerate(index_train[np.where((index_train<(i+1)*n_alpha) & ((index_train>=i*n_alpha)))]):
        alpha_train.append(aa[index])
    for kk, index in enumerate(index_val[np.where((index_val<(i+1)*n_alpha) & ((index_val>=i*n_alpha)))]):
        alpha_val.append(aa[index])
    for jj, index in enumerate(index_test[np.where((index_test<(i+1)*n_alpha) & ((index_test>=i*n_alpha)))]):
        alpha_test.append(aa[index])
        
    aTrain = np.array(alpha_train)*np.max(alpha)
    aVal = np.array(alpha_val)*np.max(alpha)
    aTest = np.array(alpha_test)*np.max(alpha)
    
    CL_trainTestSplit_Plot(i, CL, cl, aTrain, aTest, iTrain, iTest)
# Out:
# 1/1 [==============================] - 0s 92ms/step
# NACA0018 airfoil without Gurney flap
# L2 error of Cl: 0.0736
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cl: 0.0381
# 1/1 [==============================] - 0s 18ms/step
# L2 error of Cl: 0.0282
# 1/1 [==============================] - 0s 17ms/step
# L2 error of Cl: 0.0328
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cl: 0.0470
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cl: 0.0678
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cl: 0.0302
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cl: 0.0454
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cl: 0.0241
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cl: 0.0508
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cl: 0.1553
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cl: 0.0323
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cl: 0.0716
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cl: 0.0399
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cl: 0.0694
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cl: 0.3816
