# %%
# Validation of the steady-state simulation - Case 3: AeroCNN-II
import os
import sys
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import datetime
# %matplotlib inline

# %%
### Defining parameters and hyperparameters of the model
n_layers=4
n_kernels=200 # Number of kernels in convolutional network
kernel_size1=2
strides=1
n_units=128 # Number of units in the hidden layer of the MLP network
input_size = 100 # Size of input for the network (100 coefficients and 3 other parameters, AoA, h, beta)
lr = 1e-04 # Learning rate of the network
test_rate=0.1 # Defines the ratio of training dataset and test dataset
val_rate=0.2
n_data = 16 # Number of txt files from which the aerodynamic coefficients are extracted
batch_size = 20 # Mini-batch size

# %%
# Changing working directory

main_directory = 'D:\\VAWT_data\\flap_steady\\flap_steady'
os.chdir(main_directory)

# %%
## Basic parameters

c = 1 # Chord length
h = np.array([0.01, 0.02, 0.03]) * c # Height of the Gurney flaps
t = 0.02 * h # Thickness of the Gurney flaps
alpha = np.linspace(0, 16, 9).reshape((9,1)) # Angles of attack
beta = np.linspace(30, 90, 5).reshape((5,1))

h = h.reshape((-1,1))
t = t.reshape((-1,1))

# %%
n_alpha = alpha.shape[0] # Number of the angles of attack
n_beta = beta.shape[0] # Number of the Gurney flap inclination
n_h = h.shape[0] # Number of the height of the Gurney flaps
n_cases = n_data * n_alpha
aa_ = np.zeros((n_cases,1))
for i in range(0, n_data):
    aa_[n_alpha*i:n_alpha*(i+1),:] = alpha[:,:]
    
aa = aa_ / np.max(alpha)

# %%
h = h.reshape((-1,1))
t = t.reshape((-1,1))

# %%
n_alpha = alpha.shape[0] # Number of the angles of attack
n_beta = beta.shape[0] # Number of the Gurney flap inclination
n_h = h.shape[0] # Number of the height of the Gurney flaps
n_cases = n_data * n_alpha # Total number of cases(Number of geometries * Number of angles of attack)

# %%
## Creating input dataset - mask
mask_dir = main_directory + '\\aeroCNN2Mask'
os.chdir(mask_dir)
mask_list = os.listdir(mask_dir)
mask_target = [file for file in mask_list if file.endswith('.csv')]

# %%
mask_df = pd.DataFrame()
for file in mask_target:
    data = pd.read_csv(file, header=None)
    mask_df = pd.concat([mask_df, data], axis=0)

# %%
x = mask_df.iloc[:,:].values

# %%
x_alligned = np.zeros((x.shape[0],x.shape[1]))
for i in range(0,144*2):
    if i%2==0:
        x_alligned[i*100:(i+1)*100,:] = x[i*100:(i+1)*100,:]
    else:
        x_alligned[i*100:(i+1)*100,:] = x[i*100:(i+1)*100,:].T

# %%
x = x_alligned.reshape((16*9,2,input_size,input_size))

# %%
## Creating output dataset - Cl and Cd
files_orig = os.listdir(main_directory)
files_target = [file for file in files_orig if file.endswith('.txt')]
os.chdir(main_directory)

# %%
target_df = pd.DataFrame()
for file in files_target:
    data = pd.read_table(file, header=None)
    target_df = pd.concat([target_df, data], axis=0)

# %%
cd_orig = target_df.iloc[:,3].values # Cd values
#target_c4 = target_df.iloc[:,4].values# Cl values

# %%
cd = (cd_orig-np.min(cd_orig))/(np.max(cd_orig)-np.min(cd_orig))

# %%
y = cd.reshape((-1,1))

# %%
x_all, x_test, y_all, y_test = train_test_split(x, y, test_size=test_rate, random_state=1)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_all, y_all, test_size=val_rate/(1-test_rate), random_state=1)

# %%
x_train.shape
# Out:
# (100, 2, 100, 100)

# %%
y_train.shape
# Out:
# (100, 1)

# %%
tf.keras.backend.set_image_data_format('channels_first')

# %%
input_image = tf.keras.Input(shape=(2, input_size, input_size))

x_conv1 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(input_image)
x1_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv1)
x_conv2 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x1_)
x2_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv2)
x_conv3 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x2_)
x3_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv3)
x_conv4 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x3_)
x4_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv4)
x_flat = tf.keras.layers.Flatten()(x4_)
x_fc1 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc1')(x_flat)
x_fc2 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc2')(x_fc1)
x_fc3 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc3')(x_fc2)
x_fc4 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc4')(x_fc3)
x_fc5 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc5')(x_fc4)

output_data = tf.keras.layers.Dense(units=1, activation='linear', name='outputLayer')(x_fc5)
# AeroCNN-II based
model = tf.keras.Model(input_image, output_data)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2, 100, 100)]     0
#
#  conv2d (Conv2D)             (None, 200, 100, 100)     1800
#
#  max_pooling2d (MaxPooling2D  (None, 200, 50, 50)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 200, 50, 50)       160200
#
#  max_pooling2d_1 (MaxPooling  (None, 200, 25, 25)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 200, 25, 25)       160200
#
#  max_pooling2d_2 (MaxPooling  (None, 200, 12, 12)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 200, 12, 12)       160200
#
#  max_pooling2d_3 (MaxPooling  (None, 200, 6, 6)        0
#  2D)
#
#  flatten (Flatten)           (None, 7200)              0
#
#  fc1 (Dense)                 (None, 128)               921728
#
#  fc2 (Dense)                 (None, 128)               16512
#
#  fc3 (Dense)                 (None, 128)               16512
#
#  fc4 (Dense)                 (None, 128)               16512
#
#  fc5 (Dense)                 (None, 128)               16512
#
#  outputLayer (Dense)         (None, 1)                 129
#
# =================================================================
# Total params: 1,470,305
# Trainable params: 1,470,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
              loss = tf.keras.losses.MeanSquaredError(),
              metrics=[tf.keras.metrics.RootMeanSquaredError(name="rmse")])

# %%
model_directory = "D:\\TrainedModels\\20221130"
if not os.path.exists(model_directory):
    os.makedirs(model_directory)

# %%
# ckpt_name = model_directory + "\\20221130steadyValidation_AeroCNN2_val_"+str(val_rate) + "_test"+str(test_rate)+ "_" + str(n_units) +"units_OptimalSettings_Cdcheckpoint.h5"

# ckpt = tf.keras.callbacks.ModelCheckpoint(ckpt_name, monitor="val_loss", mode='min', verbose=1, save_best_only=True)

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=1000, min_delta=6e-7,
                                      restore_best_weights=True, verbose=1)
rp = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=200, factor=0.5,
                                          min_delta = 1e-09, min_lr=1e-06, verbose=1)

# %%
STEP_SIZE_TRAIN = len(x_train)//batch_size
VALIDATION_STEPS = len(x_val)//batch_size

# %%
start = datetime.datetime.now()
history = model.fit(x_train, y_train, batch_size=batch_size,
                    validation_data=(x_val, y_val),
                    steps_per_epoch = STEP_SIZE_TRAIN, validation_steps=VALIDATION_STEPS,
                    epochs=10000, shuffle=True, callbacks=[es, rp])
end = datetime.datetime.now()
# Out:
# Epoch 1/10000
# 5/5 [==============================] - 4s 69ms/step - loss: 0.0952 - rmse: 0.3086 - val_loss: 0.0163 - val_rmse: 0.1277 - lr: 1.0000e-04
# Epoch 2/10000
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0168 - rmse: 0.1297 - val_loss: 0.0099 - val_rmse: 0.0995 - lr: 1.0000e-04
# Epoch 3/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0097 - rmse: 0.0987 - val_loss: 0.0044 - val_rmse: 0.0665 - lr: 1.0000e-04
# Epoch 4/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0062 - rmse: 0.0790 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 1.0000e-04
# Epoch 5/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0065 - rmse: 0.0805 - val_loss: 0.0048 - val_rmse: 0.0692 - lr: 1.0000e-04
# Epoch 6/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0048 - rmse: 0.0695 - val_loss: 0.0047 - val_rmse: 0.0686 - lr: 1.0000e-04
# Epoch 7/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0037 - rmse: 0.0609 - val_loss: 0.0020 - val_rmse: 0.0444 - lr: 1.0000e-04
# Epoch 8/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0032 - rmse: 0.0569 - val_loss: 0.0028 - val_rmse: 0.0533 - lr: 1.0000e-04
# Epoch 9/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0021 - rmse: 0.0455 - val_loss: 0.0036 - val_rmse: 0.0603 - lr: 1.0000e-04
# Epoch 10/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0019 - rmse: 0.0439 - val_loss: 0.0021 - val_rmse: 0.0455 - lr: 1.0000e-04
# Epoch 11/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0017 - rmse: 0.0410 - val_loss: 0.0023 - val_rmse: 0.0480 - lr: 1.0000e-04
# Epoch 12/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0016 - rmse: 0.0394 - val_loss: 0.0025 - val_rmse: 0.0504 - lr: 1.0000e-04
# Epoch 13/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0016 - rmse: 0.0395 - val_loss: 0.0026 - val_rmse: 0.0506 - lr: 1.0000e-04
# Epoch 14/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0019 - rmse: 0.0436 - val_loss: 0.0019 - val_rmse: 0.0433 - lr: 1.0000e-04
# Epoch 15/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0020 - rmse: 0.0444 - val_loss: 0.0025 - val_rmse: 0.0501 - lr: 1.0000e-04
# Epoch 16/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0021 - rmse: 0.0462 - val_loss: 0.0024 - val_rmse: 0.0494 - lr: 1.0000e-04
# Epoch 17/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0018 - rmse: 0.0429 - val_loss: 0.0032 - val_rmse: 0.0565 - lr: 1.0000e-04
# Epoch 18/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0015 - rmse: 0.0386 - val_loss: 0.0021 - val_rmse: 0.0463 - lr: 1.0000e-04
# Epoch 19/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0013 - rmse: 0.0354 - val_loss: 0.0043 - val_rmse: 0.0655 - lr: 1.0000e-04
# Epoch 20/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0012 - rmse: 0.0344 - val_loss: 0.0022 - val_rmse: 0.0470 - lr: 1.0000e-04
# Epoch 21/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.5541e-04 - rmse: 0.0275 - val_loss: 0.0026 - val_rmse: 0.0506 - lr: 1.0000e-04
# Epoch 22/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.1898e-04 - rmse: 0.0303 - val_loss: 0.0040 - val_rmse: 0.0631 - lr: 1.0000e-04
# Epoch 23/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0012 - rmse: 0.0343 - val_loss: 0.0018 - val_rmse: 0.0424 - lr: 1.0000e-04
# Epoch 24/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0013 - rmse: 0.0356 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 1.0000e-04
# Epoch 25/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0011 - rmse: 0.0330 - val_loss: 0.0026 - val_rmse: 0.0507 - lr: 1.0000e-04
# Epoch 26/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0011 - rmse: 0.0334 - val_loss: 0.0021 - val_rmse: 0.0458 - lr: 1.0000e-04
# Epoch 27/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.3354e-04 - rmse: 0.0271 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 1.0000e-04
# Epoch 28/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.9697e-04 - rmse: 0.0282 - val_loss: 0.0019 - val_rmse: 0.0432 - lr: 1.0000e-04
# Epoch 29/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.2304e-04 - rmse: 0.0269 - val_loss: 0.0037 - val_rmse: 0.0612 - lr: 1.0000e-04
# Epoch 30/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.4723e-04 - rmse: 0.0308 - val_loss: 0.0017 - val_rmse: 0.0409 - lr: 1.0000e-04
# Epoch 31/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0016 - rmse: 0.0394 - val_loss: 0.0028 - val_rmse: 0.0531 - lr: 1.0000e-04
# Epoch 32/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.6448e-04 - rmse: 0.0276 - val_loss: 0.0026 - val_rmse: 0.0508 - lr: 1.0000e-04
# Epoch 33/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.1389e-04 - rmse: 0.0285 - val_loss: 0.0020 - val_rmse: 0.0446 - lr: 1.0000e-04
# Epoch 34/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.5504e-04 - rmse: 0.0292 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 1.0000e-04
# Epoch 35/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.9585e-04 - rmse: 0.0244 - val_loss: 0.0023 - val_rmse: 0.0478 - lr: 1.0000e-04
# Epoch 36/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.1728e-04 - rmse: 0.0227 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 1.0000e-04
# Epoch 37/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.0668e-04 - rmse: 0.0266 - val_loss: 0.0021 - val_rmse: 0.0453 - lr: 1.0000e-04
# Epoch 38/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.1612e-04 - rmse: 0.0286 - val_loss: 0.0020 - val_rmse: 0.0447 - lr: 1.0000e-04
# Epoch 39/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.1805e-04 - rmse: 0.0204 - val_loss: 0.0029 - val_rmse: 0.0534 - lr: 1.0000e-04
# Epoch 40/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.0135e-04 - rmse: 0.0200 - val_loss: 0.0016 - val_rmse: 0.0404 - lr: 1.0000e-04
# Epoch 41/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.6809e-04 - rmse: 0.0216 - val_loss: 0.0025 - val_rmse: 0.0503 - lr: 1.0000e-04
# Epoch 42/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9213e-04 - rmse: 0.0198 - val_loss: 0.0026 - val_rmse: 0.0512 - lr: 1.0000e-04
# Epoch 43/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.2648e-04 - rmse: 0.0181 - val_loss: 0.0019 - val_rmse: 0.0434 - lr: 1.0000e-04
# Epoch 44/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.5982e-04 - rmse: 0.0190 - val_loss: 0.0029 - val_rmse: 0.0540 - lr: 1.0000e-04
# Epoch 45/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.9052e-04 - rmse: 0.0170 - val_loss: 0.0020 - val_rmse: 0.0449 - lr: 1.0000e-04
# Epoch 46/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2818e-04 - rmse: 0.0151 - val_loss: 0.0024 - val_rmse: 0.0488 - lr: 1.0000e-04
# Epoch 47/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8880e-04 - rmse: 0.0137 - val_loss: 0.0021 - val_rmse: 0.0461 - lr: 1.0000e-04
# Epoch 48/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0856e-04 - rmse: 0.0144 - val_loss: 0.0022 - val_rmse: 0.0468 - lr: 1.0000e-04
# Epoch 49/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.6642e-04 - rmse: 0.0163 - val_loss: 0.0026 - val_rmse: 0.0505 - lr: 1.0000e-04
# Epoch 50/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7530e-04 - rmse: 0.0132 - val_loss: 0.0021 - val_rmse: 0.0461 - lr: 1.0000e-04
# Epoch 51/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0300e-04 - rmse: 0.0142 - val_loss: 0.0022 - val_rmse: 0.0465 - lr: 1.0000e-04
# Epoch 52/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1040e-04 - rmse: 0.0145 - val_loss: 0.0025 - val_rmse: 0.0497 - lr: 1.0000e-04
# Epoch 53/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.0175e-04 - rmse: 0.0200 - val_loss: 0.0022 - val_rmse: 0.0468 - lr: 1.0000e-04
# Epoch 54/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9729e-04 - rmse: 0.0199 - val_loss: 0.0026 - val_rmse: 0.0511 - lr: 1.0000e-04
# Epoch 55/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.3400e-04 - rmse: 0.0183 - val_loss: 0.0017 - val_rmse: 0.0407 - lr: 1.0000e-04
# Epoch 56/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9951e-04 - rmse: 0.0200 - val_loss: 0.0029 - val_rmse: 0.0540 - lr: 1.0000e-04
# Epoch 57/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.3142e-04 - rmse: 0.0182 - val_loss: 0.0025 - val_rmse: 0.0504 - lr: 1.0000e-04
# Epoch 58/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.5093e-04 - rmse: 0.0212 - val_loss: 0.0025 - val_rmse: 0.0497 - lr: 1.0000e-04
# Epoch 59/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.6451e-04 - rmse: 0.0191 - val_loss: 0.0023 - val_rmse: 0.0477 - lr: 1.0000e-04
# Epoch 60/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8988e-04 - rmse: 0.0170 - val_loss: 0.0027 - val_rmse: 0.0524 - lr: 1.0000e-04
# Epoch 61/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4494e-04 - rmse: 0.0157 - val_loss: 0.0029 - val_rmse: 0.0541 - lr: 1.0000e-04
# Epoch 62/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2248e-04 - rmse: 0.0149 - val_loss: 0.0025 - val_rmse: 0.0495 - lr: 1.0000e-04
# Epoch 63/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.8353e-04 - rmse: 0.0168 - val_loss: 0.0027 - val_rmse: 0.0522 - lr: 1.0000e-04
# Epoch 64/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.2051e-04 - rmse: 0.0179 - val_loss: 0.0027 - val_rmse: 0.0515 - lr: 1.0000e-04
# Epoch 65/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.2584e-04 - rmse: 0.0150 - val_loss: 0.0026 - val_rmse: 0.0514 - lr: 1.0000e-04
# Epoch 66/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9109e-04 - rmse: 0.0138 - val_loss: 0.0025 - val_rmse: 0.0503 - lr: 1.0000e-04
# Epoch 67/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0699e-04 - rmse: 0.0144 - val_loss: 0.0025 - val_rmse: 0.0500 - lr: 1.0000e-04
# Epoch 68/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.8484e-04 - rmse: 0.0136 - val_loss: 0.0021 - val_rmse: 0.0458 - lr: 1.0000e-04
# Epoch 69/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.5925e-04 - rmse: 0.0214 - val_loss: 0.0037 - val_rmse: 0.0606 - lr: 1.0000e-04
# Epoch 70/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.7418e-04 - rmse: 0.0193 - val_loss: 0.0029 - val_rmse: 0.0537 - lr: 1.0000e-04
# Epoch 71/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1760e-04 - rmse: 0.0148 - val_loss: 0.0021 - val_rmse: 0.0461 - lr: 1.0000e-04
# Epoch 72/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1269e-04 - rmse: 0.0146 - val_loss: 0.0027 - val_rmse: 0.0523 - lr: 1.0000e-04
# Epoch 73/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3809e-04 - rmse: 0.0118 - val_loss: 0.0022 - val_rmse: 0.0473 - lr: 1.0000e-04
# Epoch 74/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 9.3276e-05 - rmse: 0.0097 - val_loss: 0.0026 - val_rmse: 0.0514 - lr: 1.0000e-04
# Epoch 75/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2001e-04 - rmse: 0.0110 - val_loss: 0.0023 - val_rmse: 0.0483 - lr: 1.0000e-04
# Epoch 76/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 9.5871e-05 - rmse: 0.0098 - val_loss: 0.0023 - val_rmse: 0.0484 - lr: 1.0000e-04
# Epoch 77/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8627e-04 - rmse: 0.0169 - val_loss: 0.0044 - val_rmse: 0.0665 - lr: 1.0000e-04
# Epoch 78/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0011 - rmse: 0.0333 - val_loss: 0.0017 - val_rmse: 0.0409 - lr: 1.0000e-04
# Epoch 79/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.8007e-04 - rmse: 0.0219 - val_loss: 0.0024 - val_rmse: 0.0491 - lr: 1.0000e-04
# Epoch 80/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.3316e-04 - rmse: 0.0183 - val_loss: 0.0025 - val_rmse: 0.0498 - lr: 1.0000e-04
# Epoch 81/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.1832e-04 - rmse: 0.0178 - val_loss: 0.0029 - val_rmse: 0.0537 - lr: 1.0000e-04
# Epoch 82/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.4003e-04 - rmse: 0.0184 - val_loss: 0.0017 - val_rmse: 0.0415 - lr: 1.0000e-04
# Epoch 83/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.3898e-04 - rmse: 0.0184 - val_loss: 0.0032 - val_rmse: 0.0568 - lr: 1.0000e-04
# Epoch 84/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3771e-04 - rmse: 0.0154 - val_loss: 0.0021 - val_rmse: 0.0458 - lr: 1.0000e-04
# Epoch 85/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.8312e-04 - rmse: 0.0135 - val_loss: 0.0027 - val_rmse: 0.0516 - lr: 1.0000e-04
# Epoch 86/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9326e-04 - rmse: 0.0139 - val_loss: 0.0025 - val_rmse: 0.0500 - lr: 1.0000e-04
# Epoch 87/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2546e-04 - rmse: 0.0150 - val_loss: 0.0022 - val_rmse: 0.0471 - lr: 1.0000e-04
# Epoch 88/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0700e-04 - rmse: 0.0144 - val_loss: 0.0023 - val_rmse: 0.0476 - lr: 1.0000e-04
# Epoch 89/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3800e-04 - rmse: 0.0117 - val_loss: 0.0021 - val_rmse: 0.0455 - lr: 1.0000e-04
# Epoch 90/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.4398e-05 - rmse: 0.0092 - val_loss: 0.0024 - val_rmse: 0.0493 - lr: 1.0000e-04
# Epoch 91/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.1938e-05 - rmse: 0.0091 - val_loss: 0.0024 - val_rmse: 0.0486 - lr: 1.0000e-04
# Epoch 92/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1092e-04 - rmse: 0.0105 - val_loss: 0.0023 - val_rmse: 0.0484 - lr: 1.0000e-04
# Epoch 93/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.2016e-05 - rmse: 0.0091 - val_loss: 0.0023 - val_rmse: 0.0482 - lr: 1.0000e-04
# Epoch 94/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.0824e-05 - rmse: 0.0090 - val_loss: 0.0027 - val_rmse: 0.0522 - lr: 1.0000e-04
# Epoch 95/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4116e-04 - rmse: 0.0119 - val_loss: 0.0018 - val_rmse: 0.0422 - lr: 1.0000e-04
# Epoch 96/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7783e-04 - rmse: 0.0133 - val_loss: 0.0030 - val_rmse: 0.0547 - lr: 1.0000e-04
# Epoch 97/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6517e-04 - rmse: 0.0129 - val_loss: 0.0023 - val_rmse: 0.0481 - lr: 1.0000e-04
# Epoch 98/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 9.9499e-05 - rmse: 0.0100 - val_loss: 0.0026 - val_rmse: 0.0507 - lr: 1.0000e-04
# Epoch 99/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0283e-04 - rmse: 0.0101 - val_loss: 0.0024 - val_rmse: 0.0495 - lr: 1.0000e-04
# Epoch 100/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3338e-04 - rmse: 0.0115 - val_loss: 0.0024 - val_rmse: 0.0488 - lr: 1.0000e-04
# Epoch 101/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.3619e-05 - rmse: 0.0080 - val_loss: 0.0023 - val_rmse: 0.0480 - lr: 1.0000e-04
# Epoch 102/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.0979e-05 - rmse: 0.0090 - val_loss: 0.0022 - val_rmse: 0.0472 - lr: 1.0000e-04
# Epoch 103/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.3028e-05 - rmse: 0.0085 - val_loss: 0.0023 - val_rmse: 0.0477 - lr: 1.0000e-04
# Epoch 104/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.9927e-05 - rmse: 0.0084 - val_loss: 0.0021 - val_rmse: 0.0461 - lr: 1.0000e-04
# Epoch 105/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.2028e-05 - rmse: 0.0065 - val_loss: 0.0023 - val_rmse: 0.0481 - lr: 1.0000e-04
# Epoch 106/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.1419e-05 - rmse: 0.0064 - val_loss: 0.0020 - val_rmse: 0.0452 - lr: 1.0000e-04
# Epoch 107/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.6615e-05 - rmse: 0.0061 - val_loss: 0.0023 - val_rmse: 0.0484 - lr: 1.0000e-04
# Epoch 108/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.5171e-05 - rmse: 0.0074 - val_loss: 0.0020 - val_rmse: 0.0445 - lr: 1.0000e-04
# Epoch 109/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.1250e-05 - rmse: 0.0072 - val_loss: 0.0025 - val_rmse: 0.0496 - lr: 1.0000e-04
# Epoch 110/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.7265e-05 - rmse: 0.0082 - val_loss: 0.0020 - val_rmse: 0.0452 - lr: 1.0000e-04
# Epoch 111/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.5049e-05 - rmse: 0.0059 - val_loss: 0.0022 - val_rmse: 0.0472 - lr: 1.0000e-04
# Epoch 112/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.0742e-05 - rmse: 0.0064 - val_loss: 0.0022 - val_rmse: 0.0468 - lr: 1.0000e-04
# Epoch 113/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.5144e-05 - rmse: 0.0059 - val_loss: 0.0023 - val_rmse: 0.0481 - lr: 1.0000e-04
# Epoch 114/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7534e-05 - rmse: 0.0042 - val_loss: 0.0023 - val_rmse: 0.0475 - lr: 1.0000e-04
# Epoch 115/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2669e-05 - rmse: 0.0036 - val_loss: 0.0022 - val_rmse: 0.0470 - lr: 1.0000e-04
# Epoch 116/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5532e-05 - rmse: 0.0039 - val_loss: 0.0023 - val_rmse: 0.0475 - lr: 1.0000e-04
# Epoch 117/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5115e-05 - rmse: 0.0039 - val_loss: 0.0023 - val_rmse: 0.0476 - lr: 1.0000e-04
# Epoch 118/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0480e-05 - rmse: 0.0032 - val_loss: 0.0023 - val_rmse: 0.0482 - lr: 1.0000e-04
# Epoch 119/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 9.9866e-06 - rmse: 0.0032 - val_loss: 0.0022 - val_rmse: 0.0466 - lr: 1.0000e-04
# Epoch 120/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5911e-05 - rmse: 0.0040 - val_loss: 0.0023 - val_rmse: 0.0479 - lr: 1.0000e-04
# Epoch 121/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5307e-05 - rmse: 0.0039 - val_loss: 0.0023 - val_rmse: 0.0476 - lr: 1.0000e-04
# Epoch 122/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.5440e-05 - rmse: 0.0050 - val_loss: 0.0021 - val_rmse: 0.0461 - lr: 1.0000e-04
# Epoch 123/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.7806e-05 - rmse: 0.0061 - val_loss: 0.0024 - val_rmse: 0.0493 - lr: 1.0000e-04
# Epoch 124/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.4281e-05 - rmse: 0.0059 - val_loss: 0.0021 - val_rmse: 0.0459 - lr: 1.0000e-04
# Epoch 125/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.1300e-05 - rmse: 0.0056 - val_loss: 0.0024 - val_rmse: 0.0487 - lr: 1.0000e-04
# Epoch 126/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3903e-05 - rmse: 0.0073 - val_loss: 0.0023 - val_rmse: 0.0477 - lr: 1.0000e-04
# Epoch 127/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.7013e-05 - rmse: 0.0069 - val_loss: 0.0026 - val_rmse: 0.0509 - lr: 1.0000e-04
# Epoch 128/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.9062e-05 - rmse: 0.0094 - val_loss: 0.0021 - val_rmse: 0.0457 - lr: 1.0000e-04
# Epoch 129/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.8275e-05 - rmse: 0.0076 - val_loss: 0.0021 - val_rmse: 0.0457 - lr: 1.0000e-04
# Epoch 130/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2681e-04 - rmse: 0.0113 - val_loss: 0.0028 - val_rmse: 0.0525 - lr: 1.0000e-04
# Epoch 131/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6452e-04 - rmse: 0.0128 - val_loss: 0.0027 - val_rmse: 0.0515 - lr: 1.0000e-04
# Epoch 132/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.3671e-04 - rmse: 0.0154 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 1.0000e-04
# Epoch 133/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.6856e-04 - rmse: 0.0164 - val_loss: 0.0020 - val_rmse: 0.0451 - lr: 1.0000e-04
# Epoch 134/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.2340e-04 - rmse: 0.0149 - val_loss: 0.0026 - val_rmse: 0.0509 - lr: 1.0000e-04
# Epoch 135/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9040e-04 - rmse: 0.0138 - val_loss: 0.0024 - val_rmse: 0.0485 - lr: 1.0000e-04
# Epoch 136/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1887e-04 - rmse: 0.0109 - val_loss: 0.0026 - val_rmse: 0.0510 - lr: 1.0000e-04
# Epoch 137/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4626e-04 - rmse: 0.0121 - val_loss: 0.0020 - val_rmse: 0.0452 - lr: 1.0000e-04
# Epoch 138/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0447e-04 - rmse: 0.0102 - val_loss: 0.0024 - val_rmse: 0.0494 - lr: 1.0000e-04
# Epoch 139/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1863e-04 - rmse: 0.0109 - val_loss: 0.0022 - val_rmse: 0.0465 - lr: 1.0000e-04
# Epoch 140/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.3239e-05 - rmse: 0.0091 - val_loss: 0.0023 - val_rmse: 0.0482 - lr: 1.0000e-04
# Epoch 141/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.7873e-05 - rmse: 0.0082 - val_loss: 0.0025 - val_rmse: 0.0500 - lr: 1.0000e-04
# Epoch 142/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.8036e-05 - rmse: 0.0076 - val_loss: 0.0024 - val_rmse: 0.0487 - lr: 1.0000e-04
# Epoch 143/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.4675e-05 - rmse: 0.0080 - val_loss: 0.0022 - val_rmse: 0.0469 - lr: 1.0000e-04
# Epoch 144/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.6907e-05 - rmse: 0.0061 - val_loss: 0.0022 - val_rmse: 0.0467 - lr: 1.0000e-04
# Epoch 145/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.7415e-05 - rmse: 0.0069 - val_loss: 0.0026 - val_rmse: 0.0514 - lr: 1.0000e-04
# Epoch 146/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.0471e-05 - rmse: 0.0078 - val_loss: 0.0026 - val_rmse: 0.0512 - lr: 1.0000e-04
# Epoch 147/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.3868e-05 - rmse: 0.0080 - val_loss: 0.0025 - val_rmse: 0.0498 - lr: 1.0000e-04
# Epoch 148/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.9292e-05 - rmse: 0.0070 - val_loss: 0.0022 - val_rmse: 0.0469 - lr: 1.0000e-04
# Epoch 149/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.7062e-05 - rmse: 0.0061 - val_loss: 0.0024 - val_rmse: 0.0487 - lr: 1.0000e-04
# Epoch 150/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.2757e-05 - rmse: 0.0065 - val_loss: 0.0024 - val_rmse: 0.0495 - lr: 1.0000e-04
# Epoch 151/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.1873e-05 - rmse: 0.0065 - val_loss: 0.0026 - val_rmse: 0.0512 - lr: 1.0000e-04
# Epoch 152/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.9151e-05 - rmse: 0.0083 - val_loss: 0.0023 - val_rmse: 0.0481 - lr: 1.0000e-04
# Epoch 153/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2643e-04 - rmse: 0.0112 - val_loss: 0.0024 - val_rmse: 0.0486 - lr: 1.0000e-04
# Epoch 154/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.1504e-05 - rmse: 0.0090 - val_loss: 0.0024 - val_rmse: 0.0492 - lr: 1.0000e-04
# Epoch 155/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6327e-04 - rmse: 0.0128 - val_loss: 0.0029 - val_rmse: 0.0541 - lr: 1.0000e-04
# Epoch 156/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.4509e-04 - rmse: 0.0157 - val_loss: 0.0017 - val_rmse: 0.0413 - lr: 1.0000e-04
# Epoch 157/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3612e-04 - rmse: 0.0154 - val_loss: 0.0021 - val_rmse: 0.0458 - lr: 1.0000e-04
# Epoch 158/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.2456e-04 - rmse: 0.0150 - val_loss: 0.0028 - val_rmse: 0.0524 - lr: 1.0000e-04
# Epoch 159/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.6944e-04 - rmse: 0.0239 - val_loss: 0.0040 - val_rmse: 0.0632 - lr: 1.0000e-04
# Epoch 160/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 9.4604e-04 - rmse: 0.0308 - val_loss: 0.0019 - val_rmse: 0.0440 - lr: 1.0000e-04
# Epoch 161/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 9.2323e-04 - rmse: 0.0304 - val_loss: 0.0026 - val_rmse: 0.0512 - lr: 1.0000e-04
# Epoch 162/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.4472e-04 - rmse: 0.0254 - val_loss: 0.0021 - val_rmse: 0.0456 - lr: 1.0000e-04
# Epoch 163/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.2010e-04 - rmse: 0.0179 - val_loss: 0.0028 - val_rmse: 0.0531 - lr: 1.0000e-04
# Epoch 164/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.2452e-04 - rmse: 0.0206 - val_loss: 0.0022 - val_rmse: 0.0474 - lr: 1.0000e-04
# Epoch 165/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8542e-04 - rmse: 0.0169 - val_loss: 0.0016 - val_rmse: 0.0406 - lr: 1.0000e-04
# Epoch 166/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7335e-04 - rmse: 0.0218 - val_loss: 0.0025 - val_rmse: 0.0501 - lr: 1.0000e-04
# Epoch 167/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4075e-04 - rmse: 0.0233 - val_loss: 0.0026 - val_rmse: 0.0514 - lr: 1.0000e-04
# Epoch 168/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.7348e-04 - rmse: 0.0260 - val_loss: 0.0024 - val_rmse: 0.0485 - lr: 1.0000e-04
# Epoch 169/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.7150e-04 - rmse: 0.0217 - val_loss: 0.0018 - val_rmse: 0.0423 - lr: 1.0000e-04
# Epoch 170/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.2913e-04 - rmse: 0.0181 - val_loss: 0.0030 - val_rmse: 0.0547 - lr: 1.0000e-04
# Epoch 171/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.7785e-04 - rmse: 0.0167 - val_loss: 0.0017 - val_rmse: 0.0409 - lr: 1.0000e-04
# Epoch 172/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.5274e-04 - rmse: 0.0213 - val_loss: 0.0030 - val_rmse: 0.0552 - lr: 1.0000e-04
# Epoch 173/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.0423e-04 - rmse: 0.0246 - val_loss: 0.0017 - val_rmse: 0.0415 - lr: 1.0000e-04
# Epoch 174/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9718e-04 - rmse: 0.0199 - val_loss: 0.0036 - val_rmse: 0.0603 - lr: 1.0000e-04
# Epoch 175/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.6919e-04 - rmse: 0.0259 - val_loss: 0.0023 - val_rmse: 0.0481 - lr: 1.0000e-04
# Epoch 176/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0013 - rmse: 0.0358 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 1.0000e-04
# Epoch 177/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0030 - rmse: 0.0549 - val_loss: 0.0043 - val_rmse: 0.0654 - lr: 1.0000e-04
# Epoch 178/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0037 - rmse: 0.0609 - val_loss: 0.0040 - val_rmse: 0.0633 - lr: 1.0000e-04
# Epoch 179/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0030 - rmse: 0.0548 - val_loss: 0.0024 - val_rmse: 0.0485 - lr: 1.0000e-04
# Epoch 180/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0044 - rmse: 0.0663 - val_loss: 0.0047 - val_rmse: 0.0686 - lr: 1.0000e-04
# Epoch 181/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0037 - rmse: 0.0607 - val_loss: 0.0063 - val_rmse: 0.0794 - lr: 1.0000e-04
# Epoch 182/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0027 - rmse: 0.0523 - val_loss: 0.0040 - val_rmse: 0.0635 - lr: 1.0000e-04
# Epoch 183/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0033 - rmse: 0.0572 - val_loss: 0.0089 - val_rmse: 0.0941 - lr: 1.0000e-04
# Epoch 184/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0031 - rmse: 0.0555 - val_loss: 0.0052 - val_rmse: 0.0719 - lr: 1.0000e-04
# Epoch 185/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0036 - rmse: 0.0596 - val_loss: 0.0046 - val_rmse: 0.0676 - lr: 1.0000e-04
# Epoch 186/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0018 - rmse: 0.0428 - val_loss: 0.0061 - val_rmse: 0.0782 - lr: 1.0000e-04
# Epoch 187/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0026 - rmse: 0.0509 - val_loss: 0.0074 - val_rmse: 0.0862 - lr: 1.0000e-04
# Epoch 188/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0031 - rmse: 0.0560 - val_loss: 0.0040 - val_rmse: 0.0633 - lr: 1.0000e-04
# Epoch 189/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0030 - rmse: 0.0546 - val_loss: 0.0066 - val_rmse: 0.0812 - lr: 1.0000e-04
# Epoch 190/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0026 - rmse: 0.0510 - val_loss: 0.0031 - val_rmse: 0.0561 - lr: 1.0000e-04
# Epoch 191/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0028 - rmse: 0.0527 - val_loss: 0.0044 - val_rmse: 0.0666 - lr: 1.0000e-04
# Epoch 192/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0023 - rmse: 0.0483 - val_loss: 0.0042 - val_rmse: 0.0646 - lr: 1.0000e-04
# Epoch 193/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0011 - rmse: 0.0339 - val_loss: 0.0032 - val_rmse: 0.0568 - lr: 1.0000e-04
# Epoch 194/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0010 - rmse: 0.0322 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 1.0000e-04
# Epoch 195/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.8215e-04 - rmse: 0.0280 - val_loss: 0.0036 - val_rmse: 0.0603 - lr: 1.0000e-04
# Epoch 196/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.0156e-04 - rmse: 0.0224 - val_loss: 0.0031 - val_rmse: 0.0557 - lr: 1.0000e-04
# Epoch 197/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9213e-04 - rmse: 0.0198 - val_loss: 0.0036 - val_rmse: 0.0599 - lr: 1.0000e-04
# Epoch 198/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.4329e-04 - rmse: 0.0211 - val_loss: 0.0031 - val_rmse: 0.0558 - lr: 1.0000e-04
# Epoch 199/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.7590e-04 - rmse: 0.0218 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 1.0000e-04
# Epoch 200/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.6678e-04 - rmse: 0.0192 - val_loss: 0.0037 - val_rmse: 0.0605 - lr: 1.0000e-04
# Epoch 201/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9944e-04 - rmse: 0.0200 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 1.0000e-04
# Epoch 202/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.6511e-04 - rmse: 0.0216 - val_loss: 0.0042 - val_rmse: 0.0645 - lr: 1.0000e-04
# Epoch 203/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.3347e-04 - rmse: 0.0183 - val_loss: 0.0027 - val_rmse: 0.0520 - lr: 1.0000e-04
# Epoch 204/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.7549e-04 - rmse: 0.0278 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 1.0000e-04
# Epoch 205/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.9427e-04 - rmse: 0.0244 - val_loss: 0.0028 - val_rmse: 0.0525 - lr: 1.0000e-04
# Epoch 206/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.4185e-04 - rmse: 0.0210 - val_loss: 0.0032 - val_rmse: 0.0567 - lr: 1.0000e-04
# Epoch 207/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.9157e-04 - rmse: 0.0171 - val_loss: 0.0024 - val_rmse: 0.0486 - lr: 1.0000e-04
# Epoch 208/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.6568e-04 - rmse: 0.0163 - val_loss: 0.0029 - val_rmse: 0.0537 - lr: 1.0000e-04
# Epoch 209/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0811e-04 - rmse: 0.0144 - val_loss: 0.0028 - val_rmse: 0.0527 - lr: 1.0000e-04
# Epoch 210/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.8417e-04 - rmse: 0.0136 - val_loss: 0.0033 - val_rmse: 0.0574 - lr: 1.0000e-04
# Epoch 211/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0906e-04 - rmse: 0.0104 - val_loss: 0.0031 - val_rmse: 0.0556 - lr: 1.0000e-04
# Epoch 212/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.8662e-05 - rmse: 0.0099 - val_loss: 0.0030 - val_rmse: 0.0549 - lr: 1.0000e-04
# Epoch 213/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.8582e-05 - rmse: 0.0083 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 1.0000e-04
# Epoch 214/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.2681e-05 - rmse: 0.0079 - val_loss: 0.0031 - val_rmse: 0.0557 - lr: 1.0000e-04
# Epoch 215/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.2534e-05 - rmse: 0.0085 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 1.0000e-04
# Epoch 216/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9520e-05 - rmse: 0.0063 - val_loss: 0.0030 - val_rmse: 0.0551 - lr: 1.0000e-04
# Epoch 217/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.2520e-05 - rmse: 0.0065 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 1.0000e-04
# Epoch 218/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.1832e-05 - rmse: 0.0072 - val_loss: 0.0031 - val_rmse: 0.0556 - lr: 1.0000e-04
# Epoch 219/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.1551e-05 - rmse: 0.0072 - val_loss: 0.0033 - val_rmse: 0.0571 - lr: 1.0000e-04
# Epoch 220/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.8643e-05 - rmse: 0.0070 - val_loss: 0.0032 - val_rmse: 0.0569 - lr: 1.0000e-04
# Epoch 221/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9782e-05 - rmse: 0.0063 - val_loss: 0.0033 - val_rmse: 0.0572 - lr: 1.0000e-04
# Epoch 222/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8704e-05 - rmse: 0.0054 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 1.0000e-04
# Epoch 223/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0639e-05 - rmse: 0.0045 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 1.0000e-04
# Epoch 224/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.2424e-05 - rmse: 0.0047 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 1.0000e-04
# Epoch 225/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.0656e-05 - rmse: 0.0055 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 1.0000e-04
# Epoch 226/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8359e-05 - rmse: 0.0053 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 1.0000e-04
# Epoch 227/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9559e-05 - rmse: 0.0044 - val_loss: 0.0033 - val_rmse: 0.0575 - lr: 1.0000e-04
# Epoch 228/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9420e-05 - rmse: 0.0044 - val_loss: 0.0033 - val_rmse: 0.0572 - lr: 1.0000e-04
# Epoch 229/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4658e-05 - rmse: 0.0038 - val_loss: 0.0033 - val_rmse: 0.0574 - lr: 1.0000e-04
# Epoch 230/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4756e-05 - rmse: 0.0050 - val_loss: 0.0033 - val_rmse: 0.0572 - lr: 1.0000e-04
# Epoch 231/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9174e-05 - rmse: 0.0044 - val_loss: 0.0033 - val_rmse: 0.0571 - lr: 1.0000e-04
# Epoch 232/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7582e-05 - rmse: 0.0042 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 1.0000e-04
# Epoch 233/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.3901e-05 - rmse: 0.0049 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 1.0000e-04
# Epoch 234/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4485e-05 - rmse: 0.0038 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 1.0000e-04
# Epoch 235/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0490e-05 - rmse: 0.0045 - val_loss: 0.0032 - val_rmse: 0.0568 - lr: 1.0000e-04
# Epoch 236/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9551e-05 - rmse: 0.0044 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 1.0000e-04
# Epoch 237/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.5546e-05 - rmse: 0.0051 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 1.0000e-04
# Epoch 238/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7444e-05 - rmse: 0.0042 - val_loss: 0.0033 - val_rmse: 0.0573 - lr: 1.0000e-04
# Epoch 239/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.7813e-05 - rmse: 0.0053 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 1.0000e-04
# Epoch 240/10000
# 5/5 [==============================] - ETA: 0s - loss: 1.5597e-05 - rmse: 0.0039
# Epoch 240: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5597e-05 - rmse: 0.0039 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 1.0000e-04
# Epoch 241/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5076e-05 - rmse: 0.0039 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 242/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0113e-05 - rmse: 0.0032 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 5.0000e-05
# Epoch 243/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.1215e-06 - rmse: 0.0028 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 244/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.0917e-06 - rmse: 0.0028 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 5.0000e-05
# Epoch 245/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.3899e-06 - rmse: 0.0027 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 5.0000e-05
# Epoch 246/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.6746e-06 - rmse: 0.0028 - val_loss: 0.0033 - val_rmse: 0.0575 - lr: 5.0000e-05
# Epoch 247/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.0431e-06 - rmse: 0.0028 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 248/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.9487e-06 - rmse: 0.0026 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 5.0000e-05
# Epoch 249/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.2058e-06 - rmse: 0.0021 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 250/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.0219e-06 - rmse: 0.0020 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 251/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.7395e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 252/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.5829e-06 - rmse: 0.0021 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 5.0000e-05
# Epoch 253/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.1655e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 254/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.5362e-06 - rmse: 0.0021 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 255/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.6654e-06 - rmse: 0.0019 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 5.0000e-05
# Epoch 256/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.3316e-06 - rmse: 0.0018 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 257/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.0315e-06 - rmse: 0.0020 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 258/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.4586e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 259/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9040e-06 - rmse: 0.0020 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 260/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.7027e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 261/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.5810e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 262/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.7571e-06 - rmse: 0.0017 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 263/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.3217e-06 - rmse: 0.0018 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 264/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.3356e-06 - rmse: 0.0018 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 265/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.2868e-06 - rmse: 0.0021 - val_loss: 0.0033 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 266/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.1250e-06 - rmse: 0.0018 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 267/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.1135e-06 - rmse: 0.0020 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 5.0000e-05
# Epoch 268/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.4740e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 269/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.8205e-06 - rmse: 0.0022 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 270/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.9587e-06 - rmse: 0.0024 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 271/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.4733e-06 - rmse: 0.0025 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 272/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9309e-06 - rmse: 0.0020 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 273/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.0692e-06 - rmse: 0.0020 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 274/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.3882e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 5.0000e-05
# Epoch 275/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.6321e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 276/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8247e-06 - rmse: 0.0017 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 277/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.3620e-06 - rmse: 0.0018 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 5.0000e-05
# Epoch 278/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8024e-06 - rmse: 0.0017 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 5.0000e-05
# Epoch 279/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.6113e-06 - rmse: 0.0019 - val_loss: 0.0033 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 280/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.1379e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 5.0000e-05
# Epoch 281/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.0736e-06 - rmse: 0.0018 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 5.0000e-05
# Epoch 282/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.4464e-06 - rmse: 0.0021 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 283/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.7076e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 284/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.6222e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 285/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.1440e-06 - rmse: 0.0020 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 286/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.4133e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 5.0000e-05
# Epoch 287/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.3289e-06 - rmse: 0.0021 - val_loss: 0.0033 - val_rmse: 0.0575 - lr: 5.0000e-05
# Epoch 288/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.7862e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 289/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1961e-06 - rmse: 0.0015 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 290/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0713e-06 - rmse: 0.0014 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 291/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0020e-06 - rmse: 0.0014 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 292/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3174e-06 - rmse: 0.0015 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 293/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1621e-06 - rmse: 0.0015 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 294/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.0953e-06 - rmse: 0.0018 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 295/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.6784e-06 - rmse: 0.0019 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 5.0000e-05
# Epoch 296/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.5023e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 297/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9302e-06 - rmse: 0.0014 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 298/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0927e-06 - rmse: 0.0014 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 299/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.2021e-06 - rmse: 0.0015 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 5.0000e-05
# Epoch 300/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.8634e-06 - rmse: 0.0014 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 301/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9438e-06 - rmse: 0.0014 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 302/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.6118e-06 - rmse: 0.0016 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 303/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.6111e-06 - rmse: 0.0016 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 304/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.5349e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 5.0000e-05
# Epoch 305/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.6794e-06 - rmse: 0.0022 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 306/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3021e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 5.0000e-05
# Epoch 307/10000
# ...
# Epoch 944/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7099e-08 - rmse: 1.3076e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 945/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7366e-08 - rmse: 1.3178e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 946/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5401e-08 - rmse: 1.2410e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 947/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.8691e-08 - rmse: 1.3672e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 948/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.8383e-08 - rmse: 1.3558e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 949/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7708e-08 - rmse: 1.3307e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 950/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7225e-08 - rmse: 1.3124e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 951/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.5599e-08 - rmse: 1.6000e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 952/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.2257e-08 - rmse: 1.4919e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 953/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0977e-08 - rmse: 1.4484e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 954/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9188e-08 - rmse: 1.3852e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 955/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.8262e-08 - rmse: 1.3514e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 956/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9896e-08 - rmse: 1.4105e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 957/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9723e-08 - rmse: 1.4044e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 958/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.0056e-08 - rmse: 1.7337e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 959/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.4843e-08 - rmse: 1.5762e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 960/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.4329e-08 - rmse: 1.5598e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 961/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.4667e-08 - rmse: 1.5706e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 962/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0038e-08 - rmse: 1.4156e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 963/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1187e-08 - rmse: 1.4556e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 964/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6632e-08 - rmse: 1.2896e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 965/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9614e-08 - rmse: 1.4005e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 966/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.8604e-08 - rmse: 1.3640e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 967/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0624e-08 - rmse: 1.4361e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 968/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7811e-08 - rmse: 1.3346e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 969/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7811e-08 - rmse: 1.3346e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 970/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7122e-08 - rmse: 1.3085e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 971/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9221e-08 - rmse: 1.3864e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 972/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6523e-08 - rmse: 1.2854e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 973/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6219e-08 - rmse: 1.2735e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 974/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5380e-08 - rmse: 1.2402e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 975/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2719e-08 - rmse: 1.1278e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 976/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4459e-08 - rmse: 1.2024e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 977/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5039e-08 - rmse: 1.2264e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 978/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4282e-08 - rmse: 1.1951e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 979/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3688e-08 - rmse: 1.1699e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 980/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4504e-08 - rmse: 1.2043e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 981/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4610e-08 - rmse: 1.2087e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 982/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3838e-08 - rmse: 1.1764e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 983/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4728e-08 - rmse: 1.2136e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 984/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3271e-08 - rmse: 1.1520e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 985/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5111e-08 - rmse: 1.2293e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 986/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3387e-08 - rmse: 1.1570e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 987/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5582e-08 - rmse: 1.2483e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 988/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4474e-08 - rmse: 1.2031e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 989/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3545e-08 - rmse: 1.1638e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 990/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5868e-08 - rmse: 1.2597e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 991/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6684e-08 - rmse: 1.2917e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 992/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4761e-08 - rmse: 1.2150e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 993/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3864e-08 - rmse: 1.1774e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 994/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3119e-08 - rmse: 1.1454e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 995/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2450e-08 - rmse: 1.1158e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 996/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2068e-08 - rmse: 1.0986e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 997/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4187e-08 - rmse: 1.1911e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 998/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4959e-08 - rmse: 1.2231e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 999/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2864e-08 - rmse: 1.1342e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1000/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4532e-08 - rmse: 1.2055e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1001/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5305e-08 - rmse: 1.2371e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1002/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7909e-08 - rmse: 1.3382e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1003/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2729e-08 - rmse: 1.1282e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1004/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3333e-08 - rmse: 1.1547e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1005/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6439e-08 - rmse: 1.2821e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1006/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3677e-08 - rmse: 1.1695e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1007/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2506e-08 - rmse: 1.1183e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1008/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4660e-08 - rmse: 1.2108e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1009/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3578e-08 - rmse: 1.1652e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1010/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7821e-08 - rmse: 1.3350e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1011/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6307e-08 - rmse: 1.2770e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1012/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4558e-08 - rmse: 1.2066e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1013/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2583e-08 - rmse: 1.1217e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1014/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2914e-08 - rmse: 1.1364e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1015/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1331e-08 - rmse: 1.0645e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1016/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4313e-08 - rmse: 1.1964e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1017/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2607e-08 - rmse: 1.1228e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1018/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0836e-08 - rmse: 1.0410e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1019/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4047e-08 - rmse: 1.1852e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1020/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1473e-08 - rmse: 1.0711e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1021/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4142e-08 - rmse: 1.1892e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1022/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2519e-08 - rmse: 1.1189e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1023/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1481e-08 - rmse: 1.0715e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1024/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4013e-08 - rmse: 1.1838e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1025/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1427e-08 - rmse: 1.0690e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1026/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2397e-08 - rmse: 1.1134e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1027/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3477e-08 - rmse: 1.1609e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1028/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6650e-08 - rmse: 1.2904e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1029/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5353e-08 - rmse: 1.2391e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1030/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2135e-08 - rmse: 1.1016e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1031/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3441e-08 - rmse: 1.1594e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1032/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1646e-08 - rmse: 1.0792e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1033/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3861e-08 - rmse: 1.1773e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1034/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1053e-08 - rmse: 1.0514e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1035/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1091e-08 - rmse: 1.0531e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1036/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2547e-08 - rmse: 1.1201e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1037/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2716e-08 - rmse: 1.1276e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1038/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3198e-08 - rmse: 1.1488e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1039/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1366e-08 - rmse: 1.0661e-04 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 6.2500e-06
# Epoch 1040/10000
# 5/5 [==============================] - ETA: 0s - loss: 1.0976e-08 - rmse: 1.0477e-04Restoring model weights from the end of the best epoch: 40.
#
# Epoch 1040: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 5/5 [==============================] - 0s 22ms/step - loss: 1.0976e-08 - rmse: 1.0477e-04 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 6.2500e-06
# Epoch 1040: early stopping

# %%
time = end - start
print("Training time:", time)
# Out:
# Training time: 0:01:43.105733

# %%
storage_dir = "D:\\VAWT_data\\flap_steady\\flap_steady\\result\\"+"20221205AeroCNN2_optimalSettings\\test"+str(test_rate)+"Cdonly"
if not os.path.exists(storage_dir):
    os.makedirs(storage_dir)
os.chdir(storage_dir)

# %%
hist = history.history
plt.plot(hist['loss'], lw=2, label='Training loss')
plt.plot(hist['val_loss'], lw=2, label='Validation loss')
plt.title('Training loss (mean squared error)\nAeroCNN-II, optimal settings, $C_d$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.yscale('log')
#plt.ylim([5e-5, 1e-1])
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()
plt.legend(loc='upper right')
saveName = "TrainingLoss_test"+str(test_rate) + ".jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(hist['rmse'], lw=2)
plt.plot(hist['val_rmse'], lw=2)
plt.title('Root Mean Squared Error, optimal settings, $C_d$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.show()

# %%
plt.plot(hist['rmse'], lw=2, label='Training RMSE')
plt.plot(hist['val_loss'], lw=2, label='Validation RMSE')
plt.title('Root Mean Squared Error\nAeroCNN-II, optimal settings, $C_d$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()
plt.legend(loc='upper right')
saveName = "RMSE_test"+str(test_rate) + ".jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
train_results = model.evaluate(x_train, y_train)
# Out:
# 4/4 [==============================] - 0s 20ms/step - loss: 5.3981e-04 - rmse: 0.0232

# %%
test_results = model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 84ms/step - loss: 6.8607e-04 - rmse: 0.0262

# %%
decoded_train_ = model.predict(x_train)
decoded_val_ = model.predict(x_val)
decoded_test_ = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
index_train = np.unique(np.where(np.isin(cd, y_train)))
index_val = np.unique(np.where(np.isin(cd, y_val)))
index_test = np.unique(np.where(np.isin(cd, y_test)))

# %%
y_train = y_train*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
y_val = y_val*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
y_test = y_test*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)

# %%
decoded_train = decoded_train_*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
decoded_val = decoded_val_*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
decoded_test = decoded_test_*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)

# %%
model_directory = "D:\\TrainedModels\\20221205"
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
os.chdir(model_directory)
model_name = "20221205steadyValidation_AeroCNN2_val_"+str(val_rate)+"_test"+str(test_rate)+ "_" + str(n_kernels) +"units_optimalSettings_Cdonly.h5"
model.save(model_name, overwrite=True, include_optimizer=True, save_format='h5')

# %%
error_train_abs = np.abs(decoded_train - y_train)

# %%
error_test_abs = np.abs(decoded_test - y_test)

# %%
os.chdir(storage_dir)

# %%
l2_error_train = np.sqrt(np.sum((decoded_train - y_train)**2) / np.sum(y_train**2))
print(l2_error_train)
# Out:
# 0.046668960377652266

# %%
l2_error_val = np.sqrt(np.sum((decoded_val - y_val)**2) / np.sum(y_val**2))
print(l2_error_val)
# Out:
# 0.09385913543389285

# %%
l2_error_test = np.sqrt(np.sum((decoded_test - y_test)**2) / np.sum(y_test**2))
print(l2_error_test)
# Out:
# 0.06100663129237096

# %%
l2_error_train_list = []
for i in range(0, len(x_train)):
    l2_error_train_data = np.sqrt(np.sum((decoded_train[i] - y_train[i])**2) / np.sum(y_train[i]**2))
    l2_error_train_list.append(l2_error_train_data)

# %%
l2_error_val_list = []
for i in range(0, len(x_val)):
    l2_error_val_data = np.sqrt(np.sum((decoded_val[i] - y_val[i])**2) / np.sum((y_val[i]+1e-07)**2))
    l2_error_val_list.append(l2_error_val_data)

# %%
l2_error_test_list = []
for i in range(0, len(x_test)):
    l2_error_test_data = np.sqrt(np.sum((decoded_test[i] - y_test[i])**2) / np.sum(y_test[i]**2))
    l2_error_test_list.append(l2_error_test_data)

# %%
plt.plot(np.linspace(1,x_train.shape[0],x_train.shape[0]),
         l2_error_train*np.ones(x_train.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_train.shape[0], x_train.shape[0]), l2_error_train_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, training\nValidation rate {0}, test rate {1}, optimal settings ($C_d$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "trainingErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(np.linspace(1,x_val.shape[0],x_val.shape[0]),
         l2_error_val*np.ones(x_val.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_val.shape[0], x_val.shape[0]), l2_error_val_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, validation\nValidation rate {0}, test rate {1}, optimal settings ($C_d$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "validationErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(np.linspace(1,x_test.shape[0],x_test.shape[0]),
         l2_error_test*np.ones(x_test.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_test.shape[0], x_test.shape[0]), l2_error_test_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, test\nValidation rate {0}, test rate {1}, optimal settings ($C_d$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "testErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
predicted = model.predict(x)
# Out:
# 5/5 [==============================] - 0s 49ms/step

# %%
def CD_trainTestSplit_Plot(i, CD, cd, aTrain, aTest, iTrain, iTest):
    
    title_0_Cd = 'Gurney flap not attached (NACA0018)\n$C_D$ prediction, L2 error=%.4f' % l2_error_Cd
    #title_0_Cl = 'Gurney flap not attached (NACA0018)\n$C_L$ prediction, L2 error=%.4f' % l2_error_Cl
    
    title_n_Cd = 'Gurney flap attached h=%.2f, '%(h[i]) + r'$\beta$=%d'%(beta[i])+'\n$C_D$ prediction, L2 error=%.4f'%(l2_error_Cd)
    #title_n_Cl = 'Gurney flap attached h=%.2f, '%(h[i]) + r'$\beta$=%d'%(beta[i])+'\n$C_L$ prediction, L2 error=%.4f'%(l2_error_Cl)
    
    if i==0:
#         title_Cd, title_Cl = title_0_Cd, title_0_Cl
#         savename1,savename2 = "CdComparison_NACA0018.jpg", "ClComparison_NACA0018.jpg"
        title_Cd = title_0_Cd
        savename1 = "CdComparison_NACA0018.jpg"
    else:
#         title_Cd, title_Cl = title_n_Cd, title_n_Cl
        title_Cd = title_n_Cd
        savename1 = "CdComparison_h"+str(h[i])+"_beta"+str(beta[i])+".jpg"
#         savename2 = "ClComparison_h"+str(h[i])+"_beta"+str(beta[i])+".jpg"
    
    # CD graph plot
    plt.plot(alpha, CD, 'k-', label='Ground truth')
    plt.plot(alpha, cd, 'k--', label='Predicted value')
    plt.scatter(aTrain, iTrain, color='b', label='Training set')
    plt.scatter(aVal, iVal, color='g', label='Validation set')
    plt.scatter(aTest, iTest, color='r', label='Test set')
    plt.xlabel('AoA (degree)')
    plt.ylabel('$C_D$')
    plt.title(title_Cd, fontsize=15)        
    plt.legend(loc='upper left')
    plt.ylim([0, 0.12])
    plt.grid()
    plt.savefig(savename1, dpi=300, bbox_inches='tight', pad_inches=0.3)
    plt.show()

    '''# CL graph plot
    plt.plot(alpha, CL, 'k-', label='Ground truth')
    plt.plot(alpha, cl, 'k--', label='Predicted value')
    plt.scatter(aTrain, iTrain[:,1]*(np.max(cl_orig)-np.min(cl_orig)) + np.min(cl_orig), color='b', label='Training set')
    plt.scatter(aTest, iTest[:,1]*(np.max(cl_orig)-np.min(cl_orig)) + np.min(cl_orig), color='r', label='Test set')
    plt.xlabel('AoA (degree)')
    plt.ylabel('$C_L$')
    plt.title(title_Cl, fontsize=15)
    plt.legend(loc='upper left')
    plt.ylim([0, 2])
    plt.grid()
    plt.savefig(savename2, dpi=300, bbox_inches='tight', pad_inches=0.3)
    plt.show()'''

# %%
h = [0, 0.01, 0.01, 0.01, 0.01, 0.01, 0.02, 0.02, 0.02, 0.02, 0.02, 0.03, 0.03, 0.03, 0.03, 0.03]
beta = [0, 30, 45, 60, 75, 90, 30, 45, 60, 75, 90, 30, 45, 60, 75, 90]
for i in range(0, 16):
    # Index from each dataset
    iTrain = []
    iVal = []
    iTest = []
    
    # Index from input data (alpha, in this case)
    alpha_train = []
    alpha_val = []
    alpha_test = []
    
    predictedValue = model.predict(x[n_alpha*i:n_alpha*(i+1),:])
    y_corres = y[n_alpha*i:n_alpha*(i+1),:]
    
    l2_error_Cd = np.sqrt(np.sum((predictedValue - y_corres)**2) / np.sum(y_corres**2))
    
    if i==0:
        print('NACA0018 airfoil without Gurney flap\nL2 error of Cd: {0:0.4f}'.format(l2_error_Cd))
    else:
        print('L2 error of Cd: {0:0.4f}'.format(l2_error_Cd))
    
    cd = predicted[n_alpha*i:n_alpha*(i+1)]*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    CD = y[n_alpha*i:n_alpha*(i+1)]*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    
    for ii, index in enumerate(index_train[np.where((index_train<(i+1)*n_alpha) & ((index_train>=i*n_alpha)))]):
        iTrain.append(predicted[index])
    for kk, index in enumerate(index_val[np.where((index_val<(i+1)*n_alpha) & ((index_val>=i*n_alpha)))]):
        iVal.append(predicted[index])    
    for jj, index in enumerate(index_test[np.where((index_test<(i+1)*n_alpha) & (index_test>=i*n_alpha))]):
        iTest.append(predicted[index])
        
    iTrain = np.array(iTrain)*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    iTest = np.array(iTest)*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    iVal = np.array(iVal)*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    
    for ii, index in enumerate(index_train[np.where((index_train<(i+1)*n_alpha) & ((index_train>=i*n_alpha)))]):
        alpha_train.append(aa[index])
    for kk, index in enumerate(index_val[np.where((index_val<(i+1)*n_alpha) & ((index_val>=i*n_alpha)))]):
        alpha_val.append(aa[index])
    for jj, index in enumerate(index_test[np.where((index_test<(i+1)*n_alpha) & ((index_test>=i*n_alpha)))]):
        alpha_test.append(aa[index])
        
    aTrain = np.array(alpha_train)*np.max(alpha)
    aVal = np.array(alpha_val)*np.max(alpha)
    aTest = np.array(alpha_test)*np.max(alpha)
    
    CD_trainTestSplit_Plot(i, CD, cd, aTrain, aTest, iTrain, iTest)
# Out:
# 1/1 [==============================] - 0s 77ms/step
# NACA0018 airfoil without Gurney flap
# L2 error of Cd: 0.1453
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.1267
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0928
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0792
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0848
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0557
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0459
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0416
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0495
# 1/1 [==============================] - 0s 17ms/step
# L2 error of Cd: 0.0452
# 1/1 [==============================] - 0s 17ms/step
# L2 error of Cd: 0.1258
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0372
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0271
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0535
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0327
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.2387
