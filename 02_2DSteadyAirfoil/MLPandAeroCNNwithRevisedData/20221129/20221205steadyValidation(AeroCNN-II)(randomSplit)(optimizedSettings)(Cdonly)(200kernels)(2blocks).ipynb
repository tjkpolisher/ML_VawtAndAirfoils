# %%
# Validation of the steady-state simulation - Case 3: AeroCNN-II
import os
import sys
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import datetime
# %matplotlib inline

# %%
### Defining parameters and hyperparameters of the model

n_kernels=200 # Number of kernels in convolutional network
kernel_size1=2
strides=1
n_units=128 # Number of units in the hidden layer of the MLP network
input_size = 100 # Size of input for the network (100 coefficients and 3 other parameters, AoA, h, beta)
lr = 1e-04 # Learning rate of the network
test_rate=0.1 # Defines the ratio of training dataset and test dataset
val_rate=0.2
n_data = 16 # Number of txt files from which the aerodynamic coefficients are extracted
batch_size = 20 # Mini-batch size

# %%
# Changing working directory

main_directory = 'D:\\VAWT_data\\flap_steady\\flap_steady'
os.chdir(main_directory)

# %%
## Basic parameters

c = 1 # Chord length
h = np.array([0.01, 0.02, 0.03]) * c # Height of the Gurney flaps
t = 0.02 * h # Thickness of the Gurney flaps
alpha = np.linspace(0, 16, 9).reshape((9,1)) # Angles of attack
beta = np.linspace(30, 90, 5).reshape((5,1))

h = h.reshape((-1,1))
t = t.reshape((-1,1))

# %%
n_alpha = alpha.shape[0] # Number of the angles of attack
n_beta = beta.shape[0] # Number of the Gurney flap inclination
n_h = h.shape[0] # Number of the height of the Gurney flaps
n_cases = n_data * n_alpha
aa_ = np.zeros((n_cases,1))
for i in range(0, n_data):
    aa_[n_alpha*i:n_alpha*(i+1),:] = alpha[:,:]
    
aa = aa_ / np.max(alpha)

# %%
h = h.reshape((-1,1))
t = t.reshape((-1,1))

# %%
n_alpha = alpha.shape[0] # Number of the angles of attack
n_beta = beta.shape[0] # Number of the Gurney flap inclination
n_h = h.shape[0] # Number of the height of the Gurney flaps
n_cases = n_data * n_alpha # Total number of cases(Number of geometries * Number of angles of attack)

# %%
## Creating input dataset - mask
mask_dir = main_directory + '\\aeroCNN2Mask'
os.chdir(mask_dir)
mask_list = os.listdir(mask_dir)
mask_target = [file for file in mask_list if file.endswith('.csv')]

# %%
mask_df = pd.DataFrame()
for file in mask_target:
    data = pd.read_csv(file, header=None)
    mask_df = pd.concat([mask_df, data], axis=0)

# %%
x = mask_df.iloc[:,:].values

# %%
x_alligned = np.zeros((x.shape[0],x.shape[1]))
for i in range(0,144*2):
    if i%2==0:
        x_alligned[i*100:(i+1)*100,:] = x[i*100:(i+1)*100,:]
    else:
        x_alligned[i*100:(i+1)*100,:] = x[i*100:(i+1)*100,:].T

# %%
x = x_alligned.reshape((16*9,2,input_size,input_size))

# %%
## Creating output dataset - Cl and Cd
files_orig = os.listdir(main_directory)
files_target = [file for file in files_orig if file.endswith('.txt')]
os.chdir(main_directory)

# %%
target_df = pd.DataFrame()
for file in files_target:
    data = pd.read_table(file, header=None)
    target_df = pd.concat([target_df, data], axis=0)

# %%
cd_orig = target_df.iloc[:,3].values # Cd values
#target_c4 = target_df.iloc[:,4].values# Cl values

# %%
cd = (cd_orig-np.min(cd_orig))/(np.max(cd_orig)-np.min(cd_orig))

# %%
y = cd.reshape((-1,1))

# %%
x_all, x_test, y_all, y_test = train_test_split(x, y, test_size=test_rate, random_state=1)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_all, y_all, test_size=val_rate/(1-test_rate), random_state=1)

# %%
x_train.shape
# Out:
# (100, 2, 100, 100)

# %%
y_train.shape
# Out:
# (100, 1)

# %%
tf.keras.backend.set_image_data_format('channels_first')

# %%
input_image = tf.keras.Input(shape=(2, input_size, input_size))

x_conv1 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(input_image)
x1_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv1)
x_conv2 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x1_)
x2_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv2)
x_conv3 = tf.keras.layers.Conv2D(n_kernels, (kernel_size1, kernel_size1), strides=(strides, strides),
                                activation='relu', padding='same'
                                )(x2_)
x3_ = tf.keras.layers.MaxPooling2D((2,2))(x_conv3)
x_flat = tf.keras.layers.Flatten()(x3_)
x_fc1 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc1')(x_flat)
x_fc2 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc2')(x_fc1)
x_fc3 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc3')(x_fc2)
x_fc4 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc4')(x_fc3)
x_fc5 = tf.keras.layers.Dense(units=n_units, activation='relu', name='fc5')(x_fc4)

output_data = tf.keras.layers.Dense(units=1, activation='linear', name='outputLayer')(x_fc5)
# AeroCNN-II based
model = tf.keras.Model(input_image, output_data)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2, 100, 100)]     0
#
#  conv2d (Conv2D)             (None, 200, 100, 100)     1800
#
#  max_pooling2d (MaxPooling2D  (None, 200, 50, 50)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 200, 50, 50)       160200
#
#  max_pooling2d_1 (MaxPooling  (None, 200, 25, 25)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 200, 25, 25)       160200
#
#  max_pooling2d_2 (MaxPooling  (None, 200, 12, 12)      0
#  2D)
#
#  flatten (Flatten)           (None, 28800)             0
#
#  fc1 (Dense)                 (None, 128)               3686528
#
#  fc2 (Dense)                 (None, 128)               16512
#
#  fc3 (Dense)                 (None, 128)               16512
#
#  fc4 (Dense)                 (None, 128)               16512
#
#  fc5 (Dense)                 (None, 128)               16512
#
#  outputLayer (Dense)         (None, 1)                 129
#
# =================================================================
# Total params: 4,074,905
# Trainable params: 4,074,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
              loss = tf.keras.losses.MeanSquaredError(),
              metrics=[tf.keras.metrics.RootMeanSquaredError(name="rmse")])

# %%
model_directory = "D:\\TrainedModels\\20221130"
if not os.path.exists(model_directory):
    os.makedirs(model_directory)

# %%
# ckpt_name = model_directory + "\\20221130steadyValidation_AeroCNN2_val_"+str(val_rate) + "_test"+str(test_rate)+ "_" + str(n_units) +"units_OptimalSettings_Cdcheckpoint.h5"

# ckpt = tf.keras.callbacks.ModelCheckpoint(ckpt_name, monitor="val_loss", mode='min', verbose=1, save_best_only=True)

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=1000, min_delta=6e-7,
                                      restore_best_weights=True, verbose=1)
rp = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=200, factor=0.5,
                                          min_delta = 1e-09, min_lr=1e-06, verbose=1)

# %%
STEP_SIZE_TRAIN = len(x_train)//batch_size
VALIDATION_STEPS = len(x_val)//batch_size

# %%
start = datetime.datetime.now()
history = model.fit(x_train, y_train, batch_size=batch_size,
                    validation_data=(x_val, y_val),
                    steps_per_epoch = STEP_SIZE_TRAIN, validation_steps=VALIDATION_STEPS,
                    epochs=10000, shuffle=True, callbacks=[es, rp])
end = datetime.datetime.now()
# Out:
# Epoch 1/10000
# 5/5 [==============================] - 13s 105ms/step - loss: 0.1365 - rmse: 0.3694 - val_loss: 0.0214 - val_rmse: 0.1463 - lr: 1.0000e-04
# Epoch 2/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0169 - rmse: 0.1298 - val_loss: 0.0252 - val_rmse: 0.1588 - lr: 1.0000e-04
# Epoch 3/10000
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0164 - rmse: 0.1279 - val_loss: 0.0098 - val_rmse: 0.0988 - lr: 1.0000e-04
# Epoch 4/10000
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0078 - rmse: 0.0884 - val_loss: 0.0067 - val_rmse: 0.0820 - lr: 1.0000e-04
# Epoch 5/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0077 - rmse: 0.0880 - val_loss: 0.0056 - val_rmse: 0.0748 - lr: 1.0000e-04
# Epoch 6/10000
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0057 - rmse: 0.0755 - val_loss: 0.0037 - val_rmse: 0.0610 - lr: 1.0000e-04
# Epoch 7/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0040 - rmse: 0.0633 - val_loss: 0.0023 - val_rmse: 0.0483 - lr: 1.0000e-04
# Epoch 8/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0035 - rmse: 0.0589 - val_loss: 0.0052 - val_rmse: 0.0724 - lr: 1.0000e-04
# Epoch 9/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0024 - rmse: 0.0492 - val_loss: 0.0044 - val_rmse: 0.0660 - lr: 1.0000e-04
# Epoch 10/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0021 - rmse: 0.0462 - val_loss: 0.0046 - val_rmse: 0.0681 - lr: 1.0000e-04
# Epoch 11/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0022 - rmse: 0.0468 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 1.0000e-04
# Epoch 12/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0023 - rmse: 0.0478 - val_loss: 0.0068 - val_rmse: 0.0823 - lr: 1.0000e-04
# Epoch 13/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0033 - rmse: 0.0574 - val_loss: 0.0037 - val_rmse: 0.0606 - lr: 1.0000e-04
# Epoch 14/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0036 - rmse: 0.0604 - val_loss: 0.0038 - val_rmse: 0.0613 - lr: 1.0000e-04
# Epoch 15/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0023 - rmse: 0.0480 - val_loss: 0.0048 - val_rmse: 0.0690 - lr: 1.0000e-04
# Epoch 16/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0021 - rmse: 0.0461 - val_loss: 0.0039 - val_rmse: 0.0623 - lr: 1.0000e-04
# Epoch 17/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0020 - rmse: 0.0445 - val_loss: 0.0043 - val_rmse: 0.0659 - lr: 1.0000e-04
# Epoch 18/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0020 - rmse: 0.0442 - val_loss: 0.0038 - val_rmse: 0.0620 - lr: 1.0000e-04
# Epoch 19/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0021 - rmse: 0.0459 - val_loss: 0.0029 - val_rmse: 0.0543 - lr: 1.0000e-04
# Epoch 20/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0338 - val_loss: 0.0024 - val_rmse: 0.0493 - lr: 1.0000e-04
# Epoch 21/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0011 - rmse: 0.0326 - val_loss: 0.0041 - val_rmse: 0.0640 - lr: 1.0000e-04
# Epoch 22/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0021 - rmse: 0.0456 - val_loss: 0.0029 - val_rmse: 0.0534 - lr: 1.0000e-04
# Epoch 23/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0021 - rmse: 0.0454 - val_loss: 0.0080 - val_rmse: 0.0894 - lr: 1.0000e-04
# Epoch 24/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0045 - rmse: 0.0669 - val_loss: 0.0037 - val_rmse: 0.0605 - lr: 1.0000e-04
# Epoch 25/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0045 - rmse: 0.0667 - val_loss: 0.0143 - val_rmse: 0.1197 - lr: 1.0000e-04
# Epoch 26/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0063 - rmse: 0.0792 - val_loss: 0.0078 - val_rmse: 0.0883 - lr: 1.0000e-04
# Epoch 27/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0039 - rmse: 0.0623 - val_loss: 0.0065 - val_rmse: 0.0809 - lr: 1.0000e-04
# Epoch 28/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0033 - rmse: 0.0570 - val_loss: 0.0071 - val_rmse: 0.0844 - lr: 1.0000e-04
# Epoch 29/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0020 - rmse: 0.0449 - val_loss: 0.0042 - val_rmse: 0.0645 - lr: 1.0000e-04
# Epoch 30/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0018 - rmse: 0.0426 - val_loss: 0.0042 - val_rmse: 0.0645 - lr: 1.0000e-04
# Epoch 31/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0013 - rmse: 0.0361 - val_loss: 0.0060 - val_rmse: 0.0775 - lr: 1.0000e-04
# Epoch 32/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.6800e-04 - rmse: 0.0295 - val_loss: 0.0031 - val_rmse: 0.0555 - lr: 1.0000e-04
# Epoch 33/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0013 - rmse: 0.0360 - val_loss: 0.0037 - val_rmse: 0.0605 - lr: 1.0000e-04
# Epoch 34/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.2453e-04 - rmse: 0.0287 - val_loss: 0.0048 - val_rmse: 0.0695 - lr: 1.0000e-04
# Epoch 35/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.1917e-04 - rmse: 0.0249 - val_loss: 0.0028 - val_rmse: 0.0531 - lr: 1.0000e-04
# Epoch 36/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 8.3368e-04 - rmse: 0.0289 - val_loss: 0.0033 - val_rmse: 0.0575 - lr: 1.0000e-04
# Epoch 37/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0326e-04 - rmse: 0.0224 - val_loss: 0.0043 - val_rmse: 0.0658 - lr: 1.0000e-04
# Epoch 38/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.2098e-04 - rmse: 0.0228 - val_loss: 0.0035 - val_rmse: 0.0593 - lr: 1.0000e-04
# Epoch 39/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0841e-04 - rmse: 0.0225 - val_loss: 0.0030 - val_rmse: 0.0547 - lr: 1.0000e-04
# Epoch 40/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.1176e-04 - rmse: 0.0226 - val_loss: 0.0045 - val_rmse: 0.0668 - lr: 1.0000e-04
# Epoch 41/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.5190e-04 - rmse: 0.0235 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 1.0000e-04
# Epoch 42/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.1409e-04 - rmse: 0.0267 - val_loss: 0.0033 - val_rmse: 0.0574 - lr: 1.0000e-04
# Epoch 43/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.7475e-04 - rmse: 0.0296 - val_loss: 0.0039 - val_rmse: 0.0626 - lr: 1.0000e-04
# Epoch 44/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.5022e-04 - rmse: 0.0308 - val_loss: 0.0038 - val_rmse: 0.0617 - lr: 1.0000e-04
# Epoch 45/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.7540e-04 - rmse: 0.0278 - val_loss: 0.0029 - val_rmse: 0.0534 - lr: 1.0000e-04
# Epoch 46/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 8.2289e-04 - rmse: 0.0287 - val_loss: 0.0038 - val_rmse: 0.0617 - lr: 1.0000e-04
# Epoch 47/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.5005e-04 - rmse: 0.0255 - val_loss: 0.0038 - val_rmse: 0.0614 - lr: 1.0000e-04
# Epoch 48/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.1619e-04 - rmse: 0.0286 - val_loss: 0.0031 - val_rmse: 0.0556 - lr: 1.0000e-04
# Epoch 49/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.3387e-04 - rmse: 0.0208 - val_loss: 0.0038 - val_rmse: 0.0616 - lr: 1.0000e-04
# Epoch 50/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.8103e-04 - rmse: 0.0219 - val_loss: 0.0035 - val_rmse: 0.0596 - lr: 1.0000e-04
# Epoch 51/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9760e-04 - rmse: 0.0199 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 1.0000e-04
# Epoch 52/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.1325e-04 - rmse: 0.0177 - val_loss: 0.0032 - val_rmse: 0.0569 - lr: 1.0000e-04
# Epoch 53/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.4092e-04 - rmse: 0.0210 - val_loss: 0.0037 - val_rmse: 0.0609 - lr: 1.0000e-04
# Epoch 54/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 3.6047e-04 - rmse: 0.0190 - val_loss: 0.0035 - val_rmse: 0.0593 - lr: 1.0000e-04
# Epoch 55/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.7824e-04 - rmse: 0.0219 - val_loss: 0.0043 - val_rmse: 0.0657 - lr: 1.0000e-04
# Epoch 56/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.0587e-04 - rmse: 0.0246 - val_loss: 0.0038 - val_rmse: 0.0617 - lr: 1.0000e-04
# Epoch 57/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3863e-04 - rmse: 0.0232 - val_loss: 0.0044 - val_rmse: 0.0663 - lr: 1.0000e-04
# Epoch 58/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.6297e-04 - rmse: 0.0257 - val_loss: 0.0043 - val_rmse: 0.0655 - lr: 1.0000e-04
# Epoch 59/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9676e-04 - rmse: 0.0244 - val_loss: 0.0033 - val_rmse: 0.0570 - lr: 1.0000e-04
# Epoch 60/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.7977e-04 - rmse: 0.0195 - val_loss: 0.0038 - val_rmse: 0.0613 - lr: 1.0000e-04
# Epoch 61/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.6068e-04 - rmse: 0.0215 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 1.0000e-04
# Epoch 62/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5488e-04 - rmse: 0.0160 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 1.0000e-04
# Epoch 63/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7078e-04 - rmse: 0.0131 - val_loss: 0.0036 - val_rmse: 0.0602 - lr: 1.0000e-04
# Epoch 64/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.2201e-04 - rmse: 0.0149 - val_loss: 0.0040 - val_rmse: 0.0632 - lr: 1.0000e-04
# Epoch 65/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.1053e-04 - rmse: 0.0176 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 1.0000e-04
# Epoch 66/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9484e-04 - rmse: 0.0140 - val_loss: 0.0039 - val_rmse: 0.0627 - lr: 1.0000e-04
# Epoch 67/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7202e-04 - rmse: 0.0131 - val_loss: 0.0035 - val_rmse: 0.0591 - lr: 1.0000e-04
# Epoch 68/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8195e-04 - rmse: 0.0135 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 1.0000e-04
# Epoch 69/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4796e-04 - rmse: 0.0122 - val_loss: 0.0039 - val_rmse: 0.0628 - lr: 1.0000e-04
# Epoch 70/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1042e-04 - rmse: 0.0105 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 1.0000e-04
# Epoch 71/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2796e-04 - rmse: 0.0113 - val_loss: 0.0039 - val_rmse: 0.0622 - lr: 1.0000e-04
# Epoch 72/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1214e-04 - rmse: 0.0106 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 1.0000e-04
# Epoch 73/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5655e-04 - rmse: 0.0125 - val_loss: 0.0037 - val_rmse: 0.0609 - lr: 1.0000e-04
# Epoch 74/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.6243e-04 - rmse: 0.0127 - val_loss: 0.0037 - val_rmse: 0.0607 - lr: 1.0000e-04
# Epoch 75/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1088e-04 - rmse: 0.0105 - val_loss: 0.0039 - val_rmse: 0.0628 - lr: 1.0000e-04
# Epoch 76/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4411e-04 - rmse: 0.0120 - val_loss: 0.0038 - val_rmse: 0.0618 - lr: 1.0000e-04
# Epoch 77/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0758e-04 - rmse: 0.0144 - val_loss: 0.0029 - val_rmse: 0.0538 - lr: 1.0000e-04
# Epoch 78/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.1720e-04 - rmse: 0.0178 - val_loss: 0.0043 - val_rmse: 0.0657 - lr: 1.0000e-04
# Epoch 79/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2997e-04 - rmse: 0.0114 - val_loss: 0.0033 - val_rmse: 0.0578 - lr: 1.0000e-04
# Epoch 80/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4684e-04 - rmse: 0.0121 - val_loss: 0.0039 - val_rmse: 0.0628 - lr: 1.0000e-04
# Epoch 81/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0284e-04 - rmse: 0.0142 - val_loss: 0.0030 - val_rmse: 0.0546 - lr: 1.0000e-04
# Epoch 82/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.5095e-04 - rmse: 0.0235 - val_loss: 0.0045 - val_rmse: 0.0674 - lr: 1.0000e-04
# Epoch 83/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.3573e-04 - rmse: 0.0231 - val_loss: 0.0036 - val_rmse: 0.0603 - lr: 1.0000e-04
# Epoch 84/10000
# 5/5 [==============================] - 0s 23ms/step - loss: 5.4081e-04 - rmse: 0.0233 - val_loss: 0.0042 - val_rmse: 0.0651 - lr: 1.0000e-04
# Epoch 85/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 3.6805e-04 - rmse: 0.0192 - val_loss: 0.0032 - val_rmse: 0.0563 - lr: 1.0000e-04
# Epoch 86/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.6431e-04 - rmse: 0.0163 - val_loss: 0.0044 - val_rmse: 0.0663 - lr: 1.0000e-04
# Epoch 87/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.0586e-04 - rmse: 0.0201 - val_loss: 0.0032 - val_rmse: 0.0565 - lr: 1.0000e-04
# Epoch 88/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.0459e-04 - rmse: 0.0201 - val_loss: 0.0037 - val_rmse: 0.0606 - lr: 1.0000e-04
# Epoch 89/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.0684e-04 - rmse: 0.0202 - val_loss: 0.0046 - val_rmse: 0.0675 - lr: 1.0000e-04
# Epoch 90/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.2604e-04 - rmse: 0.0181 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 1.0000e-04
# Epoch 91/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0725e-04 - rmse: 0.0175 - val_loss: 0.0041 - val_rmse: 0.0639 - lr: 1.0000e-04
# Epoch 92/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.8080e-04 - rmse: 0.0195 - val_loss: 0.0031 - val_rmse: 0.0557 - lr: 1.0000e-04
# Epoch 93/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5517e-04 - rmse: 0.0160 - val_loss: 0.0037 - val_rmse: 0.0606 - lr: 1.0000e-04
# Epoch 94/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6726e-04 - rmse: 0.0129 - val_loss: 0.0044 - val_rmse: 0.0664 - lr: 1.0000e-04
# Epoch 95/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.0660e-04 - rmse: 0.0202 - val_loss: 0.0046 - val_rmse: 0.0680 - lr: 1.0000e-04
# Epoch 96/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.4506e-04 - rmse: 0.0307 - val_loss: 0.0038 - val_rmse: 0.0616 - lr: 1.0000e-04
# Epoch 97/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.5929e-04 - rmse: 0.0257 - val_loss: 0.0046 - val_rmse: 0.0682 - lr: 1.0000e-04
# Epoch 98/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0018 - rmse: 0.0424 - val_loss: 0.0037 - val_rmse: 0.0611 - lr: 1.0000e-04
# Epoch 99/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0014 - rmse: 0.0373 - val_loss: 0.0063 - val_rmse: 0.0791 - lr: 1.0000e-04
# Epoch 100/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0013 - rmse: 0.0361 - val_loss: 0.0066 - val_rmse: 0.0813 - lr: 1.0000e-04
# Epoch 101/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0015 - rmse: 0.0386 - val_loss: 0.0036 - val_rmse: 0.0604 - lr: 1.0000e-04
# Epoch 102/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0018 - rmse: 0.0427 - val_loss: 0.0059 - val_rmse: 0.0767 - lr: 1.0000e-04
# Epoch 103/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0014 - rmse: 0.0375 - val_loss: 0.0047 - val_rmse: 0.0685 - lr: 1.0000e-04
# Epoch 104/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0012 - rmse: 0.0351 - val_loss: 0.0051 - val_rmse: 0.0711 - lr: 1.0000e-04
# Epoch 105/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.1963e-04 - rmse: 0.0249 - val_loss: 0.0048 - val_rmse: 0.0690 - lr: 1.0000e-04
# Epoch 106/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3000e-04 - rmse: 0.0230 - val_loss: 0.0042 - val_rmse: 0.0647 - lr: 1.0000e-04
# Epoch 107/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.1298e-04 - rmse: 0.0226 - val_loss: 0.0037 - val_rmse: 0.0608 - lr: 1.0000e-04
# Epoch 108/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.4709e-04 - rmse: 0.0186 - val_loss: 0.0045 - val_rmse: 0.0673 - lr: 1.0000e-04
# Epoch 109/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9693e-04 - rmse: 0.0172 - val_loss: 0.0038 - val_rmse: 0.0613 - lr: 1.0000e-04
# Epoch 110/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5038e-04 - rmse: 0.0158 - val_loss: 0.0042 - val_rmse: 0.0647 - lr: 1.0000e-04
# Epoch 111/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2311e-04 - rmse: 0.0149 - val_loss: 0.0048 - val_rmse: 0.0692 - lr: 1.0000e-04
# Epoch 112/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4546e-04 - rmse: 0.0157 - val_loss: 0.0045 - val_rmse: 0.0674 - lr: 1.0000e-04
# Epoch 113/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.1597e-04 - rmse: 0.0227 - val_loss: 0.0037 - val_rmse: 0.0607 - lr: 1.0000e-04
# Epoch 114/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8700e-04 - rmse: 0.0169 - val_loss: 0.0042 - val_rmse: 0.0652 - lr: 1.0000e-04
# Epoch 115/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.5584e-04 - rmse: 0.0214 - val_loss: 0.0045 - val_rmse: 0.0668 - lr: 1.0000e-04
# Epoch 116/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.1990e-04 - rmse: 0.0179 - val_loss: 0.0048 - val_rmse: 0.0693 - lr: 1.0000e-04
# Epoch 117/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4323e-04 - rmse: 0.0156 - val_loss: 0.0041 - val_rmse: 0.0638 - lr: 1.0000e-04
# Epoch 118/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1021e-04 - rmse: 0.0145 - val_loss: 0.0049 - val_rmse: 0.0697 - lr: 1.0000e-04
# Epoch 119/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5930e-04 - rmse: 0.0161 - val_loss: 0.0041 - val_rmse: 0.0637 - lr: 1.0000e-04
# Epoch 120/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0886e-04 - rmse: 0.0176 - val_loss: 0.0049 - val_rmse: 0.0702 - lr: 1.0000e-04
# Epoch 121/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.6666e-04 - rmse: 0.0191 - val_loss: 0.0044 - val_rmse: 0.0665 - lr: 1.0000e-04
# Epoch 122/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.3842e-04 - rmse: 0.0154 - val_loss: 0.0040 - val_rmse: 0.0635 - lr: 1.0000e-04
# Epoch 123/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.0332e-04 - rmse: 0.0201 - val_loss: 0.0035 - val_rmse: 0.0593 - lr: 1.0000e-04
# Epoch 124/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 4.3019e-04 - rmse: 0.0207 - val_loss: 0.0045 - val_rmse: 0.0673 - lr: 1.0000e-04
# Epoch 125/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0549e-04 - rmse: 0.0225 - val_loss: 0.0028 - val_rmse: 0.0525 - lr: 1.0000e-04
# Epoch 126/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.2935e-04 - rmse: 0.0207 - val_loss: 0.0036 - val_rmse: 0.0603 - lr: 1.0000e-04
# Epoch 127/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7967e-04 - rmse: 0.0167 - val_loss: 0.0037 - val_rmse: 0.0610 - lr: 1.0000e-04
# Epoch 128/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1867e-04 - rmse: 0.0148 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 1.0000e-04
# Epoch 129/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5898e-04 - rmse: 0.0126 - val_loss: 0.0038 - val_rmse: 0.0620 - lr: 1.0000e-04
# Epoch 130/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1938e-04 - rmse: 0.0148 - val_loss: 0.0036 - val_rmse: 0.0603 - lr: 1.0000e-04
# Epoch 131/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9638e-04 - rmse: 0.0140 - val_loss: 0.0037 - val_rmse: 0.0605 - lr: 1.0000e-04
# Epoch 132/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2505e-04 - rmse: 0.0150 - val_loss: 0.0039 - val_rmse: 0.0625 - lr: 1.0000e-04
# Epoch 133/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.4804e-04 - rmse: 0.0187 - val_loss: 0.0028 - val_rmse: 0.0528 - lr: 1.0000e-04
# Epoch 134/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.8117e-04 - rmse: 0.0261 - val_loss: 0.0045 - val_rmse: 0.0670 - lr: 1.0000e-04
# Epoch 135/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.9116e-04 - rmse: 0.0198 - val_loss: 0.0039 - val_rmse: 0.0624 - lr: 1.0000e-04
# Epoch 136/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.4911e-04 - rmse: 0.0187 - val_loss: 0.0029 - val_rmse: 0.0541 - lr: 1.0000e-04
# Epoch 137/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.9131e-04 - rmse: 0.0198 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 1.0000e-04
# Epoch 138/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9775e-04 - rmse: 0.0173 - val_loss: 0.0045 - val_rmse: 0.0669 - lr: 1.0000e-04
# Epoch 139/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.6285e-04 - rmse: 0.0190 - val_loss: 0.0037 - val_rmse: 0.0605 - lr: 1.0000e-04
# Epoch 140/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8698e-04 - rmse: 0.0169 - val_loss: 0.0033 - val_rmse: 0.0574 - lr: 1.0000e-04
# Epoch 141/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3787e-04 - rmse: 0.0154 - val_loss: 0.0039 - val_rmse: 0.0628 - lr: 1.0000e-04
# Epoch 142/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6926e-04 - rmse: 0.0130 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 1.0000e-04
# Epoch 143/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0140e-04 - rmse: 0.0142 - val_loss: 0.0038 - val_rmse: 0.0616 - lr: 1.0000e-04
# Epoch 144/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.5281e-04 - rmse: 0.0159 - val_loss: 0.0037 - val_rmse: 0.0609 - lr: 1.0000e-04
# Epoch 145/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2531e-04 - rmse: 0.0112 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 1.0000e-04
# Epoch 146/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4076e-04 - rmse: 0.0119 - val_loss: 0.0039 - val_rmse: 0.0623 - lr: 1.0000e-04
# Epoch 147/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1075e-04 - rmse: 0.0105 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 1.0000e-04
# Epoch 148/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1394e-04 - rmse: 0.0107 - val_loss: 0.0035 - val_rmse: 0.0591 - lr: 1.0000e-04
# Epoch 149/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.1234e-05 - rmse: 0.0084 - val_loss: 0.0039 - val_rmse: 0.0627 - lr: 1.0000e-04
# Epoch 150/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0757e-04 - rmse: 0.0104 - val_loss: 0.0035 - val_rmse: 0.0592 - lr: 1.0000e-04
# Epoch 151/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1098e-04 - rmse: 0.0105 - val_loss: 0.0035 - val_rmse: 0.0591 - lr: 1.0000e-04
# Epoch 152/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.8124e-05 - rmse: 0.0094 - val_loss: 0.0037 - val_rmse: 0.0612 - lr: 1.0000e-04
# Epoch 153/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1174e-04 - rmse: 0.0106 - val_loss: 0.0039 - val_rmse: 0.0624 - lr: 1.0000e-04
# Epoch 154/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0897e-04 - rmse: 0.0104 - val_loss: 0.0032 - val_rmse: 0.0567 - lr: 1.0000e-04
# Epoch 155/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2666e-04 - rmse: 0.0113 - val_loss: 0.0041 - val_rmse: 0.0643 - lr: 1.0000e-04
# Epoch 156/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4442e-04 - rmse: 0.0120 - val_loss: 0.0037 - val_rmse: 0.0607 - lr: 1.0000e-04
# Epoch 157/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3473e-04 - rmse: 0.0116 - val_loss: 0.0038 - val_rmse: 0.0619 - lr: 1.0000e-04
# Epoch 158/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.7805e-05 - rmse: 0.0094 - val_loss: 0.0033 - val_rmse: 0.0577 - lr: 1.0000e-04
# Epoch 159/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2941e-04 - rmse: 0.0114 - val_loss: 0.0038 - val_rmse: 0.0619 - lr: 1.0000e-04
# Epoch 160/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.0915e-05 - rmse: 0.0095 - val_loss: 0.0039 - val_rmse: 0.0627 - lr: 1.0000e-04
# Epoch 161/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2027e-04 - rmse: 0.0110 - val_loss: 0.0040 - val_rmse: 0.0634 - lr: 1.0000e-04
# Epoch 162/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0506e-04 - rmse: 0.0102 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 1.0000e-04
# Epoch 163/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1966e-04 - rmse: 0.0109 - val_loss: 0.0039 - val_rmse: 0.0625 - lr: 1.0000e-04
# Epoch 164/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8619e-04 - rmse: 0.0136 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 1.0000e-04
# Epoch 165/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9630e-04 - rmse: 0.0140 - val_loss: 0.0041 - val_rmse: 0.0637 - lr: 1.0000e-04
# Epoch 166/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1570e-04 - rmse: 0.0147 - val_loss: 0.0037 - val_rmse: 0.0612 - lr: 1.0000e-04
# Epoch 167/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1115e-04 - rmse: 0.0145 - val_loss: 0.0039 - val_rmse: 0.0627 - lr: 1.0000e-04
# Epoch 168/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.5925e-04 - rmse: 0.0190 - val_loss: 0.0030 - val_rmse: 0.0546 - lr: 1.0000e-04
# Epoch 169/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.2524e-04 - rmse: 0.0269 - val_loss: 0.0046 - val_rmse: 0.0676 - lr: 1.0000e-04
# Epoch 170/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.5625e-04 - rmse: 0.0256 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 1.0000e-04
# Epoch 171/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.0102e-04 - rmse: 0.0200 - val_loss: 0.0048 - val_rmse: 0.0690 - lr: 1.0000e-04
# Epoch 172/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.0164e-04 - rmse: 0.0265 - val_loss: 0.0030 - val_rmse: 0.0544 - lr: 1.0000e-04
# Epoch 173/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8609e-04 - rmse: 0.0169 - val_loss: 0.0031 - val_rmse: 0.0559 - lr: 1.0000e-04
# Epoch 174/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3112e-04 - rmse: 0.0152 - val_loss: 0.0032 - val_rmse: 0.0564 - lr: 1.0000e-04
# Epoch 175/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.5792e-04 - rmse: 0.0214 - val_loss: 0.0028 - val_rmse: 0.0530 - lr: 1.0000e-04
# Epoch 176/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8921e-04 - rmse: 0.0170 - val_loss: 0.0032 - val_rmse: 0.0562 - lr: 1.0000e-04
# Epoch 177/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.3843e-04 - rmse: 0.0184 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 1.0000e-04
# Epoch 178/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8519e-04 - rmse: 0.0169 - val_loss: 0.0037 - val_rmse: 0.0605 - lr: 1.0000e-04
# Epoch 179/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.4918e-04 - rmse: 0.0212 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 1.0000e-04
# Epoch 180/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0223e-04 - rmse: 0.0174 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 1.0000e-04
# Epoch 181/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8962e-04 - rmse: 0.0170 - val_loss: 0.0030 - val_rmse: 0.0549 - lr: 1.0000e-04
# Epoch 182/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0396e-04 - rmse: 0.0174 - val_loss: 0.0038 - val_rmse: 0.0613 - lr: 1.0000e-04
# Epoch 183/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9112e-04 - rmse: 0.0243 - val_loss: 0.0042 - val_rmse: 0.0646 - lr: 1.0000e-04
# Epoch 184/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.6322e-04 - rmse: 0.0215 - val_loss: 0.0029 - val_rmse: 0.0537 - lr: 1.0000e-04
# Epoch 185/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.9164e-04 - rmse: 0.0171 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 1.0000e-04
# Epoch 186/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 2.0265e-04 - rmse: 0.0142 - val_loss: 0.0036 - val_rmse: 0.0600 - lr: 1.0000e-04
# Epoch 187/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3672e-04 - rmse: 0.0117 - val_loss: 0.0027 - val_rmse: 0.0523 - lr: 1.0000e-04
# Epoch 188/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3069e-04 - rmse: 0.0114 - val_loss: 0.0033 - val_rmse: 0.0576 - lr: 1.0000e-04
# Epoch 189/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.3424e-05 - rmse: 0.0086 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 1.0000e-04
# Epoch 190/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4857e-05 - rmse: 0.0074 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 1.0000e-04
# Epoch 191/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.5082e-05 - rmse: 0.0067 - val_loss: 0.0032 - val_rmse: 0.0569 - lr: 1.0000e-04
# Epoch 192/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9763e-05 - rmse: 0.0077 - val_loss: 0.0035 - val_rmse: 0.0595 - lr: 1.0000e-04
# Epoch 193/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.5053e-05 - rmse: 0.0059 - val_loss: 0.0033 - val_rmse: 0.0574 - lr: 1.0000e-04
# Epoch 194/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.8608e-05 - rmse: 0.0077 - val_loss: 0.0032 - val_rmse: 0.0566 - lr: 1.0000e-04
# Epoch 195/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.5579e-05 - rmse: 0.0060 - val_loss: 0.0033 - val_rmse: 0.0574 - lr: 1.0000e-04
# Epoch 196/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8910e-05 - rmse: 0.0054 - val_loss: 0.0033 - val_rmse: 0.0575 - lr: 1.0000e-04
# Epoch 197/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 3.2600e-05 - rmse: 0.0057 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 1.0000e-04
# Epoch 198/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8345e-05 - rmse: 0.0053 - val_loss: 0.0033 - val_rmse: 0.0575 - lr: 1.0000e-04
# Epoch 199/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8412e-05 - rmse: 0.0053 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 1.0000e-04
# Epoch 200/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.1772e-05 - rmse: 0.0065 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 1.0000e-04
# Epoch 201/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4585e-05 - rmse: 0.0050 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 1.0000e-04
# Epoch 202/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3998e-05 - rmse: 0.0049 - val_loss: 0.0035 - val_rmse: 0.0593 - lr: 1.0000e-04
# Epoch 203/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2408e-05 - rmse: 0.0047 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 1.0000e-04
# Epoch 204/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3026e-05 - rmse: 0.0036 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 1.0000e-04
# Epoch 205/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3519e-05 - rmse: 0.0037 - val_loss: 0.0035 - val_rmse: 0.0589 - lr: 1.0000e-04
# Epoch 206/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0737e-05 - rmse: 0.0033 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 1.0000e-04
# Epoch 207/10000
# 5/5 [==============================] - ETA: 0s - loss: 1.6830e-05 - rmse: 0.0041
# Epoch 207: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6830e-05 - rmse: 0.0041 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 1.0000e-04
# Epoch 208/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0203e-05 - rmse: 0.0032 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 5.0000e-05
# Epoch 209/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.6113e-06 - rmse: 0.0028 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 210/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.6050e-06 - rmse: 0.0028 - val_loss: 0.0034 - val_rmse: 0.0580 - lr: 5.0000e-05
# Epoch 211/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.0068e-06 - rmse: 0.0028 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 5.0000e-05
# Epoch 212/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.2634e-06 - rmse: 0.0027 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 5.0000e-05
# Epoch 213/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.2109e-06 - rmse: 0.0025 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 214/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3343e-06 - rmse: 0.0025 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 215/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9008e-06 - rmse: 0.0024 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 5.0000e-05
# Epoch 216/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.2881e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 217/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4247e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 218/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.9995e-06 - rmse: 0.0024 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 219/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.0586e-06 - rmse: 0.0025 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 5.0000e-05
# Epoch 220/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 6.3136e-06 - rmse: 0.0025 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 5.0000e-05
# Epoch 221/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.4050e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 222/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3724e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 5.0000e-05
# Epoch 223/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.8683e-06 - rmse: 0.0022 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 5.0000e-05
# Epoch 224/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.1819e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 5.0000e-05
# Epoch 225/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.6839e-06 - rmse: 0.0024 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 5.0000e-05
# Epoch 226/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7597e-06 - rmse: 0.0022 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 227/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.4177e-06 - rmse: 0.0025 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 5.0000e-05
# Epoch 228/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.9831e-06 - rmse: 0.0020 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 5.0000e-05
# Epoch 229/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.2768e-06 - rmse: 0.0023 - val_loss: 0.0035 - val_rmse: 0.0589 - lr: 5.0000e-05
# Epoch 230/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.2404e-06 - rmse: 0.0025 - val_loss: 0.0034 - val_rmse: 0.0585 - lr: 5.0000e-05
# Epoch 231/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.3065e-06 - rmse: 0.0023 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 5.0000e-05
# Epoch 232/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.1591e-06 - rmse: 0.0029 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 233/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0075e-05 - rmse: 0.0032 - val_loss: 0.0035 - val_rmse: 0.0591 - lr: 5.0000e-05
# Epoch 234/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.4081e-06 - rmse: 0.0027 - val_loss: 0.0034 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 235/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0067e-05 - rmse: 0.0032 - val_loss: 0.0035 - val_rmse: 0.0591 - lr: 5.0000e-05
# Epoch 236/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3237e-05 - rmse: 0.0036 - val_loss: 0.0033 - val_rmse: 0.0579 - lr: 5.0000e-05
# Epoch 237/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2144e-05 - rmse: 0.0035 - val_loss: 0.0035 - val_rmse: 0.0592 - lr: 5.0000e-05
# Epoch 238/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3874e-05 - rmse: 0.0037 - val_loss: 0.0035 - val_rmse: 0.0589 - lr: 5.0000e-05
# Epoch 239/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2201e-05 - rmse: 0.0047 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 5.0000e-05
# Epoch 240/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.6854e-05 - rmse: 0.0041 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 5.0000e-05
# Epoch 241/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5528e-05 - rmse: 0.0039 - val_loss: 0.0036 - val_rmse: 0.0596 - lr: 5.0000e-05
# Epoch 242/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5742e-05 - rmse: 0.0040 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 5.0000e-05
# Epoch 243/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.6694e-05 - rmse: 0.0041 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 5.0000e-05
# Epoch 244/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7391e-05 - rmse: 0.0042 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 245/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1709e-05 - rmse: 0.0034 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 246/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1840e-05 - rmse: 0.0034 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 247/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0938e-05 - rmse: 0.0033 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 5.0000e-05
# Epoch 248/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.7658e-06 - rmse: 0.0031 - val_loss: 0.0035 - val_rmse: 0.0593 - lr: 5.0000e-05
# Epoch 249/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.0388e-06 - rmse: 0.0028 - val_loss: 0.0034 - val_rmse: 0.0582 - lr: 5.0000e-05
# Epoch 250/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7995e-06 - rmse: 0.0022 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 5.0000e-05
# Epoch 251/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.4058e-06 - rmse: 0.0021 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 5.0000e-05
# Epoch 252/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.2124e-06 - rmse: 0.0021 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 5.0000e-05
# Epoch 253/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.0644e-06 - rmse: 0.0020 - val_loss: 0.0035 - val_rmse: 0.0592 - lr: 5.0000e-05
# Epoch 254/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.7021e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 5.0000e-05
# Epoch 255/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.5985e-06 - rmse: 0.0021 - val_loss: 0.0035 - val_rmse: 0.0589 - lr: 5.0000e-05
# Epoch 256/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9020e-06 - rmse: 0.0017 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 5.0000e-05
# Epoch 257/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.7178e-06 - rmse: 0.0022 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 258/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.0063e-06 - rmse: 0.0022 - val_loss: 0.0035 - val_rmse: 0.0592 - lr: 5.0000e-05
# Epoch 259/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.8528e-06 - rmse: 0.0024 - val_loss: 0.0034 - val_rmse: 0.0584 - lr: 5.0000e-05
# Epoch 260/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0080e-05 - rmse: 0.0032 - val_loss: 0.0035 - val_rmse: 0.0592 - lr: 5.0000e-05
# Epoch 261/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 9.6094e-06 - rmse: 0.0031 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 262/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.4291e-06 - rmse: 0.0025 - val_loss: 0.0035 - val_rmse: 0.0589 - lr: 5.0000e-05
# Epoch 263/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.1634e-06 - rmse: 0.0027 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 264/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 7.6447e-06 - rmse: 0.0028 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 5.0000e-05
# Epoch 265/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 5.8864e-06 - rmse: 0.0024 - val_loss: 0.0035 - val_rmse: 0.0591 - lr: 5.0000e-05
# Epoch 266/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.8614e-06 - rmse: 0.0026 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 267/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.0191e-06 - rmse: 0.0028 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 268/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0048e-05 - rmse: 0.0032 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 5.0000e-05
# Epoch 269/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3959e-05 - rmse: 0.0037 - val_loss: 0.0035 - val_rmse: 0.0596 - lr: 5.0000e-05
# Epoch 270/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2975e-05 - rmse: 0.0036 - val_loss: 0.0034 - val_rmse: 0.0581 - lr: 5.0000e-05
# Epoch 271/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0761e-05 - rmse: 0.0033 - val_loss: 0.0035 - val_rmse: 0.0595 - lr: 5.0000e-05
# Epoch 272/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 9.6669e-06 - rmse: 0.0031 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 5.0000e-05
# Epoch 273/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1934e-05 - rmse: 0.0035 - val_loss: 0.0034 - val_rmse: 0.0583 - lr: 5.0000e-05
# Epoch 274/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.3155e-06 - rmse: 0.0029 - val_loss: 0.0035 - val_rmse: 0.0593 - lr: 5.0000e-05
# Epoch 275/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.3242e-06 - rmse: 0.0025 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 5.0000e-05
# Epoch 276/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.2360e-06 - rmse: 0.0029 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 277/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.7036e-06 - rmse: 0.0019 - val_loss: 0.0035 - val_rmse: 0.0589 - lr: 5.0000e-05
# Epoch 278/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.7867e-06 - rmse: 0.0019 - val_loss: 0.0034 - val_rmse: 0.0586 - lr: 5.0000e-05
# Epoch 279/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6731e-06 - rmse: 0.0016 - val_loss: 0.0035 - val_rmse: 0.0591 - lr: 5.0000e-05
# Epoch 280/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8587e-06 - rmse: 0.0017 - val_loss: 0.0035 - val_rmse: 0.0591 - lr: 5.0000e-05
# Epoch 281/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8597e-06 - rmse: 0.0017 - val_loss: 0.0035 - val_rmse: 0.0588 - lr: 5.0000e-05
# Epoch 282/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2418e-06 - rmse: 0.0015 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 5.0000e-05
# Epoch 283/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4410e-06 - rmse: 0.0016 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 284/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3117e-06 - rmse: 0.0015 - val_loss: 0.0035 - val_rmse: 0.0593 - lr: 5.0000e-05
# Epoch 285/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.5019e-06 - rmse: 0.0023 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 286/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9474e-06 - rmse: 0.0017 - val_loss: 0.0035 - val_rmse: 0.0593 - lr: 5.0000e-05
# Epoch 287/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.5419e-06 - rmse: 0.0026 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 288/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.3041e-06 - rmse: 0.0021 - val_loss: 0.0035 - val_rmse: 0.0591 - lr: 5.0000e-05
# Epoch 289/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.3289e-06 - rmse: 0.0021 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 5.0000e-05
# Epoch 290/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.2644e-06 - rmse: 0.0021 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 291/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.5379e-06 - rmse: 0.0019 - val_loss: 0.0035 - val_rmse: 0.0593 - lr: 5.0000e-05
# Epoch 292/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.0035e-06 - rmse: 0.0025 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 293/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.3001e-06 - rmse: 0.0018 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 294/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.0464e-06 - rmse: 0.0020 - val_loss: 0.0035 - val_rmse: 0.0596 - lr: 5.0000e-05
# Epoch 295/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.1903e-06 - rmse: 0.0020 - val_loss: 0.0034 - val_rmse: 0.0587 - lr: 5.0000e-05
# Epoch 296/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.8174e-06 - rmse: 0.0020 - val_loss: 0.0035 - val_rmse: 0.0594 - lr: 5.0000e-05
# Epoch 297/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.9147e-06 - rmse: 0.0020 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 298/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0058e-06 - rmse: 0.0017 - val_loss: 0.0035 - val_rmse: 0.0592 - lr: 5.0000e-05
# Epoch 299/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8147e-06 - rmse: 0.0017 - val_loss: 0.0035 - val_rmse: 0.0591 - lr: 5.0000e-05
# Epoch 300/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.8827e-06 - rmse: 0.0020 - val_loss: 0.0035 - val_rmse: 0.0589 - lr: 5.0000e-05
# Epoch 301/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.3277e-06 - rmse: 0.0018 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 5.0000e-05
# Epoch 302/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0116e-06 - rmse: 0.0014 - val_loss: 0.0035 - val_rmse: 0.0589 - lr: 5.0000e-05
# Epoch 303/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.2592e-06 - rmse: 0.0015 - val_loss: 0.0035 - val_rmse: 0.0595 - lr: 5.0000e-05
# Epoch 304/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.1677e-06 - rmse: 0.0025 - val_loss: 0.0035 - val_rmse: 0.0592 - lr: 5.0000e-05
# Epoch 305/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.1319e-06 - rmse: 0.0025 - val_loss: 0.0035 - val_rmse: 0.0590 - lr: 5.0000e-05
# Epoch 306/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0970e-05 - rmse: 0.0033 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 5.0000e-05
# Epoch 307/10000
# ...
# Epoch 911/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.6025e-08 - rmse: 1.2659e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 912/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6977e-08 - rmse: 1.3030e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 913/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.6286e-08 - rmse: 1.2762e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 914/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6254e-08 - rmse: 1.2749e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 915/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5292e-08 - rmse: 1.2366e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 916/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4747e-08 - rmse: 1.2144e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 917/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6736e-08 - rmse: 1.2937e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 918/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5540e-08 - rmse: 1.2466e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 919/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5913e-08 - rmse: 1.2615e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 920/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8491e-08 - rmse: 1.3598e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 921/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6122e-08 - rmse: 1.2697e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 922/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5840e-08 - rmse: 1.2586e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 923/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3710e-08 - rmse: 1.1709e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 924/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4635e-08 - rmse: 1.2097e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 925/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5180e-08 - rmse: 1.2321e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 926/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3720e-08 - rmse: 1.1713e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 927/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4103e-08 - rmse: 1.1875e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 928/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5088e-08 - rmse: 1.2284e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 929/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5637e-08 - rmse: 1.2505e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 930/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4441e-08 - rmse: 1.2017e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 931/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6305e-08 - rmse: 1.2769e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 932/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.4463e-08 - rmse: 1.2026e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 933/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3639e-08 - rmse: 1.1679e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 934/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5526e-08 - rmse: 1.2460e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 935/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3815e-08 - rmse: 1.1754e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 936/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.4174e-08 - rmse: 1.1906e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 937/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4531e-08 - rmse: 1.2055e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 938/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3882e-08 - rmse: 1.1782e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 939/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3981e-08 - rmse: 1.1824e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 940/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3224e-08 - rmse: 1.1500e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 941/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3469e-08 - rmse: 1.1606e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 942/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2839e-08 - rmse: 1.1331e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 943/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2849e-08 - rmse: 1.1335e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 944/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3813e-08 - rmse: 1.1753e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 945/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3962e-08 - rmse: 1.1816e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 946/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3778e-08 - rmse: 1.1738e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 947/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3999e-08 - rmse: 1.1832e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 948/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3244e-08 - rmse: 1.1508e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 949/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4292e-08 - rmse: 1.1955e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 950/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2853e-08 - rmse: 1.1337e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 951/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4509e-08 - rmse: 1.2045e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 952/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4032e-08 - rmse: 1.1846e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 953/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3369e-08 - rmse: 1.1562e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 954/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4116e-08 - rmse: 1.1881e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 955/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3581e-08 - rmse: 1.1654e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 956/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5739e-08 - rmse: 1.2546e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 957/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5266e-08 - rmse: 1.2356e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 958/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.6958e-08 - rmse: 1.3022e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 959/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9219e-08 - rmse: 1.3863e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 960/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2983e-08 - rmse: 1.1394e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 961/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4992e-08 - rmse: 1.2244e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 962/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4090e-08 - rmse: 1.1870e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 963/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4694e-08 - rmse: 1.2122e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 964/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2891e-08 - rmse: 1.1354e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 965/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3604e-08 - rmse: 1.1664e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 966/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3018e-08 - rmse: 1.1410e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 967/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2241e-08 - rmse: 1.1064e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 968/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4418e-08 - rmse: 1.2007e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 969/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4391e-08 - rmse: 1.1996e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 970/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4682e-08 - rmse: 1.2117e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 971/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8540e-08 - rmse: 1.3616e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 972/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.6093e-08 - rmse: 1.2686e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 973/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5255e-08 - rmse: 1.2351e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 974/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5503e-08 - rmse: 1.2451e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 975/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5976e-08 - rmse: 1.2640e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 976/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6930e-08 - rmse: 1.3012e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 977/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.6403e-08 - rmse: 1.2808e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 978/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.7020e-08 - rmse: 1.3046e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 979/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2021e-08 - rmse: 1.0964e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 980/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2782e-08 - rmse: 1.1306e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 981/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2042e-08 - rmse: 1.0973e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 982/10000
# 5/5 [==============================] - 0s 20ms/step - loss: 1.3562e-08 - rmse: 1.1646e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 983/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3957e-08 - rmse: 1.1814e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 984/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3145e-08 - rmse: 1.1465e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 985/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2276e-08 - rmse: 1.1080e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 986/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4338e-08 - rmse: 1.1974e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 987/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3244e-08 - rmse: 1.1508e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 988/10000
# 5/5 [==============================] - 0s 22ms/step - loss: 1.4059e-08 - rmse: 1.1857e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 989/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2546e-08 - rmse: 1.1201e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 990/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2484e-08 - rmse: 1.1173e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 991/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1562e-08 - rmse: 1.0753e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 992/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2380e-08 - rmse: 1.1126e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 993/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4252e-08 - rmse: 1.1938e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 994/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4919e-08 - rmse: 1.2214e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 995/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3779e-08 - rmse: 1.1738e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 996/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4760e-08 - rmse: 1.2149e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 997/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6471e-08 - rmse: 1.2834e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 998/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8411e-08 - rmse: 1.3569e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 999/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7384e-08 - rmse: 1.6548e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 1000/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9461e-08 - rmse: 1.3950e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 1001/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6851e-08 - rmse: 1.2981e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 1002/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1184e-08 - rmse: 1.4555e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 1003/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.9469e-08 - rmse: 1.3953e-04 - val_loss: 0.0036 - val_rmse: 0.0597 - lr: 6.2500e-06
# Epoch 1004/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6319e-08 - rmse: 1.2774e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 1005/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7354e-08 - rmse: 1.3173e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 1006/10000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4652e-08 - rmse: 1.2105e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 1007/10000
# 5/5 [==============================] - ETA: 0s - loss: 1.3975e-08 - rmse: 1.1821e-04Restoring model weights from the end of the best epoch: 7.
#
# Epoch 1007: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 5/5 [==============================] - 0s 23ms/step - loss: 1.3975e-08 - rmse: 1.1821e-04 - val_loss: 0.0036 - val_rmse: 0.0598 - lr: 6.2500e-06
# Epoch 1007: early stopping

# %%
time = end - start
print("Training time:", time)
# Out:
# Training time: 0:01:54.115489

# %%
storage_dir = "D:\\VAWT_data\\flap_steady\\flap_steady\\result\\"+"20221205AeroCNN2_optimalSettings\\test"+str(test_rate)+"Cdonly"
if not os.path.exists(storage_dir):
    os.makedirs(storage_dir)
os.chdir(storage_dir)

# %%
hist = history.history
plt.plot(hist['loss'], lw=2, label='Training loss')
plt.plot(hist['val_loss'], lw=2, label='Validation loss')
plt.title('Training loss (mean squared error)\nAeroCNN-II, optimal settings, $C_d$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.yscale('log')
#plt.ylim([5e-5, 1e-1])
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()
plt.legend(loc='upper right')
saveName = "TrainingLoss_test"+str(test_rate) + ".jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(hist['rmse'], lw=2)
plt.plot(hist['val_rmse'], lw=2)
plt.title('Root Mean Squared Error, optimal settings, $C_d$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.show()

# %%
plt.plot(hist['rmse'], lw=2, label='Training RMSE')
plt.plot(hist['val_loss'], lw=2, label='Validation RMSE')
plt.title('Root Mean Squared Error\nAeroCNN-II, optimal settings, $C_d$ only', size=15)
plt.xlabel('Epoch', size=15)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()
plt.legend(loc='upper right')
saveName = "RMSE_test"+str(test_rate) + ".jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
train_results = model.evaluate(x_train, y_train)
# Out:
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0026 - rmse: 0.0512

# %%
test_results = model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0019 - rmse: 0.0432

# %%
decoded_train_ = model.predict(x_train)
decoded_val_ = model.predict(x_val)
decoded_test_ = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
index_train = np.unique(np.where(np.isin(cd, y_train)))
index_val = np.unique(np.where(np.isin(cd, y_val)))
index_test = np.unique(np.where(np.isin(cd, y_test)))

# %%
y_train = y_train*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
y_val = y_val*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
y_test = y_test*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)

# %%
decoded_train = decoded_train_*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
decoded_val = decoded_val_*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)
decoded_test = decoded_test_*(np.max(cd_orig)-np.min(cd_orig))+np.min(cd_orig)

# %%
model_directory = "D:\\TrainedModels\\20221205"
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
os.chdir(model_directory)
model_name = "20221205steadyValidation_AeroCNN2_val_"+str(val_rate)+"_test"+str(test_rate)+ "_" + str(n_kernels) +"units_optimalSettings_Cdonly.h5"
model.save(model_name, overwrite=True, include_optimizer=True, save_format='h5')

# %%
error_train_abs = np.abs(decoded_train - y_train)

# %%
error_test_abs = np.abs(decoded_test - y_test)

# %%
os.chdir(storage_dir)

# %%
l2_error_train = np.sqrt(np.sum((decoded_train - y_train)**2) / np.sum(y_train**2))
print(l2_error_train)
# Out:
# 0.10293591446846102

# %%
l2_error_val = np.sqrt(np.sum((decoded_val - y_val)**2) / np.sum(y_val**2))
print(l2_error_val)
# Out:
# 0.1058500868056762

# %%
l2_error_test = np.sqrt(np.sum((decoded_test - y_test)**2) / np.sum(y_test**2))
print(l2_error_test)
# Out:
# 0.10062279316145406

# %%
l2_error_train_list = []
for i in range(0, len(x_train)):
    l2_error_train_data = np.sqrt(np.sum((decoded_train[i] - y_train[i])**2) / np.sum(y_train[i]**2))
    l2_error_train_list.append(l2_error_train_data)

# %%
l2_error_val_list = []
for i in range(0, len(x_val)):
    l2_error_val_data = np.sqrt(np.sum((decoded_val[i] - y_val[i])**2) / np.sum((y_val[i]+1e-07)**2))
    l2_error_val_list.append(l2_error_val_data)

# %%
l2_error_test_list = []
for i in range(0, len(x_test)):
    l2_error_test_data = np.sqrt(np.sum((decoded_test[i] - y_test[i])**2) / np.sum(y_test[i]**2))
    l2_error_test_list.append(l2_error_test_data)

# %%
plt.plot(np.linspace(1,x_train.shape[0],x_train.shape[0]),
         l2_error_train*np.ones(x_train.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_train.shape[0], x_train.shape[0]), l2_error_train_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, training\nValidation rate {0}, test rate {1}, optimal settings ($C_d$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "trainingErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(np.linspace(1,x_val.shape[0],x_val.shape[0]),
         l2_error_val*np.ones(x_val.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_val.shape[0], x_val.shape[0]), l2_error_val_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, validation\nValidation rate {0}, test rate {1}, optimal settings ($C_d$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "validationErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
plt.plot(np.linspace(1,x_test.shape[0],x_test.shape[0]),
         l2_error_test*np.ones(x_test.shape[0],), 'k', lw=2.5)
plt.scatter(np.linspace(1, x_test.shape[0], x_test.shape[0]), l2_error_test_list, c='b')
plt.xlabel('Index', fontsize=15)
plt.ylabel('$L_2$ error norm', fontsize=15)
plt.yscale('log')
plt.title('$L_2$ error norm distribution - AeroCNN-II, test\nValidation rate {0}, test rate {1}, optimal settings ($C_d$)'.format(
    val_rate, test_rate), fontsize=15
         )
plt.grid()
saveName = "testErrorDistribution.jpg"
plt.savefig(saveName, dpi=300, bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
predicted = model.predict(x)
# Out:
# 5/5 [==============================] - 0s 30ms/step

# %%
def CD_trainTestSplit_Plot(i, CD, cd, aTrain, aTest, iTrain, iTest):
    
    title_0_Cd = 'Gurney flap not attached (NACA0018)\n$C_D$ prediction, L2 error=%.4f' % l2_error_Cd
    #title_0_Cl = 'Gurney flap not attached (NACA0018)\n$C_L$ prediction, L2 error=%.4f' % l2_error_Cl
    
    title_n_Cd = 'Gurney flap attached h=%.2f, '%(h[i]) + r'$\beta$=%d'%(beta[i])+'\n$C_D$ prediction, L2 error=%.4f'%(l2_error_Cd)
    #title_n_Cl = 'Gurney flap attached h=%.2f, '%(h[i]) + r'$\beta$=%d'%(beta[i])+'\n$C_L$ prediction, L2 error=%.4f'%(l2_error_Cl)
    
    if i==0:
#         title_Cd, title_Cl = title_0_Cd, title_0_Cl
#         savename1,savename2 = "CdComparison_NACA0018.jpg", "ClComparison_NACA0018.jpg"
        title_Cd = title_0_Cd
        savename1 = "CdComparison_NACA0018.jpg"
    else:
#         title_Cd, title_Cl = title_n_Cd, title_n_Cl
        title_Cd = title_n_Cd
        savename1 = "CdComparison_h"+str(h[i])+"_beta"+str(beta[i])+".jpg"
#         savename2 = "ClComparison_h"+str(h[i])+"_beta"+str(beta[i])+".jpg"
    
    # CD graph plot
    plt.plot(alpha, CD, 'k-', label='Ground truth')
    plt.plot(alpha, cd, 'k--', label='Predicted value')
    plt.scatter(aTrain, iTrain, color='b', label='Training set')
    plt.scatter(aVal, iVal, color='g', label='Validation set')
    plt.scatter(aTest, iTest, color='r', label='Test set')
    plt.xlabel('AoA (degree)')
    plt.ylabel('$C_D$')
    plt.title(title_Cd, fontsize=15)        
    plt.legend(loc='upper left')
    plt.ylim([0, 0.12])
    plt.grid()
    plt.savefig(savename1, dpi=300, bbox_inches='tight', pad_inches=0.3)
    plt.show()

    '''# CL graph plot
    plt.plot(alpha, CL, 'k-', label='Ground truth')
    plt.plot(alpha, cl, 'k--', label='Predicted value')
    plt.scatter(aTrain, iTrain[:,1]*(np.max(cl_orig)-np.min(cl_orig)) + np.min(cl_orig), color='b', label='Training set')
    plt.scatter(aTest, iTest[:,1]*(np.max(cl_orig)-np.min(cl_orig)) + np.min(cl_orig), color='r', label='Test set')
    plt.xlabel('AoA (degree)')
    plt.ylabel('$C_L$')
    plt.title(title_Cl, fontsize=15)
    plt.legend(loc='upper left')
    plt.ylim([0, 2])
    plt.grid()
    plt.savefig(savename2, dpi=300, bbox_inches='tight', pad_inches=0.3)
    plt.show()'''

# %%
h = [0, 0.01, 0.01, 0.01, 0.01, 0.01, 0.02, 0.02, 0.02, 0.02, 0.02, 0.03, 0.03, 0.03, 0.03, 0.03]
beta = [0, 30, 45, 60, 75, 90, 30, 45, 60, 75, 90, 30, 45, 60, 75, 90]
for i in range(0, 16):
    # Index from each dataset
    iTrain = []
    iVal = []
    iTest = []
    
    # Index from input data (alpha, in this case)
    alpha_train = []
    alpha_val = []
    alpha_test = []
    
    predictedValue = model.predict(x[n_alpha*i:n_alpha*(i+1),:])
    y_corres = y[n_alpha*i:n_alpha*(i+1),:]
    
    l2_error_Cd = np.sqrt(np.sum((predictedValue - y_corres)**2) / np.sum(y_corres**2))
    
    if i==0:
        print('NACA0018 airfoil without Gurney flap\nL2 error of Cd: {0:0.4f}'.format(l2_error_Cd))
    else:
        print('L2 error of Cd: {0:0.4f}'.format(l2_error_Cd))
    
    cd = predicted[n_alpha*i:n_alpha*(i+1)]*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    CD = y[n_alpha*i:n_alpha*(i+1)]*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    
    for ii, index in enumerate(index_train[np.where((index_train<(i+1)*n_alpha) & ((index_train>=i*n_alpha)))]):
        iTrain.append(predicted[index])
    for kk, index in enumerate(index_val[np.where((index_val<(i+1)*n_alpha) & ((index_val>=i*n_alpha)))]):
        iVal.append(predicted[index])    
    for jj, index in enumerate(index_test[np.where((index_test<(i+1)*n_alpha) & (index_test>=i*n_alpha))]):
        iTest.append(predicted[index])
        
    iTrain = np.array(iTrain)*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    iTest = np.array(iTest)*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    iVal = np.array(iVal)*(np.max(cd_orig)-np.min(cd_orig)) + np.min(cd_orig)
    
    for ii, index in enumerate(index_train[np.where((index_train<(i+1)*n_alpha) & ((index_train>=i*n_alpha)))]):
        alpha_train.append(aa[index])
    for kk, index in enumerate(index_val[np.where((index_val<(i+1)*n_alpha) & ((index_val>=i*n_alpha)))]):
        alpha_val.append(aa[index])
    for jj, index in enumerate(index_test[np.where((index_test<(i+1)*n_alpha) & ((index_test>=i*n_alpha)))]):
        alpha_test.append(aa[index])
        
    aTrain = np.array(alpha_train)*np.max(alpha)
    aVal = np.array(alpha_val)*np.max(alpha)
    aTest = np.array(alpha_test)*np.max(alpha)
    
    CD_trainTestSplit_Plot(i, CD, cd, aTrain, aTest, iTrain, iTest)
# Out:
# 1/1 [==============================] - 0s 70ms/step
# NACA0018 airfoil without Gurney flap
# L2 error of Cd: 0.2754
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.2321
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.1873
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.1752
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.1807
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.1625
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0885
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0740
# 1/1 [==============================] - 0s 16ms/step
# L2 error of Cd: 0.0520
# 1/1 [==============================] - 0s 17ms/step
# L2 error of Cd: 0.0935
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.1724
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0765
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.1050
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.0661
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.1046
# 1/1 [==============================] - 0s 15ms/step
# L2 error of Cd: 0.2631
